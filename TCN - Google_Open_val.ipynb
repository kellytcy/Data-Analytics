# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tcn import TCN
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-08-19    49.813290    51.835709    47.800831    49.982655    49.982655
# 2004-08-20    50.316402    54.336334    50.062355    53.952770    53.952770
# 2004-08-23    55.168217    56.528118    54.321388    54.495735    54.495735
# 2004-08-24    55.412300    55.591629    51.591621    52.239197    52.239197
# 2004-08-25    52.284027    53.798351    51.746044    52.802086    52.802086
# ...                 ...          ...          ...          ...          ...
# 2021-10-04  2713.989990  2714.000000  2623.330078  2675.300049  2675.300049
# 2021-10-05  2680.000000  2747.239990  2680.000000  2723.540039  2723.540039
# 2021-10-06  2692.510010  2757.040039  2689.729980  2747.080078  2747.080078
# 2021-10-07  2777.260010  2803.089111  2771.260010  2783.709961  2783.709961
# 2021-10-08  2798.120117  2806.340088  2788.586914  2801.120117  2801.120117
#
#               Volume
# Date
# 2004-08-19  44871361
# 2004-08-20  22942874
# 2004-08-23  18342897
# 2004-08-24  15319808
# 2004-08-25   9232276
# ...              ...
# 2021-10-04   1576500
# 2021-10-05   1206300
# 2021-10-06    988200
# 2021-10-07    912500
# 2021-10-08    946200
#
# [4316 rows x 6 columns]

# %%
dataset = df['Open']
dataset = dataset.values.astype('float32')
tf.random.set_seed(10)

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [],[]
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
dataset = dataset.reshape(-1,1)
mm = MinMaxScaler(feature_range=(0,1))

n = len(dataset)
train = dataset[0:int(n*0.7)]
val = dataset[int(n*0.7):int(n*0.8)]
test = dataset[int(n*0.8):]

# %%
look_back = 1
X_train, y_train = create_dataset(train, look_back)
X_val, y_val = create_dataset(val, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
X_train = X_train.reshape(-1,1)
X_val = X_val.reshape(-1,1)
y_train = y_train.reshape(-1,1)
y_val = y_val.reshape(-1,1)
X_test = X_test.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
X_train = mm.fit_transform(X_train)
y_train = mm.fit_transform(y_train)

X_val = mm.transform(X_val)
y_val = mm.transform(y_val)

X_test = mm.transform(X_test)
y_test = mm.transform(y_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_val = np.reshape(X_val, (X_val.shape[0], 1, X_val.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(TCN(nb_filters=64, kernel_size=4, nb_stacks=1, dilations=[1,2,4,8,16]))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train, y_train, epochs=100, batch_size = 64, verbose = 2, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 48/48 - 2s - loss: 0.0206 - val_loss: 6.0695e-04 - 2s/epoch - 43ms/step
# Epoch 2/100
# 48/48 - 0s - loss: 1.4899e-04 - val_loss: 3.5091e-04 - 316ms/epoch - 7ms/step
# Epoch 3/100
# 48/48 - 0s - loss: 8.0132e-05 - val_loss: 2.8973e-04 - 313ms/epoch - 7ms/step
# Epoch 4/100
# 48/48 - 0s - loss: 7.9943e-05 - val_loss: 2.8636e-04 - 299ms/epoch - 6ms/step
# Epoch 5/100
# 48/48 - 0s - loss: 8.3098e-05 - val_loss: 3.0769e-04 - 311ms/epoch - 6ms/step
# Epoch 6/100
# 48/48 - 0s - loss: 8.4844e-05 - val_loss: 5.7583e-04 - 306ms/epoch - 6ms/step
# Epoch 7/100
# 48/48 - 0s - loss: 1.0580e-04 - val_loss: 3.9892e-04 - 304ms/epoch - 6ms/step
# Epoch 8/100
# 48/48 - 0s - loss: 9.0884e-05 - val_loss: 3.0332e-04 - 303ms/epoch - 6ms/step
# Epoch 9/100
# 48/48 - 0s - loss: 8.8926e-05 - val_loss: 5.9999e-04 - 304ms/epoch - 6ms/step
# Epoch 10/100
# 48/48 - 0s - loss: 1.0252e-04 - val_loss: 2.8558e-04 - 304ms/epoch - 6ms/step
# Epoch 11/100
# 48/48 - 0s - loss: 9.3166e-05 - val_loss: 3.1166e-04 - 305ms/epoch - 6ms/step
# Epoch 12/100
# 48/48 - 0s - loss: 8.1153e-05 - val_loss: 0.0011 - 303ms/epoch - 6ms/step
# Epoch 13/100
# 48/48 - 0s - loss: 1.0173e-04 - val_loss: 4.8624e-04 - 309ms/epoch - 6ms/step
# Epoch 14/100
# 48/48 - 0s - loss: 1.0025e-04 - val_loss: 3.0481e-04 - 304ms/epoch - 6ms/step
# Epoch 15/100
# 48/48 - 0s - loss: 1.2981e-04 - val_loss: 5.1573e-04 - 301ms/epoch - 6ms/step
# Epoch 16/100
# 48/48 - 0s - loss: 1.1968e-04 - val_loss: 3.2282e-04 - 302ms/epoch - 6ms/step
# Epoch 17/100
# 48/48 - 0s - loss: 1.2759e-04 - val_loss: 2.8745e-04 - 304ms/epoch - 6ms/step
# Epoch 18/100
# 48/48 - 0s - loss: 9.7390e-05 - val_loss: 3.6897e-04 - 301ms/epoch - 6ms/step
# Epoch 19/100
# 48/48 - 0s - loss: 8.4490e-05 - val_loss: 6.6249e-04 - 303ms/epoch - 6ms/step
# Epoch 20/100
# 48/48 - 0s - loss: 8.3875e-05 - val_loss: 2.8591e-04 - 304ms/epoch - 6ms/step
# Epoch 21/100
# 48/48 - 0s - loss: 8.8500e-05 - val_loss: 3.5291e-04 - 305ms/epoch - 6ms/step
# Epoch 22/100
# 48/48 - 0s - loss: 9.1174e-05 - val_loss: 3.0800e-04 - 300ms/epoch - 6ms/step
# Epoch 23/100
# 48/48 - 0s - loss: 9.0259e-05 - val_loss: 0.0010 - 301ms/epoch - 6ms/step
# Epoch 24/100
# 48/48 - 0s - loss: 1.0034e-04 - val_loss: 3.1132e-04 - 310ms/epoch - 6ms/step
# Epoch 25/100
# 48/48 - 0s - loss: 9.7626e-05 - val_loss: 3.7350e-04 - 305ms/epoch - 6ms/step
# Epoch 26/100
# 48/48 - 0s - loss: 2.1308e-04 - val_loss: 5.0005e-04 - 318ms/epoch - 7ms/step
# Epoch 27/100
# 48/48 - 0s - loss: 1.3617e-04 - val_loss: 3.3998e-04 - 330ms/epoch - 7ms/step
# Epoch 28/100
# 48/48 - 0s - loss: 1.2861e-04 - val_loss: 0.0016 - 326ms/epoch - 7ms/step
# Epoch 29/100
# 48/48 - 0s - loss: 1.0161e-04 - val_loss: 5.3367e-04 - 330ms/epoch - 7ms/step
# Epoch 30/100
# 48/48 - 0s - loss: 1.1274e-04 - val_loss: 3.6382e-04 - 353ms/epoch - 7ms/step
# Epoch 31/100
# 48/48 - 0s - loss: 1.3352e-04 - val_loss: 3.2706e-04 - 374ms/epoch - 8ms/step
# Epoch 32/100
# 48/48 - 0s - loss: 1.7510e-04 - val_loss: 0.0018 - 322ms/epoch - 7ms/step
# Epoch 33/100
# 48/48 - 0s - loss: 1.3266e-04 - val_loss: 3.1894e-04 - 303ms/epoch - 6ms/step
# Epoch 34/100
# 48/48 - 0s - loss: 1.0786e-04 - val_loss: 3.8845e-04 - 384ms/epoch - 8ms/step
# Epoch 35/100
# 48/48 - 0s - loss: 1.4565e-04 - val_loss: 9.3892e-04 - 302ms/epoch - 6ms/step
# Epoch 36/100
# 48/48 - 0s - loss: 1.6687e-04 - val_loss: 0.0074 - 311ms/epoch - 6ms/step
# Epoch 37/100
# 48/48 - 0s - loss: 2.9095e-04 - val_loss: 7.4749e-04 - 359ms/epoch - 7ms/step
# Epoch 38/100
# 48/48 - 0s - loss: 1.1806e-04 - val_loss: 2.8629e-04 - 309ms/epoch - 6ms/step
# Epoch 39/100
# 48/48 - 0s - loss: 1.3222e-04 - val_loss: 3.4659e-04 - 367ms/epoch - 8ms/step
# Epoch 40/100
# 48/48 - 0s - loss: 9.8312e-05 - val_loss: 0.0012 - 308ms/epoch - 6ms/step
# Epoch 41/100
# 48/48 - 0s - loss: 1.4122e-04 - val_loss: 5.0454e-04 - 306ms/epoch - 6ms/step
# Epoch 42/100
# 48/48 - 0s - loss: 2.1177e-04 - val_loss: 0.0023 - 306ms/epoch - 6ms/step
# Epoch 43/100
# 48/48 - 0s - loss: 1.3968e-04 - val_loss: 5.6489e-04 - 303ms/epoch - 6ms/step
# Epoch 44/100
# 48/48 - 0s - loss: 1.6992e-04 - val_loss: 0.0011 - 307ms/epoch - 6ms/step
# Epoch 45/100
# 48/48 - 0s - loss: 3.0262e-04 - val_loss: 0.0022 - 306ms/epoch - 6ms/step
# Epoch 46/100
# 48/48 - 0s - loss: 1.5125e-04 - val_loss: 3.0301e-04 - 366ms/epoch - 8ms/step
# Epoch 47/100
# 48/48 - 0s - loss: 1.0858e-04 - val_loss: 3.1547e-04 - 315ms/epoch - 7ms/step
# Epoch 48/100
# 48/48 - 0s - loss: 1.0991e-04 - val_loss: 3.0050e-04 - 360ms/epoch - 7ms/step
# Epoch 49/100
# 48/48 - 0s - loss: 2.4632e-04 - val_loss: 2.8536e-04 - 304ms/epoch - 6ms/step
# Epoch 50/100
# 48/48 - 0s - loss: 1.5515e-04 - val_loss: 5.5619e-04 - 305ms/epoch - 6ms/step
# Epoch 51/100
# 48/48 - 0s - loss: 1.0803e-04 - val_loss: 9.4168e-04 - 313ms/epoch - 7ms/step
# Epoch 52/100
# 48/48 - 0s - loss: 1.1596e-04 - val_loss: 4.8192e-04 - 305ms/epoch - 6ms/step
# Epoch 53/100
# 48/48 - 0s - loss: 1.4562e-04 - val_loss: 0.0046 - 310ms/epoch - 6ms/step
# Epoch 54/100
# 48/48 - 0s - loss: 2.6541e-04 - val_loss: 3.7561e-04 - 306ms/epoch - 6ms/step
# Epoch 55/100
# 48/48 - 0s - loss: 9.1409e-05 - val_loss: 4.6948e-04 - 307ms/epoch - 6ms/step
# Epoch 56/100
# 48/48 - 0s - loss: 1.6457e-04 - val_loss: 0.0014 - 309ms/epoch - 6ms/step
# Epoch 57/100
# 48/48 - 0s - loss: 3.3389e-04 - val_loss: 2.8818e-04 - 343ms/epoch - 7ms/step
# Epoch 58/100
# 48/48 - 0s - loss: 1.0263e-04 - val_loss: 0.0012 - 311ms/epoch - 6ms/step
# Epoch 59/100
# 48/48 - 0s - loss: 1.2855e-04 - val_loss: 0.0048 - 317ms/epoch - 7ms/step
# Epoch 60/100
# 48/48 - 0s - loss: 2.1637e-04 - val_loss: 0.0010 - 307ms/epoch - 6ms/step
# Epoch 61/100
# 48/48 - 0s - loss: 1.0271e-04 - val_loss: 4.2558e-04 - 322ms/epoch - 7ms/step
# Epoch 62/100
# 48/48 - 0s - loss: 9.4476e-05 - val_loss: 4.1760e-04 - 316ms/epoch - 7ms/step
# Epoch 63/100
# 48/48 - 0s - loss: 1.4695e-04 - val_loss: 6.6417e-04 - 316ms/epoch - 7ms/step
# Epoch 64/100
# 48/48 - 0s - loss: 1.0850e-04 - val_loss: 0.0015 - 310ms/epoch - 6ms/step
# Epoch 65/100
# 48/48 - 0s - loss: 1.4241e-04 - val_loss: 4.5190e-04 - 303ms/epoch - 6ms/step
# Epoch 66/100
# 48/48 - 0s - loss: 1.4497e-04 - val_loss: 3.2988e-04 - 342ms/epoch - 7ms/step
# Epoch 67/100
# 48/48 - 0s - loss: 1.1149e-04 - val_loss: 3.3368e-04 - 315ms/epoch - 7ms/step
# Epoch 68/100
# 48/48 - 0s - loss: 1.2253e-04 - val_loss: 0.0013 - 302ms/epoch - 6ms/step
# Epoch 69/100
# 48/48 - 0s - loss: 1.4524e-04 - val_loss: 0.0012 - 303ms/epoch - 6ms/step
# Epoch 70/100
# 48/48 - 0s - loss: 1.8623e-04 - val_loss: 0.0010 - 305ms/epoch - 6ms/step
# Epoch 71/100
# 48/48 - 0s - loss: 1.3068e-04 - val_loss: 4.0595e-04 - 307ms/epoch - 6ms/step
# Epoch 72/100
# 48/48 - 0s - loss: 1.1607e-04 - val_loss: 7.0517e-04 - 327ms/epoch - 7ms/step
# Epoch 73/100
# 48/48 - 0s - loss: 1.0862e-04 - val_loss: 0.0047 - 327ms/epoch - 7ms/step
# Epoch 74/100
# 48/48 - 0s - loss: 1.5650e-04 - val_loss: 4.4692e-04 - 306ms/epoch - 6ms/step
# Epoch 75/100
# 48/48 - 0s - loss: 9.2158e-05 - val_loss: 8.5097e-04 - 301ms/epoch - 6ms/step
# Epoch 76/100
# 48/48 - 0s - loss: 2.4907e-04 - val_loss: 0.0011 - 332ms/epoch - 7ms/step
# Epoch 77/100
# 48/48 - 0s - loss: 2.2888e-04 - val_loss: 2.9879e-04 - 336ms/epoch - 7ms/step
# Epoch 78/100
# 48/48 - 0s - loss: 1.2758e-04 - val_loss: 9.3586e-04 - 323ms/epoch - 7ms/step
# Epoch 79/100
# 48/48 - 0s - loss: 1.4980e-04 - val_loss: 3.3179e-04 - 331ms/epoch - 7ms/step
# Epoch 80/100
# 48/48 - 0s - loss: 1.4219e-04 - val_loss: 0.0011 - 336ms/epoch - 7ms/step
# Epoch 81/100
# 48/48 - 0s - loss: 1.0028e-04 - val_loss: 3.1766e-04 - 342ms/epoch - 7ms/step
# Epoch 82/100
# 48/48 - 0s - loss: 8.8592e-05 - val_loss: 2.9897e-04 - 313ms/epoch - 7ms/step
# Epoch 83/100
# 48/48 - 0s - loss: 1.0520e-04 - val_loss: 0.0014 - 318ms/epoch - 7ms/step
# Epoch 84/100
# 48/48 - 0s - loss: 1.3896e-04 - val_loss: 0.0025 - 302ms/epoch - 6ms/step
# Epoch 85/100
# 48/48 - 0s - loss: 1.2435e-04 - val_loss: 3.5042e-04 - 345ms/epoch - 7ms/step
# Epoch 86/100
# 48/48 - 0s - loss: 1.0983e-04 - val_loss: 8.4055e-04 - 318ms/epoch - 7ms/step
# Epoch 87/100
# 48/48 - 0s - loss: 1.3541e-04 - val_loss: 5.8375e-04 - 302ms/epoch - 6ms/step
# Epoch 88/100
# 48/48 - 0s - loss: 1.6845e-04 - val_loss: 5.5923e-04 - 310ms/epoch - 6ms/step
# Epoch 89/100
# 48/48 - 0s - loss: 9.0441e-05 - val_loss: 2.9225e-04 - 325ms/epoch - 7ms/step
# Epoch 90/100
# 48/48 - 0s - loss: 1.2129e-04 - val_loss: 2.8621e-04 - 315ms/epoch - 7ms/step
# Epoch 91/100
# 48/48 - 0s - loss: 2.5577e-04 - val_loss: 0.0039 - 312ms/epoch - 6ms/step
# Epoch 92/100
# 48/48 - 0s - loss: 1.7056e-04 - val_loss: 9.6175e-04 - 309ms/epoch - 6ms/step
# Epoch 93/100
# 48/48 - 0s - loss: 9.8602e-05 - val_loss: 4.1830e-04 - 310ms/epoch - 6ms/step
# Epoch 94/100
# 48/48 - 0s - loss: 1.0730e-04 - val_loss: 4.0194e-04 - 302ms/epoch - 6ms/step
# Epoch 95/100
# 48/48 - 0s - loss: 9.1666e-05 - val_loss: 3.9496e-04 - 309ms/epoch - 6ms/step
# Epoch 96/100
# 48/48 - 0s - loss: 1.1498e-04 - val_loss: 0.0012 - 313ms/epoch - 7ms/step
# Epoch 97/100
# 48/48 - 0s - loss: 1.2806e-04 - val_loss: 9.3818e-04 - 314ms/epoch - 7ms/step
# Epoch 98/100
# 48/48 - 0s - loss: 1.0284e-04 - val_loss: 5.5954e-04 - 316ms/epoch - 7ms/step
# Epoch 99/100
# 48/48 - 0s - loss: 9.8831e-05 - val_loss: 6.4070e-04 - 311ms/epoch - 6ms/step
# Epoch 100/100
# 48/48 - 0s - loss: 1.0840e-04 - val_loss: 6.8390e-04 - 303ms/epoch - 6ms/step

# %%
print("Evaluate on test data")
results = model.evaluate(X_test, y_test, batch_size=64)
print("Test loss:", results)
# Out:
# Evaluate on test data
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0022
# Test loss: 0.002196588786318898

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred = mm.inverse_transform(train_pred)
y_train = mm.inverse_transform(y_train)

test_pred = mm.inverse_transform(test_pred)
y_test = mm.inverse_transform(y_test)

train_score = np.sqrt(mean_squared_error(y_train[:,0], train_pred[:,0]))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test[:,0], test_pred[:,0]))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 95/95 [==============================] - 2s 2ms/step
# 27/27 [==============================] - 0s 2ms/step
# Train score: 8.60 RMSE
# Test score: 34.48 RMSE

# %%
z = len(train) + len(val)

# %%
look_back = 1
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[z + (look_back*2):len(dataset), :] = test_pred

plt.plot(dataset)
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()

# %% [markdown]
# ### Increasing timesteps

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
dataset = df['Open']
dataset = dataset.values.astype('float32')
tf.random.set_seed(10)

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [],[]
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
dataset = dataset.reshape(-1,1)
mm = MinMaxScaler(feature_range=(0,1))

n = len(dataset)
train = dataset[0:int(n*0.7)]
val = dataset[int(n*0.7):int(n*0.8)]
test = dataset[int(n*0.8):]

# %%
train = mm.fit_transform(train)
val = mm.transform(val)
test = mm.transform(test)

# %%
look_back = 3
X_train, y_train = create_dataset(train, look_back)
X_val, y_val = create_dataset(val, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
X_train.shape
# Out:
# (3017, 3)

# %%
y_train = y_train.reshape(-1,1)
y_val = y_val.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
X_val = np.reshape(X_val, (X_val.shape[0], 1, X_val.shape[1]))

# %%
model = Sequential()
model.add(TCN(nb_filters=64, kernel_size=4, nb_stacks=1, dilations=[1,2,4,8,16]))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train, y_train, epochs=100, batch_size = 64, verbose = 2, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 48/48 - 2s - loss: 0.0133 - val_loss: 9.5520e-04 - 2s/epoch - 43ms/step
# Epoch 2/100
# 48/48 - 0s - loss: 1.9506e-04 - val_loss: 6.4873e-04 - 315ms/epoch - 7ms/step
# Epoch 3/100
# 48/48 - 0s - loss: 1.5089e-04 - val_loss: 4.6493e-04 - 309ms/epoch - 6ms/step
# Epoch 4/100
# 48/48 - 0s - loss: 1.3158e-04 - val_loss: 5.1018e-04 - 304ms/epoch - 6ms/step
# Epoch 5/100
# 48/48 - 0s - loss: 1.2771e-04 - val_loss: 6.5053e-04 - 311ms/epoch - 6ms/step
# Epoch 6/100
# 48/48 - 0s - loss: 9.6595e-05 - val_loss: 0.0031 - 307ms/epoch - 6ms/step
# Epoch 7/100
# 48/48 - 0s - loss: 1.4368e-04 - val_loss: 0.0010 - 308ms/epoch - 6ms/step
# Epoch 8/100
# 48/48 - 0s - loss: 1.1689e-04 - val_loss: 0.0012 - 306ms/epoch - 6ms/step
# Epoch 9/100
# 48/48 - 0s - loss: 1.0560e-04 - val_loss: 5.1488e-04 - 312ms/epoch - 6ms/step
# Epoch 10/100
# 48/48 - 0s - loss: 1.0635e-04 - val_loss: 5.0674e-04 - 303ms/epoch - 6ms/step
# Epoch 11/100
# 48/48 - 0s - loss: 8.5661e-05 - val_loss: 7.6749e-04 - 314ms/epoch - 7ms/step
# Epoch 12/100
# 48/48 - 0s - loss: 1.3720e-04 - val_loss: 2.9770e-04 - 309ms/epoch - 6ms/step
# Epoch 13/100
# 48/48 - 0s - loss: 1.0243e-04 - val_loss: 3.3793e-04 - 309ms/epoch - 6ms/step
# Epoch 14/100
# 48/48 - 0s - loss: 1.0057e-04 - val_loss: 5.5587e-04 - 307ms/epoch - 6ms/step
# Epoch 15/100
# 48/48 - 0s - loss: 9.8469e-05 - val_loss: 2.9617e-04 - 328ms/epoch - 7ms/step
# Epoch 16/100
# 48/48 - 0s - loss: 1.0331e-04 - val_loss: 3.8130e-04 - 307ms/epoch - 6ms/step
# Epoch 17/100
# 48/48 - 0s - loss: 1.4780e-04 - val_loss: 6.2952e-04 - 312ms/epoch - 6ms/step
# Epoch 18/100
# 48/48 - 0s - loss: 1.9008e-04 - val_loss: 0.0042 - 310ms/epoch - 6ms/step
# Epoch 19/100
# 48/48 - 0s - loss: 1.9101e-04 - val_loss: 0.0031 - 314ms/epoch - 7ms/step
# Epoch 20/100
# 48/48 - 0s - loss: 1.7309e-04 - val_loss: 4.5746e-04 - 307ms/epoch - 6ms/step
# Epoch 21/100
# 48/48 - 0s - loss: 1.6615e-04 - val_loss: 0.0148 - 308ms/epoch - 6ms/step
# Epoch 22/100
# 48/48 - 0s - loss: 5.1959e-04 - val_loss: 0.0010 - 305ms/epoch - 6ms/step
# Epoch 23/100
# 48/48 - 0s - loss: 2.3273e-04 - val_loss: 0.0033 - 310ms/epoch - 6ms/step
# Epoch 24/100
# 48/48 - 0s - loss: 2.2391e-04 - val_loss: 2.9745e-04 - 313ms/epoch - 7ms/step
# Epoch 25/100
# 48/48 - 0s - loss: 1.9553e-04 - val_loss: 2.9720e-04 - 311ms/epoch - 6ms/step
# Epoch 26/100
# 48/48 - 0s - loss: 1.9511e-04 - val_loss: 5.7381e-04 - 307ms/epoch - 6ms/step
# Epoch 27/100
# 48/48 - 0s - loss: 1.5740e-04 - val_loss: 0.0012 - 310ms/epoch - 6ms/step
# Epoch 28/100
# 48/48 - 0s - loss: 2.8838e-04 - val_loss: 4.1984e-04 - 312ms/epoch - 6ms/step
# Epoch 29/100
# 48/48 - 0s - loss: 9.4695e-05 - val_loss: 6.3792e-04 - 318ms/epoch - 7ms/step
# Epoch 30/100
# 48/48 - 0s - loss: 9.6386e-05 - val_loss: 0.0016 - 319ms/epoch - 7ms/step
# Epoch 31/100
# 48/48 - 0s - loss: 9.7938e-05 - val_loss: 0.0017 - 310ms/epoch - 6ms/step
# Epoch 32/100
# 48/48 - 0s - loss: 2.1268e-04 - val_loss: 0.0024 - 320ms/epoch - 7ms/step
# Epoch 33/100
# 48/48 - 0s - loss: 2.1880e-04 - val_loss: 0.0012 - 317ms/epoch - 7ms/step
# Epoch 34/100
# 48/48 - 0s - loss: 1.2024e-04 - val_loss: 0.0040 - 319ms/epoch - 7ms/step
# Epoch 35/100
# 48/48 - 0s - loss: 2.1875e-04 - val_loss: 3.4031e-04 - 309ms/epoch - 6ms/step
# Epoch 36/100
# 48/48 - 0s - loss: 1.0564e-04 - val_loss: 2.8706e-04 - 317ms/epoch - 7ms/step
# Epoch 37/100
# 48/48 - 0s - loss: 1.6314e-04 - val_loss: 4.2508e-04 - 346ms/epoch - 7ms/step
# Epoch 38/100
# 48/48 - 0s - loss: 1.6508e-04 - val_loss: 2.8805e-04 - 336ms/epoch - 7ms/step
# Epoch 39/100
# 48/48 - 0s - loss: 1.6408e-04 - val_loss: 3.3221e-04 - 353ms/epoch - 7ms/step
# Epoch 40/100
# 48/48 - 0s - loss: 1.3219e-04 - val_loss: 3.2886e-04 - 371ms/epoch - 8ms/step
# Epoch 41/100
# 48/48 - 0s - loss: 1.2955e-04 - val_loss: 0.0052 - 346ms/epoch - 7ms/step
# Epoch 42/100
# 48/48 - 0s - loss: 2.0717e-04 - val_loss: 0.0021 - 326ms/epoch - 7ms/step
# Epoch 43/100
# 48/48 - 0s - loss: 2.8075e-04 - val_loss: 3.1385e-04 - 311ms/epoch - 6ms/step
# Epoch 44/100
# 48/48 - 0s - loss: 1.9922e-04 - val_loss: 5.9774e-04 - 309ms/epoch - 6ms/step
# Epoch 45/100
# 48/48 - 0s - loss: 4.8436e-04 - val_loss: 0.0013 - 310ms/epoch - 6ms/step
# Epoch 46/100
# 48/48 - 0s - loss: 5.1944e-04 - val_loss: 0.0044 - 310ms/epoch - 6ms/step
# Epoch 47/100
# 48/48 - 0s - loss: 1.5198e-04 - val_loss: 6.6410e-04 - 309ms/epoch - 6ms/step
# Epoch 48/100
# 48/48 - 0s - loss: 1.2856e-04 - val_loss: 9.8443e-04 - 316ms/epoch - 7ms/step
# Epoch 49/100
# 48/48 - 0s - loss: 1.6643e-04 - val_loss: 3.4006e-04 - 312ms/epoch - 6ms/step
# Epoch 50/100
# 48/48 - 0s - loss: 1.5923e-04 - val_loss: 9.1484e-04 - 309ms/epoch - 6ms/step
# Epoch 51/100
# 48/48 - 0s - loss: 1.1778e-04 - val_loss: 5.0474e-04 - 313ms/epoch - 7ms/step
# Epoch 52/100
# 48/48 - 0s - loss: 1.4231e-04 - val_loss: 0.0027 - 316ms/epoch - 7ms/step
# Epoch 53/100
# 48/48 - 0s - loss: 2.7234e-04 - val_loss: 2.9794e-04 - 315ms/epoch - 7ms/step
# Epoch 54/100
# 48/48 - 0s - loss: 1.7175e-04 - val_loss: 0.0049 - 312ms/epoch - 6ms/step
# Epoch 55/100
# 48/48 - 0s - loss: 3.6790e-04 - val_loss: 7.1230e-04 - 310ms/epoch - 6ms/step
# Epoch 56/100
# 48/48 - 0s - loss: 1.5303e-04 - val_loss: 2.9921e-04 - 331ms/epoch - 7ms/step
# Epoch 57/100
# 48/48 - 0s - loss: 1.0697e-04 - val_loss: 4.3439e-04 - 332ms/epoch - 7ms/step
# Epoch 58/100
# 48/48 - 0s - loss: 1.0815e-04 - val_loss: 3.3963e-04 - 310ms/epoch - 6ms/step
# Epoch 59/100
# 48/48 - 0s - loss: 1.0004e-04 - val_loss: 4.6127e-04 - 304ms/epoch - 6ms/step
# Epoch 60/100
# 48/48 - 0s - loss: 1.2652e-04 - val_loss: 5.5102e-04 - 327ms/epoch - 7ms/step
# Epoch 61/100
# 48/48 - 0s - loss: 1.5677e-04 - val_loss: 3.8774e-04 - 325ms/epoch - 7ms/step
# Epoch 62/100
# 48/48 - 0s - loss: 1.5155e-04 - val_loss: 2.9657e-04 - 322ms/epoch - 7ms/step
# Epoch 63/100
# 48/48 - 0s - loss: 1.3578e-04 - val_loss: 5.6294e-04 - 308ms/epoch - 6ms/step
# Epoch 64/100
# 48/48 - 0s - loss: 1.8533e-04 - val_loss: 0.0011 - 311ms/epoch - 6ms/step
# Epoch 65/100
# 48/48 - 0s - loss: 1.7067e-04 - val_loss: 4.7420e-04 - 311ms/epoch - 6ms/step
# Epoch 66/100
# 48/48 - 0s - loss: 2.8084e-04 - val_loss: 3.3913e-04 - 308ms/epoch - 6ms/step
# Epoch 67/100
# 48/48 - 0s - loss: 1.2826e-04 - val_loss: 0.0011 - 310ms/epoch - 6ms/step
# Epoch 68/100
# 48/48 - 0s - loss: 1.4447e-04 - val_loss: 9.1126e-04 - 306ms/epoch - 6ms/step
# Epoch 69/100
# 48/48 - 0s - loss: 2.1353e-04 - val_loss: 0.0014 - 303ms/epoch - 6ms/step
# Epoch 70/100
# 48/48 - 0s - loss: 1.1493e-04 - val_loss: 8.8829e-04 - 305ms/epoch - 6ms/step
# Epoch 71/100
# 48/48 - 0s - loss: 1.4101e-04 - val_loss: 0.0011 - 308ms/epoch - 6ms/step
# Epoch 72/100
# 48/48 - 0s - loss: 1.2988e-04 - val_loss: 5.2558e-04 - 310ms/epoch - 6ms/step
# Epoch 73/100
# 48/48 - 0s - loss: 1.1836e-04 - val_loss: 0.0023 - 308ms/epoch - 6ms/step
# Epoch 74/100
# 48/48 - 0s - loss: 1.0119e-04 - val_loss: 3.6137e-04 - 310ms/epoch - 6ms/step
# Epoch 75/100
# 48/48 - 0s - loss: 9.4775e-05 - val_loss: 0.0011 - 307ms/epoch - 6ms/step
# Epoch 76/100
# 48/48 - 0s - loss: 1.0589e-04 - val_loss: 2.8613e-04 - 312ms/epoch - 7ms/step
# Epoch 77/100
# 48/48 - 0s - loss: 1.2433e-04 - val_loss: 0.0016 - 312ms/epoch - 6ms/step
# Epoch 78/100
# 48/48 - 0s - loss: 2.3838e-04 - val_loss: 0.0015 - 310ms/epoch - 6ms/step
# Epoch 79/100
# 48/48 - 0s - loss: 1.7344e-04 - val_loss: 0.0014 - 320ms/epoch - 7ms/step
# Epoch 80/100
# 48/48 - 0s - loss: 1.1776e-04 - val_loss: 3.4100e-04 - 308ms/epoch - 6ms/step
# Epoch 81/100
# 48/48 - 0s - loss: 1.2070e-04 - val_loss: 0.0014 - 306ms/epoch - 6ms/step
# Epoch 82/100
# 48/48 - 0s - loss: 1.6831e-04 - val_loss: 9.6565e-04 - 317ms/epoch - 7ms/step
# Epoch 83/100
# 48/48 - 0s - loss: 1.8737e-04 - val_loss: 2.8884e-04 - 311ms/epoch - 6ms/step
# Epoch 84/100
# 48/48 - 0s - loss: 1.8532e-04 - val_loss: 0.0020 - 309ms/epoch - 6ms/step
# Epoch 85/100
# 48/48 - 0s - loss: 4.0145e-04 - val_loss: 2.9149e-04 - 308ms/epoch - 6ms/step
# Epoch 86/100
# 48/48 - 0s - loss: 9.7078e-05 - val_loss: 2.8939e-04 - 313ms/epoch - 7ms/step
# Epoch 87/100
# 48/48 - 0s - loss: 1.5230e-04 - val_loss: 4.6881e-04 - 329ms/epoch - 7ms/step
# Epoch 88/100
# 48/48 - 0s - loss: 1.0121e-04 - val_loss: 0.0011 - 334ms/epoch - 7ms/step
# Epoch 89/100
# 48/48 - 0s - loss: 1.0866e-04 - val_loss: 3.0877e-04 - 329ms/epoch - 7ms/step
# Epoch 90/100
# 48/48 - 0s - loss: 1.2727e-04 - val_loss: 2.8938e-04 - 373ms/epoch - 8ms/step
# Epoch 91/100
# 48/48 - 0s - loss: 1.1402e-04 - val_loss: 2.8905e-04 - 427ms/epoch - 9ms/step
# Epoch 92/100
# 48/48 - 0s - loss: 9.6102e-05 - val_loss: 3.7181e-04 - 376ms/epoch - 8ms/step
# Epoch 93/100
# 48/48 - 0s - loss: 1.0832e-04 - val_loss: 4.0627e-04 - 314ms/epoch - 7ms/step
# Epoch 94/100
# 48/48 - 0s - loss: 1.8476e-04 - val_loss: 3.0933e-04 - 328ms/epoch - 7ms/step
# Epoch 95/100
# 48/48 - 0s - loss: 1.3919e-04 - val_loss: 5.9693e-04 - 329ms/epoch - 7ms/step
# Epoch 96/100
# 48/48 - 0s - loss: 9.9406e-05 - val_loss: 5.0377e-04 - 340ms/epoch - 7ms/step
# Epoch 97/100
# 48/48 - 0s - loss: 1.1493e-04 - val_loss: 0.0014 - 337ms/epoch - 7ms/step
# Epoch 98/100
# 48/48 - 0s - loss: 1.1531e-04 - val_loss: 0.0012 - 354ms/epoch - 7ms/step
# Epoch 99/100
# 48/48 - 0s - loss: 1.2666e-04 - val_loss: 0.0011 - 347ms/epoch - 7ms/step
# Epoch 100/100
# 48/48 - 0s - loss: 1.4909e-04 - val_loss: 7.0162e-04 - 373ms/epoch - 8ms/step

# %%
print("Evaluate on test data")
results = model.evaluate(X_test, y_test, batch_size=64)
print("Test loss:", results)
# Out:
# Evaluate on test data
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0024
# Test loss: 0.002405231585726142

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred = mm.inverse_transform(train_pred)
y_train = mm.inverse_transform(y_train)

test_pred = mm.inverse_transform(test_pred)
y_test = mm.inverse_transform(y_test)

train_score = np.sqrt(mean_squared_error(y_train[:,0], train_pred[:,0]))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test[:,0], test_pred[:,0]))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 95/95 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 2ms/step
# Train score: 8.84 RMSE
# Test score: 36.08 RMSE

# %%
z = len(train) + len(val)

# %%
look_back = 3
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[z +4:len(dataset), :] = test_pred

plt.plot(dataset)
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()

# %% [markdown]
# ### Multiple features

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
dataset = df.values.astype('float32')
tf.random.set_seed(10)

mm = MinMaxScaler(feature_range=(0,1))

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# %%
train = mm.fit_transform(train)
test = mm.transform(test)

# %%
train
# Out:
# array([[3.5772845e-04, 1.0171272e-03, 0.0000000e+00, 1.4599040e-04,
#         1.4599040e-04, 5.4357713e-01],
#        [8.0378354e-04, 3.2179765e-03, 2.0117126e-03, 3.6717802e-03,
#         3.6717802e-03, 2.7788585e-01],
#        [5.1053390e-03, 5.1470064e-03, 5.8002844e-03, 4.1539781e-03,
#         4.1539781e-03, 2.2215134e-01],
#        ...,
#        [8.6769450e-01, 8.7106174e-01, 8.6736101e-01, 8.6549103e-01,
#         8.6549103e-01, 1.9327592e-02],
#        [8.5962659e-01, 8.6163211e-01, 8.5261244e-01, 8.6490488e-01,
#         8.6490488e-01, 2.1896239e-02],
#        [8.5776478e-01, 8.7820917e-01, 8.6205047e-01, 8.8665396e-01,
#         8.8665396e-01, 2.3393810e-02]], dtype=float32)

# %%
y_train = train[:,0]
y_test = test[:,0]

# %%
def create_dataset_features (dataset, look_back=1):
    dataX = np.ones(shape=(1, 6))
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), :]
        dataX = np.vstack((dataX, a))
    return np.array(dataX)

# %%
def create_test (dataset, look_back=1):
    dataY = np.ones(shape=(1))
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back)]
        dataY = np.vstack((dataY, a))
    return np.array(dataY)

# %%
look_back = 1
X_train = create_dataset_features(train, look_back)
X_test = create_dataset_features(test, look_back)
y_train = create_test(y_train, look_back)
y_test = create_test(y_test, look_back)

# %%
X_train = np.delete(X_train, 0, 0)
y_train = np.delete(y_train, 0, 0)
X_test = np.delete(X_test, 0, 0)
y_test = np.delete(y_test, 0, 0)

# %%
X_train_reshape = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test_reshape = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(1, 6), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train_reshape, y_train, epochs=100, batch_size = 64, verbose = 2)
model.summary()
# Out:
# Epoch 1/100
# 54/54 - 2s - loss: 0.0587 - 2s/epoch - 45ms/step
# Epoch 2/100
# 54/54 - 0s - loss: 0.0045 - 93ms/epoch - 2ms/step
# Epoch 3/100
# 54/54 - 0s - loss: 0.0023 - 115ms/epoch - 2ms/step
# Epoch 4/100
# 54/54 - 0s - loss: 0.0020 - 100ms/epoch - 2ms/step
# Epoch 5/100
# 54/54 - 0s - loss: 0.0020 - 102ms/epoch - 2ms/step
# Epoch 6/100
# 54/54 - 0s - loss: 0.0018 - 106ms/epoch - 2ms/step
# Epoch 7/100
# 54/54 - 0s - loss: 0.0018 - 105ms/epoch - 2ms/step
# Epoch 8/100
# 54/54 - 0s - loss: 0.0016 - 109ms/epoch - 2ms/step
# Epoch 9/100
# 54/54 - 0s - loss: 0.0014 - 92ms/epoch - 2ms/step
# Epoch 10/100
# 54/54 - 0s - loss: 0.0015 - 121ms/epoch - 2ms/step
# Epoch 11/100
# 54/54 - 0s - loss: 0.0013 - 100ms/epoch - 2ms/step
# Epoch 12/100
# 54/54 - 0s - loss: 0.0012 - 100ms/epoch - 2ms/step
# Epoch 13/100
# 54/54 - 0s - loss: 0.0012 - 109ms/epoch - 2ms/step
# Epoch 14/100
# 54/54 - 0s - loss: 0.0012 - 103ms/epoch - 2ms/step
# Epoch 15/100
# 54/54 - 0s - loss: 0.0012 - 110ms/epoch - 2ms/step
# Epoch 16/100
# 54/54 - 0s - loss: 0.0011 - 109ms/epoch - 2ms/step
# Epoch 17/100
# 54/54 - 0s - loss: 0.0011 - 113ms/epoch - 2ms/step
# Epoch 18/100
# 54/54 - 0s - loss: 0.0011 - 99ms/epoch - 2ms/step
# Epoch 19/100
# 54/54 - 0s - loss: 0.0011 - 102ms/epoch - 2ms/step
# Epoch 20/100
# 54/54 - 0s - loss: 0.0010 - 113ms/epoch - 2ms/step
# Epoch 21/100
# 54/54 - 0s - loss: 0.0011 - 102ms/epoch - 2ms/step
# Epoch 22/100
# 54/54 - 0s - loss: 8.6508e-04 - 111ms/epoch - 2ms/step
# Epoch 23/100
# 54/54 - 0s - loss: 9.2531e-04 - 105ms/epoch - 2ms/step
# Epoch 24/100
# 54/54 - 0s - loss: 9.4307e-04 - 101ms/epoch - 2ms/step
# Epoch 25/100
# 54/54 - 0s - loss: 8.9543e-04 - 100ms/epoch - 2ms/step
# Epoch 26/100
# 54/54 - 0s - loss: 8.9993e-04 - 117ms/epoch - 2ms/step
# Epoch 27/100
# 54/54 - 0s - loss: 8.8647e-04 - 112ms/epoch - 2ms/step
# Epoch 28/100
# 54/54 - 0s - loss: 8.5421e-04 - 104ms/epoch - 2ms/step
# Epoch 29/100
# 54/54 - 0s - loss: 8.1874e-04 - 100ms/epoch - 2ms/step
# Epoch 30/100
# 54/54 - 0s - loss: 9.4988e-04 - 111ms/epoch - 2ms/step
# Epoch 31/100
# 54/54 - 0s - loss: 8.2279e-04 - 108ms/epoch - 2ms/step
# Epoch 32/100
# 54/54 - 0s - loss: 8.1359e-04 - 115ms/epoch - 2ms/step
# Epoch 33/100
# 54/54 - 0s - loss: 8.0815e-04 - 100ms/epoch - 2ms/step
# Epoch 34/100
# 54/54 - 0s - loss: 7.6724e-04 - 102ms/epoch - 2ms/step
# Epoch 35/100
# 54/54 - 0s - loss: 8.2780e-04 - 115ms/epoch - 2ms/step
# Epoch 36/100
# 54/54 - 0s - loss: 6.9058e-04 - 101ms/epoch - 2ms/step
# Epoch 37/100
# 54/54 - 0s - loss: 7.0962e-04 - 115ms/epoch - 2ms/step
# Epoch 38/100
# 54/54 - 0s - loss: 7.7645e-04 - 102ms/epoch - 2ms/step
# Epoch 39/100
# 54/54 - 0s - loss: 7.6415e-04 - 98ms/epoch - 2ms/step
# Epoch 40/100
# 54/54 - 0s - loss: 6.8102e-04 - 101ms/epoch - 2ms/step
# Epoch 41/100
# 54/54 - 0s - loss: 7.7879e-04 - 103ms/epoch - 2ms/step
# Epoch 42/100
# 54/54 - 0s - loss: 6.1155e-04 - 110ms/epoch - 2ms/step
# Epoch 43/100
# 54/54 - 0s - loss: 6.4060e-04 - 106ms/epoch - 2ms/step
# Epoch 44/100
# 54/54 - 0s - loss: 7.2834e-04 - 99ms/epoch - 2ms/step
# Epoch 45/100
# 54/54 - 0s - loss: 7.0309e-04 - 118ms/epoch - 2ms/step
# Epoch 46/100
# 54/54 - 0s - loss: 7.2708e-04 - 133ms/epoch - 2ms/step
# Epoch 47/100
# 54/54 - 0s - loss: 7.2329e-04 - 112ms/epoch - 2ms/step
# Epoch 48/100
# 54/54 - 0s - loss: 6.5536e-04 - 100ms/epoch - 2ms/step
# Epoch 49/100
# 54/54 - 0s - loss: 6.6727e-04 - 116ms/epoch - 2ms/step
# Epoch 50/100
# 54/54 - 0s - loss: 6.2936e-04 - 100ms/epoch - 2ms/step
# Epoch 51/100
# 54/54 - 0s - loss: 6.7783e-04 - 117ms/epoch - 2ms/step
# Epoch 52/100
# 54/54 - 0s - loss: 6.1303e-04 - 100ms/epoch - 2ms/step
# Epoch 53/100
# 54/54 - 0s - loss: 6.4747e-04 - 115ms/epoch - 2ms/step
# Epoch 54/100
# 54/54 - 0s - loss: 6.3467e-04 - 100ms/epoch - 2ms/step
# Epoch 55/100
# 54/54 - 0s - loss: 6.6683e-04 - 115ms/epoch - 2ms/step
# Epoch 56/100
# 54/54 - 0s - loss: 6.0785e-04 - 103ms/epoch - 2ms/step
# Epoch 57/100
# 54/54 - 0s - loss: 6.2059e-04 - 101ms/epoch - 2ms/step
# Epoch 58/100
# 54/54 - 0s - loss: 6.1934e-04 - 98ms/epoch - 2ms/step
# Epoch 59/100
# 54/54 - 0s - loss: 6.2784e-04 - 119ms/epoch - 2ms/step
# Epoch 60/100
# 54/54 - 0s - loss: 6.6220e-04 - 99ms/epoch - 2ms/step
# Epoch 61/100
# 54/54 - 0s - loss: 5.7635e-04 - 99ms/epoch - 2ms/step
# Epoch 62/100
# 54/54 - 0s - loss: 6.0419e-04 - 117ms/epoch - 2ms/step
# Epoch 63/100
# 54/54 - 0s - loss: 5.8642e-04 - 100ms/epoch - 2ms/step
# Epoch 64/100
# 54/54 - 0s - loss: 5.7471e-04 - 98ms/epoch - 2ms/step
# Epoch 65/100
# 54/54 - 0s - loss: 5.4710e-04 - 118ms/epoch - 2ms/step
# Epoch 66/100
# 54/54 - 0s - loss: 5.9863e-04 - 103ms/epoch - 2ms/step
# Epoch 67/100
# 54/54 - 0s - loss: 5.7402e-04 - 113ms/epoch - 2ms/step
# Epoch 68/100
# 54/54 - 0s - loss: 5.6237e-04 - 102ms/epoch - 2ms/step
# Epoch 69/100
# 54/54 - 0s - loss: 6.0515e-04 - 132ms/epoch - 2ms/step
# Epoch 70/100
# 54/54 - 0s - loss: 5.9133e-04 - 138ms/epoch - 3ms/step
# Epoch 71/100
# 54/54 - 0s - loss: 5.3366e-04 - 131ms/epoch - 2ms/step
# Epoch 72/100
# 54/54 - 0s - loss: 5.0895e-04 - 99ms/epoch - 2ms/step
# Epoch 73/100
# 54/54 - 0s - loss: 5.2636e-04 - 109ms/epoch - 2ms/step
# Epoch 74/100
# 54/54 - 0s - loss: 5.7490e-04 - 102ms/epoch - 2ms/step
# Epoch 75/100
# 54/54 - 0s - loss: 5.5707e-04 - 101ms/epoch - 2ms/step
# Epoch 76/100
# 54/54 - 0s - loss: 5.5643e-04 - 117ms/epoch - 2ms/step
# Epoch 77/100
# 54/54 - 0s - loss: 5.6018e-04 - 95ms/epoch - 2ms/step
# Epoch 78/100
# 54/54 - 0s - loss: 6.0694e-04 - 123ms/epoch - 2ms/step
# Epoch 79/100
# 54/54 - 0s - loss: 5.2304e-04 - 97ms/epoch - 2ms/step
# Epoch 80/100
# 54/54 - 0s - loss: 5.7650e-04 - 99ms/epoch - 2ms/step
# Epoch 81/100
# 54/54 - 0s - loss: 5.6110e-04 - 118ms/epoch - 2ms/step
# Epoch 82/100
# 54/54 - 0s - loss: 5.5128e-04 - 98ms/epoch - 2ms/step
# Epoch 83/100
# 54/54 - 0s - loss: 4.8740e-04 - 132ms/epoch - 2ms/step
# Epoch 84/100
# 54/54 - 0s - loss: 5.6257e-04 - 126ms/epoch - 2ms/step
# Epoch 85/100
# 54/54 - 0s - loss: 5.3165e-04 - 124ms/epoch - 2ms/step
# Epoch 86/100
# 54/54 - 0s - loss: 5.7155e-04 - 117ms/epoch - 2ms/step
# Epoch 87/100
# 54/54 - 0s - loss: 5.2013e-04 - 119ms/epoch - 2ms/step
# Epoch 88/100
# 54/54 - 0s - loss: 5.2717e-04 - 117ms/epoch - 2ms/step
# Epoch 89/100
# 54/54 - 0s - loss: 5.0377e-04 - 116ms/epoch - 2ms/step
# Epoch 90/100
# 54/54 - 0s - loss: 4.9476e-04 - 127ms/epoch - 2ms/step
# Epoch 91/100
# 54/54 - 0s - loss: 5.3264e-04 - 120ms/epoch - 2ms/step
# Epoch 92/100
# 54/54 - 0s - loss: 5.1941e-04 - 134ms/epoch - 2ms/step
# Epoch 93/100
# 54/54 - 0s - loss: 5.2272e-04 - 116ms/epoch - 2ms/step
# Epoch 94/100
# 54/54 - 0s - loss: 5.1322e-04 - 110ms/epoch - 2ms/step
# Epoch 95/100
# 54/54 - 0s - loss: 5.4719e-04 - 95ms/epoch - 2ms/step
# Epoch 96/100
# 54/54 - 0s - loss: 5.3385e-04 - 131ms/epoch - 2ms/step
# Epoch 97/100
# 54/54 - 0s - loss: 5.7086e-04 - 133ms/epoch - 2ms/step
# Epoch 98/100
# 54/54 - 0s - loss: 4.9889e-04 - 109ms/epoch - 2ms/step
# Epoch 99/100
# 54/54 - 0s - loss: 5.4983e-04 - 101ms/epoch - 2ms/step
# Epoch 100/100
# 54/54 - 0s - loss: 5.1782e-04 - 115ms/epoch - 2ms/step
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_24 (LSTM)              (None, 1, 50)             11400
#
#  dropout_24 (Dropout)        (None, 1, 50)             0
#
#  lstm_25 (LSTM)              (None, 50)                20200
#
#  dropout_25 (Dropout)        (None, 50)                0
#
#  dense_12 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 31,651
# Trainable params: 31,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make predictions
train_pred = model.predict(X_train_reshape)
test_pred = model.predict(X_test_reshape)

# unable to inverse transform values due to original output having 6 features

# calculate RMSE
train_score = np.sqrt(mean_squared_error(y_train, train_pred))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test, test_pred))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 108/108 [==============================] - 1s 783us/step
# 27/27 [==============================] - 0s 883us/step
# Train score: 0.01 RMSE
# Test score: 0.46 RMSE

# %%
dataset_trans = mm.transform(dataset)

# %%
# shift train predictions for plotting
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

# shift test predictions for plotting
test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[len(train_pred) + (look_back*2)+1:len(dataset)-1, :] = test_pred

# plot baseline and predictions
plt.plot(dataset_trans[:,0])
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()
