# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.layers import GRU
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-08-19    49.813290    51.835709    47.800831    49.982655    49.982655
# 2004-08-20    50.316402    54.336334    50.062355    53.952770    53.952770
# 2004-08-23    55.168217    56.528118    54.321388    54.495735    54.495735
# 2004-08-24    55.412300    55.591629    51.591621    52.239197    52.239197
# 2004-08-25    52.284027    53.798351    51.746044    52.802086    52.802086
# ...                 ...          ...          ...          ...          ...
# 2021-10-04  2713.989990  2714.000000  2623.330078  2675.300049  2675.300049
# 2021-10-05  2680.000000  2747.239990  2680.000000  2723.540039  2723.540039
# 2021-10-06  2692.510010  2757.040039  2689.729980  2747.080078  2747.080078
# 2021-10-07  2777.260010  2803.089111  2771.260010  2783.709961  2783.709961
# 2021-10-08  2798.120117  2806.340088  2788.586914  2801.120117  2801.120117
#
#               Volume
# Date
# 2004-08-19  44871361
# 2004-08-20  22942874
# 2004-08-23  18342897
# 2004-08-24  15319808
# 2004-08-25   9232276
# ...              ...
# 2021-10-04   1576500
# 2021-10-05   1206300
# 2021-10-06    988200
# 2021-10-07    912500
# 2021-10-08    946200
#
# [4316 rows x 6 columns]

# %%
df.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999920  0.999903  0.999827   0.999827 -0.476751
# High       0.999920  1.000000  0.999878  0.999911   0.999911 -0.475723
# Low        0.999903  0.999878  1.000000  0.999924   0.999924 -0.477952
# Close      0.999827  0.999911  0.999924  1.000000   1.000000 -0.476871
# Adj Close  0.999827  0.999911  0.999924  1.000000   1.000000 -0.476871
# Volume    -0.476751 -0.475723 -0.477952 -0.476871  -0.476871  1.000000

# %%
dataset = df['Open']
dataset = dataset.values.astype('float32')
tf.random.set_seed(10)

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [],[]
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
dataset = dataset.reshape(-1,1)
mm = MinMaxScaler(feature_range=(0,1))

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# %%
look_back = 1
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)
y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
X_train = mm.fit_transform(X_train)
y_train = mm.fit_transform(y_train)

X_test = mm.transform(X_test)
y_test = mm.transform(y_test)

# %%
# reshape input to be (samples, timesteps, features)
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(GRU(50, input_shape=(1, look_back), return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(50))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train, y_train, epochs=100, batch_size = 64, verbose = 2)
# Out:
# Epoch 1/100
# 54/54 - 3s - loss: 0.0428 - 3s/epoch - 55ms/step
# Epoch 2/100
# 54/54 - 0s - loss: 0.0047 - 96ms/epoch - 2ms/step
# Epoch 3/100
# 54/54 - 0s - loss: 0.0019 - 112ms/epoch - 2ms/step
# Epoch 4/100
# 54/54 - 0s - loss: 0.0017 - 120ms/epoch - 2ms/step
# Epoch 5/100
# 54/54 - 0s - loss: 0.0017 - 108ms/epoch - 2ms/step
# Epoch 6/100
# 54/54 - 0s - loss: 0.0015 - 110ms/epoch - 2ms/step
# Epoch 7/100
# 54/54 - 0s - loss: 0.0015 - 100ms/epoch - 2ms/step
# Epoch 8/100
# 54/54 - 0s - loss: 0.0013 - 99ms/epoch - 2ms/step
# Epoch 9/100
# 54/54 - 0s - loss: 0.0012 - 100ms/epoch - 2ms/step
# Epoch 10/100
# 54/54 - 0s - loss: 0.0012 - 102ms/epoch - 2ms/step
# Epoch 11/100
# 54/54 - 0s - loss: 0.0011 - 99ms/epoch - 2ms/step
# Epoch 12/100
# 54/54 - 0s - loss: 0.0011 - 112ms/epoch - 2ms/step
# Epoch 13/100
# 54/54 - 0s - loss: 0.0011 - 101ms/epoch - 2ms/step
# Epoch 14/100
# 54/54 - 0s - loss: 0.0011 - 101ms/epoch - 2ms/step
# Epoch 15/100
# 54/54 - 0s - loss: 0.0011 - 99ms/epoch - 2ms/step
# Epoch 16/100
# 54/54 - 0s - loss: 0.0011 - 97ms/epoch - 2ms/step
# Epoch 17/100
# 54/54 - 0s - loss: 0.0010 - 98ms/epoch - 2ms/step
# Epoch 18/100
# 54/54 - 0s - loss: 0.0011 - 102ms/epoch - 2ms/step
# Epoch 19/100
# 54/54 - 0s - loss: 9.3799e-04 - 102ms/epoch - 2ms/step
# Epoch 20/100
# 54/54 - 0s - loss: 9.0871e-04 - 98ms/epoch - 2ms/step
# Epoch 21/100
# 54/54 - 0s - loss: 0.0010 - 99ms/epoch - 2ms/step
# Epoch 22/100
# 54/54 - 0s - loss: 8.5730e-04 - 99ms/epoch - 2ms/step
# Epoch 23/100
# 54/54 - 0s - loss: 8.8475e-04 - 100ms/epoch - 2ms/step
# Epoch 24/100
# 54/54 - 0s - loss: 8.9621e-04 - 102ms/epoch - 2ms/step
# Epoch 25/100
# 54/54 - 0s - loss: 8.6743e-04 - 99ms/epoch - 2ms/step
# Epoch 26/100
# 54/54 - 0s - loss: 8.6657e-04 - 100ms/epoch - 2ms/step
# Epoch 27/100
# 54/54 - 0s - loss: 8.9453e-04 - 101ms/epoch - 2ms/step
# Epoch 28/100
# 54/54 - 0s - loss: 8.3602e-04 - 98ms/epoch - 2ms/step
# Epoch 29/100
# 54/54 - 0s - loss: 8.3724e-04 - 101ms/epoch - 2ms/step
# Epoch 30/100
# 54/54 - 0s - loss: 9.5044e-04 - 98ms/epoch - 2ms/step
# Epoch 31/100
# 54/54 - 0s - loss: 8.4092e-04 - 98ms/epoch - 2ms/step
# Epoch 32/100
# 54/54 - 0s - loss: 8.6847e-04 - 98ms/epoch - 2ms/step
# Epoch 33/100
# 54/54 - 0s - loss: 8.7183e-04 - 99ms/epoch - 2ms/step
# Epoch 34/100
# 54/54 - 0s - loss: 7.8305e-04 - 102ms/epoch - 2ms/step
# Epoch 35/100
# 54/54 - 0s - loss: 8.2240e-04 - 99ms/epoch - 2ms/step
# Epoch 36/100
# 54/54 - 0s - loss: 7.4687e-04 - 101ms/epoch - 2ms/step
# Epoch 37/100
# 54/54 - 0s - loss: 7.3921e-04 - 98ms/epoch - 2ms/step
# Epoch 38/100
# 54/54 - 0s - loss: 7.9762e-04 - 99ms/epoch - 2ms/step
# Epoch 39/100
# 54/54 - 0s - loss: 8.1488e-04 - 101ms/epoch - 2ms/step
# Epoch 40/100
# 54/54 - 0s - loss: 7.2854e-04 - 99ms/epoch - 2ms/step
# Epoch 41/100
# 54/54 - 0s - loss: 7.7454e-04 - 112ms/epoch - 2ms/step
# Epoch 42/100
# 54/54 - 0s - loss: 6.7061e-04 - 101ms/epoch - 2ms/step
# Epoch 43/100
# 54/54 - 0s - loss: 7.0307e-04 - 98ms/epoch - 2ms/step
# Epoch 44/100
# 54/54 - 0s - loss: 7.6782e-04 - 102ms/epoch - 2ms/step
# Epoch 45/100
# 54/54 - 0s - loss: 7.5054e-04 - 99ms/epoch - 2ms/step
# Epoch 46/100
# 54/54 - 0s - loss: 7.4764e-04 - 101ms/epoch - 2ms/step
# Epoch 47/100
# 54/54 - 0s - loss: 7.2318e-04 - 102ms/epoch - 2ms/step
# Epoch 48/100
# 54/54 - 0s - loss: 7.0779e-04 - 103ms/epoch - 2ms/step
# Epoch 49/100
# 54/54 - 0s - loss: 7.1100e-04 - 102ms/epoch - 2ms/step
# Epoch 50/100
# 54/54 - 0s - loss: 6.5910e-04 - 101ms/epoch - 2ms/step
# Epoch 51/100
# 54/54 - 0s - loss: 7.2271e-04 - 100ms/epoch - 2ms/step
# Epoch 52/100
# 54/54 - 0s - loss: 6.8697e-04 - 101ms/epoch - 2ms/step
# Epoch 53/100
# 54/54 - 0s - loss: 7.3241e-04 - 98ms/epoch - 2ms/step
# Epoch 54/100
# 54/54 - 0s - loss: 6.9938e-04 - 106ms/epoch - 2ms/step
# Epoch 55/100
# 54/54 - 0s - loss: 7.1873e-04 - 98ms/epoch - 2ms/step
# Epoch 56/100
# 54/54 - 0s - loss: 6.8605e-04 - 96ms/epoch - 2ms/step
# Epoch 57/100
# 54/54 - 0s - loss: 6.8494e-04 - 96ms/epoch - 2ms/step
# Epoch 58/100
# 54/54 - 0s - loss: 6.7999e-04 - 98ms/epoch - 2ms/step
# Epoch 59/100
# 54/54 - 0s - loss: 7.0460e-04 - 99ms/epoch - 2ms/step
# Epoch 60/100
# 54/54 - 0s - loss: 7.1732e-04 - 97ms/epoch - 2ms/step
# Epoch 61/100
# 54/54 - 0s - loss: 6.0850e-04 - 97ms/epoch - 2ms/step
# Epoch 62/100
# 54/54 - 0s - loss: 6.6193e-04 - 96ms/epoch - 2ms/step
# Epoch 63/100
# 54/54 - 0s - loss: 6.5987e-04 - 97ms/epoch - 2ms/step
# Epoch 64/100
# 54/54 - 0s - loss: 6.5018e-04 - 101ms/epoch - 2ms/step
# Epoch 65/100
# 54/54 - 0s - loss: 5.9077e-04 - 96ms/epoch - 2ms/step
# Epoch 66/100
# 54/54 - 0s - loss: 6.5484e-04 - 100ms/epoch - 2ms/step
# Epoch 67/100
# 54/54 - 0s - loss: 6.3285e-04 - 96ms/epoch - 2ms/step
# Epoch 68/100
# 54/54 - 0s - loss: 6.1967e-04 - 97ms/epoch - 2ms/step
# Epoch 69/100
# 54/54 - 0s - loss: 6.3428e-04 - 100ms/epoch - 2ms/step
# Epoch 70/100
# 54/54 - 0s - loss: 6.4375e-04 - 98ms/epoch - 2ms/step
# Epoch 71/100
# 54/54 - 0s - loss: 5.8964e-04 - 97ms/epoch - 2ms/step
# Epoch 72/100
# 54/54 - 0s - loss: 6.0087e-04 - 97ms/epoch - 2ms/step
# Epoch 73/100
# 54/54 - 0s - loss: 6.2166e-04 - 99ms/epoch - 2ms/step
# Epoch 74/100
# 54/54 - 0s - loss: 6.2190e-04 - 99ms/epoch - 2ms/step
# Epoch 75/100
# 54/54 - 0s - loss: 6.0900e-04 - 119ms/epoch - 2ms/step
# Epoch 76/100
# 54/54 - 0s - loss: 6.4669e-04 - 119ms/epoch - 2ms/step
# Epoch 77/100
# 54/54 - 0s - loss: 6.1824e-04 - 108ms/epoch - 2ms/step
# Epoch 78/100
# 54/54 - 0s - loss: 6.9313e-04 - 106ms/epoch - 2ms/step
# Epoch 79/100
# 54/54 - 0s - loss: 5.9030e-04 - 105ms/epoch - 2ms/step
# Epoch 80/100
# 54/54 - 0s - loss: 6.4202e-04 - 98ms/epoch - 2ms/step
# Epoch 81/100
# 54/54 - 0s - loss: 6.2498e-04 - 97ms/epoch - 2ms/step
# Epoch 82/100
# 54/54 - 0s - loss: 6.0965e-04 - 97ms/epoch - 2ms/step
# Epoch 83/100
# 54/54 - 0s - loss: 5.6054e-04 - 118ms/epoch - 2ms/step
# Epoch 84/100
# 54/54 - 0s - loss: 6.2828e-04 - 103ms/epoch - 2ms/step
# Epoch 85/100
# 54/54 - 0s - loss: 5.8539e-04 - 92ms/epoch - 2ms/step
# Epoch 86/100
# 54/54 - 0s - loss: 6.3478e-04 - 98ms/epoch - 2ms/step
# Epoch 87/100
# 54/54 - 0s - loss: 5.8871e-04 - 98ms/epoch - 2ms/step
# Epoch 88/100
# 54/54 - 0s - loss: 6.0314e-04 - 97ms/epoch - 2ms/step
# Epoch 89/100
# 54/54 - 0s - loss: 5.8104e-04 - 99ms/epoch - 2ms/step
# Epoch 90/100
# 54/54 - 0s - loss: 5.5366e-04 - 97ms/epoch - 2ms/step
# Epoch 91/100
# 54/54 - 0s - loss: 6.1214e-04 - 98ms/epoch - 2ms/step
# Epoch 92/100
# 54/54 - 0s - loss: 5.9926e-04 - 96ms/epoch - 2ms/step
# Epoch 93/100
# 54/54 - 0s - loss: 5.9575e-04 - 97ms/epoch - 2ms/step
# Epoch 94/100
# 54/54 - 0s - loss: 5.8371e-04 - 100ms/epoch - 2ms/step
# Epoch 95/100
# 54/54 - 0s - loss: 5.9634e-04 - 96ms/epoch - 2ms/step
# Epoch 96/100
# 54/54 - 0s - loss: 5.9974e-04 - 96ms/epoch - 2ms/step
# Epoch 97/100
# 54/54 - 0s - loss: 6.2430e-04 - 112ms/epoch - 2ms/step
# Epoch 98/100
# 54/54 - 0s - loss: 6.1007e-04 - 98ms/epoch - 2ms/step
# Epoch 99/100
# 54/54 - 0s - loss: 5.9726e-04 - 96ms/epoch - 2ms/step
# Epoch 100/100
# 54/54 - 0s - loss: 6.1532e-04 - 97ms/epoch - 2ms/step

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred = mm.inverse_transform(train_pred)
y_train = mm.inverse_transform(y_train)

test_pred = mm.inverse_transform(test_pred)
y_test = mm.inverse_transform(y_test)

train_score = np.sqrt(mean_squared_error(y_train[:,0], train_pred[:,0]))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test[:,0], test_pred[:,0]))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 108/108 [==============================] - 1s 772us/step
# 27/27 [==============================] - 0s 817us/step
# Train score: 7.66 RMSE
# Test score: 127.09 RMSE

# %%
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[len(train_pred) + (look_back*2):len(dataset)-2, :] = test_pred

plt.plot(dataset)
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()

# %% [markdown]
# ### Increasing timesteps

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
dataset = df['Open']
dataset = dataset.values.astype('float32')
tf.random.set_seed(10)

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [],[]
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
dataset = dataset.reshape(-1,1)
mm = MinMaxScaler(feature_range=(0,1))

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# %%
train = mm.fit_transform(train)
test = mm.transform(test)

# %%
look_back = 3
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
X_train.shape
# Out:
# (3448, 3)

# %%
y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(GRU(50, input_shape=(1, look_back), return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(50))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train, y_train, epochs=100, batch_size = 64, verbose = 2)
# Out:
# Epoch 1/100
# 54/54 - 3s - loss: 0.0370 - 3s/epoch - 53ms/step
# Epoch 2/100
# 54/54 - 0s - loss: 0.0033 - 98ms/epoch - 2ms/step
# Epoch 3/100
# 54/54 - 0s - loss: 0.0022 - 101ms/epoch - 2ms/step
# Epoch 4/100
# 54/54 - 0s - loss: 0.0020 - 100ms/epoch - 2ms/step
# Epoch 5/100
# 54/54 - 0s - loss: 0.0021 - 100ms/epoch - 2ms/step
# Epoch 6/100
# 54/54 - 0s - loss: 0.0018 - 105ms/epoch - 2ms/step
# Epoch 7/100
# 54/54 - 0s - loss: 0.0015 - 99ms/epoch - 2ms/step
# Epoch 8/100
# 54/54 - 0s - loss: 0.0015 - 101ms/epoch - 2ms/step
# Epoch 9/100
# 54/54 - 0s - loss: 0.0015 - 100ms/epoch - 2ms/step
# Epoch 10/100
# 54/54 - 0s - loss: 0.0014 - 101ms/epoch - 2ms/step
# Epoch 11/100
# 54/54 - 0s - loss: 0.0013 - 103ms/epoch - 2ms/step
# Epoch 12/100
# 54/54 - 0s - loss: 0.0013 - 100ms/epoch - 2ms/step
# Epoch 13/100
# 54/54 - 0s - loss: 0.0012 - 101ms/epoch - 2ms/step
# Epoch 14/100
# 54/54 - 0s - loss: 0.0012 - 100ms/epoch - 2ms/step
# Epoch 15/100
# 54/54 - 0s - loss: 0.0011 - 99ms/epoch - 2ms/step
# Epoch 16/100
# 54/54 - 0s - loss: 0.0012 - 102ms/epoch - 2ms/step
# Epoch 17/100
# 54/54 - 0s - loss: 0.0011 - 98ms/epoch - 2ms/step
# Epoch 18/100
# 54/54 - 0s - loss: 9.7658e-04 - 99ms/epoch - 2ms/step
# Epoch 19/100
# 54/54 - 0s - loss: 0.0010 - 101ms/epoch - 2ms/step
# Epoch 20/100
# 54/54 - 0s - loss: 9.6554e-04 - 99ms/epoch - 2ms/step
# Epoch 21/100
# 54/54 - 0s - loss: 9.9708e-04 - 102ms/epoch - 2ms/step
# Epoch 22/100
# 54/54 - 0s - loss: 9.4562e-04 - 99ms/epoch - 2ms/step
# Epoch 23/100
# 54/54 - 0s - loss: 0.0010 - 99ms/epoch - 2ms/step
# Epoch 24/100
# 54/54 - 0s - loss: 9.2080e-04 - 101ms/epoch - 2ms/step
# Epoch 25/100
# 54/54 - 0s - loss: 9.8804e-04 - 103ms/epoch - 2ms/step
# Epoch 26/100
# 54/54 - 0s - loss: 9.4517e-04 - 103ms/epoch - 2ms/step
# Epoch 27/100
# 54/54 - 0s - loss: 8.6708e-04 - 100ms/epoch - 2ms/step
# Epoch 28/100
# 54/54 - 0s - loss: 8.5916e-04 - 101ms/epoch - 2ms/step
# Epoch 29/100
# 54/54 - 0s - loss: 9.7321e-04 - 99ms/epoch - 2ms/step
# Epoch 30/100
# 54/54 - 0s - loss: 8.6483e-04 - 101ms/epoch - 2ms/step
# Epoch 31/100
# 54/54 - 0s - loss: 8.4300e-04 - 102ms/epoch - 2ms/step
# Epoch 32/100
# 54/54 - 0s - loss: 8.7231e-04 - 98ms/epoch - 2ms/step
# Epoch 33/100
# 54/54 - 0s - loss: 8.6635e-04 - 102ms/epoch - 2ms/step
# Epoch 34/100
# 54/54 - 0s - loss: 8.0921e-04 - 95ms/epoch - 2ms/step
# Epoch 35/100
# 54/54 - 0s - loss: 8.0296e-04 - 99ms/epoch - 2ms/step
# Epoch 36/100
# 54/54 - 0s - loss: 8.3498e-04 - 102ms/epoch - 2ms/step
# Epoch 37/100
# 54/54 - 0s - loss: 8.1102e-04 - 100ms/epoch - 2ms/step
# Epoch 38/100
# 54/54 - 0s - loss: 8.1966e-04 - 101ms/epoch - 2ms/step
# Epoch 39/100
# 54/54 - 0s - loss: 8.3828e-04 - 100ms/epoch - 2ms/step
# Epoch 40/100
# 54/54 - 0s - loss: 8.0734e-04 - 99ms/epoch - 2ms/step
# Epoch 41/100
# 54/54 - 0s - loss: 8.6108e-04 - 104ms/epoch - 2ms/step
# Epoch 42/100
# 54/54 - 0s - loss: 7.8043e-04 - 136ms/epoch - 3ms/step
# Epoch 43/100
# 54/54 - 0s - loss: 7.6606e-04 - 100ms/epoch - 2ms/step
# Epoch 44/100
# 54/54 - 0s - loss: 7.1099e-04 - 101ms/epoch - 2ms/step
# Epoch 45/100
# 54/54 - 0s - loss: 7.2281e-04 - 102ms/epoch - 2ms/step
# Epoch 46/100
# 54/54 - 0s - loss: 8.1468e-04 - 100ms/epoch - 2ms/step
# Epoch 47/100
# 54/54 - 0s - loss: 7.1210e-04 - 101ms/epoch - 2ms/step
# Epoch 48/100
# 54/54 - 0s - loss: 7.4734e-04 - 99ms/epoch - 2ms/step
# Epoch 49/100
# 54/54 - 0s - loss: 7.2481e-04 - 99ms/epoch - 2ms/step
# Epoch 50/100
# 54/54 - 0s - loss: 7.7953e-04 - 102ms/epoch - 2ms/step
# Epoch 51/100
# 54/54 - 0s - loss: 7.2060e-04 - 102ms/epoch - 2ms/step
# Epoch 52/100
# 54/54 - 0s - loss: 6.4334e-04 - 105ms/epoch - 2ms/step
# Epoch 53/100
# 54/54 - 0s - loss: 6.8938e-04 - 97ms/epoch - 2ms/step
# Epoch 54/100
# 54/54 - 0s - loss: 7.3854e-04 - 103ms/epoch - 2ms/step
# Epoch 55/100
# 54/54 - 0s - loss: 7.5278e-04 - 99ms/epoch - 2ms/step
# Epoch 56/100
# 54/54 - 0s - loss: 6.7941e-04 - 98ms/epoch - 2ms/step
# Epoch 57/100
# 54/54 - 0s - loss: 6.9982e-04 - 97ms/epoch - 2ms/step
# Epoch 58/100
# 54/54 - 0s - loss: 6.8641e-04 - 98ms/epoch - 2ms/step
# Epoch 59/100
# 54/54 - 0s - loss: 6.3245e-04 - 98ms/epoch - 2ms/step
# Epoch 60/100
# 54/54 - 0s - loss: 6.8675e-04 - 101ms/epoch - 2ms/step
# Epoch 61/100
# 54/54 - 0s - loss: 7.3936e-04 - 98ms/epoch - 2ms/step
# Epoch 62/100
# 54/54 - 0s - loss: 6.4742e-04 - 101ms/epoch - 2ms/step
# Epoch 63/100
# 54/54 - 0s - loss: 6.9075e-04 - 98ms/epoch - 2ms/step
# Epoch 64/100
# 54/54 - 0s - loss: 6.5755e-04 - 101ms/epoch - 2ms/step
# Epoch 65/100
# 54/54 - 0s - loss: 6.6223e-04 - 104ms/epoch - 2ms/step
# Epoch 66/100
# 54/54 - 0s - loss: 6.5370e-04 - 99ms/epoch - 2ms/step
# Epoch 67/100
# 54/54 - 0s - loss: 6.1880e-04 - 94ms/epoch - 2ms/step
# Epoch 68/100
# 54/54 - 0s - loss: 6.6865e-04 - 97ms/epoch - 2ms/step
# Epoch 69/100
# 54/54 - 0s - loss: 6.4628e-04 - 97ms/epoch - 2ms/step
# Epoch 70/100
# 54/54 - 0s - loss: 6.3014e-04 - 102ms/epoch - 2ms/step
# Epoch 71/100
# 54/54 - 0s - loss: 6.3276e-04 - 97ms/epoch - 2ms/step
# Epoch 72/100
# 54/54 - 0s - loss: 6.2808e-04 - 97ms/epoch - 2ms/step
# Epoch 73/100
# 54/54 - 0s - loss: 6.1403e-04 - 97ms/epoch - 2ms/step
# Epoch 74/100
# 54/54 - 0s - loss: 6.3792e-04 - 98ms/epoch - 2ms/step
# Epoch 75/100
# 54/54 - 0s - loss: 6.2310e-04 - 98ms/epoch - 2ms/step
# Epoch 76/100
# 54/54 - 0s - loss: 6.2036e-04 - 98ms/epoch - 2ms/step
# Epoch 77/100
# 54/54 - 0s - loss: 6.8767e-04 - 98ms/epoch - 2ms/step
# Epoch 78/100
# 54/54 - 0s - loss: 5.9713e-04 - 111ms/epoch - 2ms/step
# Epoch 79/100
# 54/54 - 0s - loss: 6.0058e-04 - 98ms/epoch - 2ms/step
# Epoch 80/100
# 54/54 - 0s - loss: 5.3871e-04 - 99ms/epoch - 2ms/step
# Epoch 81/100
# 54/54 - 0s - loss: 6.0502e-04 - 99ms/epoch - 2ms/step
# Epoch 82/100
# 54/54 - 0s - loss: 6.1279e-04 - 104ms/epoch - 2ms/step
# Epoch 83/100
# 54/54 - 0s - loss: 6.1263e-04 - 99ms/epoch - 2ms/step
# Epoch 84/100
# 54/54 - 0s - loss: 6.0085e-04 - 100ms/epoch - 2ms/step
# Epoch 85/100
# 54/54 - 0s - loss: 6.2139e-04 - 97ms/epoch - 2ms/step
# Epoch 86/100
# 54/54 - 0s - loss: 6.4897e-04 - 99ms/epoch - 2ms/step
# Epoch 87/100
# 54/54 - 0s - loss: 5.7263e-04 - 97ms/epoch - 2ms/step
# Epoch 88/100
# 54/54 - 0s - loss: 6.0144e-04 - 98ms/epoch - 2ms/step
# Epoch 89/100
# 54/54 - 0s - loss: 5.6707e-04 - 98ms/epoch - 2ms/step
# Epoch 90/100
# 54/54 - 0s - loss: 6.1136e-04 - 99ms/epoch - 2ms/step
# Epoch 91/100
# 54/54 - 0s - loss: 6.0582e-04 - 100ms/epoch - 2ms/step
# Epoch 92/100
# 54/54 - 0s - loss: 6.2244e-04 - 99ms/epoch - 2ms/step
# Epoch 93/100
# 54/54 - 0s - loss: 6.4361e-04 - 99ms/epoch - 2ms/step
# Epoch 94/100
# 54/54 - 0s - loss: 5.5533e-04 - 105ms/epoch - 2ms/step
# Epoch 95/100
# 54/54 - 0s - loss: 6.1299e-04 - 98ms/epoch - 2ms/step
# Epoch 96/100
# 54/54 - 0s - loss: 6.1964e-04 - 98ms/epoch - 2ms/step
# Epoch 97/100
# 54/54 - 0s - loss: 6.3250e-04 - 98ms/epoch - 2ms/step
# Epoch 98/100
# 54/54 - 0s - loss: 5.7064e-04 - 98ms/epoch - 2ms/step
# Epoch 99/100
# 54/54 - 0s - loss: 5.6785e-04 - 99ms/epoch - 2ms/step
# Epoch 100/100
# 54/54 - 0s - loss: 6.1863e-04 - 99ms/epoch - 2ms/step

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred = mm.inverse_transform(train_pred)
y_train = mm.inverse_transform(y_train)

test_pred = mm.inverse_transform(test_pred)
y_test = mm.inverse_transform(y_test)

train_score = np.sqrt(mean_squared_error(y_train[:,0], train_pred[:,0]))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test[:,0], test_pred[:,0]))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 108/108 [==============================] - 1s 750us/step
# 27/27 [==============================] - 0s 731us/step
# Train score: 10.20 RMSE
# Test score: 299.94 RMSE

# %%
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[len(train_pred) + (look_back*2):len(dataset)-2, :] = test_pred

plt.plot(dataset)
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()

# %% [markdown]
# ### Multiple features

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
dataset = df.values.astype('float32')
tf.random.set_seed(10)

mm = MinMaxScaler(feature_range=(0,1))

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# %%
train = mm.fit_transform(train)
test = mm.transform(test)

# %%
y_train = train[:,0]
y_test = test[:,0]

# %%
def create_dataset_features (dataset, look_back=1):
    dataX = np.ones(shape=(1, 6))
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), :]
        dataX = np.vstack((dataX, a))
    return np.array(dataX)

# %%
def create_test (dataset, look_back=1):
    dataY = np.ones(shape=(1))
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back)]
        dataY = np.vstack((dataY, a))
    return np.array(dataY)

# %%
look_back = 1
X_train = create_dataset_features(train, look_back)
X_test = create_dataset_features(test, look_back)
y_train = create_test(y_train, look_back)
y_test = create_test(y_test, look_back)

# %%
X_train = np.delete(X_train, 0, 0)
y_train = np.delete(y_train, 0, 0)
X_test = np.delete(X_test, 0, 0)
y_test = np.delete(y_test, 0, 0)

# %%
X_train_reshape = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test_reshape = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(GRU(50, input_shape=(1, 6), return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(50))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train_reshape, y_train, epochs=100, batch_size = 64, verbose = 2)
model.summary()
# Out:
# Epoch 1/100
# 54/54 - 3s - loss: 0.0302 - 3s/epoch - 50ms/step
# Epoch 2/100
# 54/54 - 0s - loss: 0.0030 - 124ms/epoch - 2ms/step
# Epoch 3/100
# 54/54 - 0s - loss: 0.0025 - 101ms/epoch - 2ms/step
# Epoch 4/100
# 54/54 - 0s - loss: 0.0021 - 102ms/epoch - 2ms/step
# Epoch 5/100
# 54/54 - 0s - loss: 0.0022 - 102ms/epoch - 2ms/step
# Epoch 6/100
# 54/54 - 0s - loss: 0.0018 - 98ms/epoch - 2ms/step
# Epoch 7/100
# 54/54 - 0s - loss: 0.0017 - 103ms/epoch - 2ms/step
# Epoch 8/100
# 54/54 - 0s - loss: 0.0015 - 100ms/epoch - 2ms/step
# Epoch 9/100
# 54/54 - 0s - loss: 0.0013 - 99ms/epoch - 2ms/step
# Epoch 10/100
# 54/54 - 0s - loss: 0.0013 - 98ms/epoch - 2ms/step
# Epoch 11/100
# 54/54 - 0s - loss: 0.0012 - 102ms/epoch - 2ms/step
# Epoch 12/100
# 54/54 - 0s - loss: 0.0012 - 99ms/epoch - 2ms/step
# Epoch 13/100
# 54/54 - 0s - loss: 0.0012 - 100ms/epoch - 2ms/step
# Epoch 14/100
# 54/54 - 0s - loss: 0.0012 - 99ms/epoch - 2ms/step
# Epoch 15/100
# 54/54 - 0s - loss: 0.0011 - 98ms/epoch - 2ms/step
# Epoch 16/100
# 54/54 - 0s - loss: 0.0011 - 100ms/epoch - 2ms/step
# Epoch 17/100
# 54/54 - 0s - loss: 0.0010 - 101ms/epoch - 2ms/step
# Epoch 18/100
# 54/54 - 0s - loss: 0.0011 - 98ms/epoch - 2ms/step
# Epoch 19/100
# 54/54 - 0s - loss: 9.9852e-04 - 104ms/epoch - 2ms/step
# Epoch 20/100
# 54/54 - 0s - loss: 9.1457e-04 - 98ms/epoch - 2ms/step
# Epoch 21/100
# 54/54 - 0s - loss: 0.0010 - 103ms/epoch - 2ms/step
# Epoch 22/100
# 54/54 - 0s - loss: 8.2584e-04 - 97ms/epoch - 2ms/step
# Epoch 23/100
# 54/54 - 0s - loss: 8.4474e-04 - 100ms/epoch - 2ms/step
# Epoch 24/100
# 54/54 - 0s - loss: 8.7987e-04 - 100ms/epoch - 2ms/step
# Epoch 25/100
# 54/54 - 0s - loss: 8.5738e-04 - 101ms/epoch - 2ms/step
# Epoch 26/100
# 54/54 - 0s - loss: 8.4074e-04 - 103ms/epoch - 2ms/step
# Epoch 27/100
# 54/54 - 0s - loss: 8.6174e-04 - 99ms/epoch - 2ms/step
# Epoch 28/100
# 54/54 - 0s - loss: 7.9015e-04 - 98ms/epoch - 2ms/step
# Epoch 29/100
# 54/54 - 0s - loss: 7.7862e-04 - 99ms/epoch - 2ms/step
# Epoch 30/100
# 54/54 - 0s - loss: 9.2260e-04 - 100ms/epoch - 2ms/step
# Epoch 31/100
# 54/54 - 0s - loss: 7.9232e-04 - 100ms/epoch - 2ms/step
# Epoch 32/100
# 54/54 - 0s - loss: 8.1542e-04 - 100ms/epoch - 2ms/step
# Epoch 33/100
# 54/54 - 0s - loss: 8.2074e-04 - 101ms/epoch - 2ms/step
# Epoch 34/100
# 54/54 - 0s - loss: 7.4783e-04 - 101ms/epoch - 2ms/step
# Epoch 35/100
# 54/54 - 0s - loss: 8.2462e-04 - 102ms/epoch - 2ms/step
# Epoch 36/100
# 54/54 - 0s - loss: 6.8167e-04 - 102ms/epoch - 2ms/step
# Epoch 37/100
# 54/54 - 0s - loss: 7.0844e-04 - 101ms/epoch - 2ms/step
# Epoch 38/100
# 54/54 - 0s - loss: 7.6300e-04 - 103ms/epoch - 2ms/step
# Epoch 39/100
# 54/54 - 0s - loss: 7.8213e-04 - 98ms/epoch - 2ms/step
# Epoch 40/100
# 54/54 - 0s - loss: 6.8356e-04 - 101ms/epoch - 2ms/step
# Epoch 41/100
# 54/54 - 0s - loss: 7.5749e-04 - 101ms/epoch - 2ms/step
# Epoch 42/100
# 54/54 - 0s - loss: 6.4257e-04 - 100ms/epoch - 2ms/step
# Epoch 43/100
# 54/54 - 0s - loss: 6.4835e-04 - 99ms/epoch - 2ms/step
# Epoch 44/100
# 54/54 - 0s - loss: 7.1692e-04 - 102ms/epoch - 2ms/step
# Epoch 45/100
# 54/54 - 0s - loss: 7.1876e-04 - 103ms/epoch - 2ms/step
# Epoch 46/100
# 54/54 - 0s - loss: 7.2059e-04 - 100ms/epoch - 2ms/step
# Epoch 47/100
# 54/54 - 0s - loss: 6.8618e-04 - 100ms/epoch - 2ms/step
# Epoch 48/100
# 54/54 - 0s - loss: 6.7205e-04 - 101ms/epoch - 2ms/step
# Epoch 49/100
# 54/54 - 0s - loss: 6.6616e-04 - 100ms/epoch - 2ms/step
# Epoch 50/100
# 54/54 - 0s - loss: 6.2680e-04 - 102ms/epoch - 2ms/step
# Epoch 51/100
# 54/54 - 0s - loss: 6.9348e-04 - 100ms/epoch - 2ms/step
# Epoch 52/100
# 54/54 - 0s - loss: 6.2556e-04 - 101ms/epoch - 2ms/step
# Epoch 53/100
# 54/54 - 0s - loss: 6.7947e-04 - 100ms/epoch - 2ms/step
# Epoch 54/100
# 54/54 - 0s - loss: 6.5183e-04 - 99ms/epoch - 2ms/step
# Epoch 55/100
# 54/54 - 0s - loss: 6.7767e-04 - 103ms/epoch - 2ms/step
# Epoch 56/100
# 54/54 - 0s - loss: 6.2753e-04 - 98ms/epoch - 2ms/step
# Epoch 57/100
# 54/54 - 0s - loss: 6.5595e-04 - 97ms/epoch - 2ms/step
# Epoch 58/100
# 54/54 - 0s - loss: 6.4260e-04 - 97ms/epoch - 2ms/step
# Epoch 59/100
# 54/54 - 0s - loss: 6.5384e-04 - 97ms/epoch - 2ms/step
# Epoch 60/100
# 54/54 - 0s - loss: 6.7954e-04 - 98ms/epoch - 2ms/step
# Epoch 61/100
# 54/54 - 0s - loss: 5.8945e-04 - 98ms/epoch - 2ms/step
# Epoch 62/100
# 54/54 - 0s - loss: 6.2112e-04 - 101ms/epoch - 2ms/step
# Epoch 63/100
# 54/54 - 0s - loss: 5.9044e-04 - 101ms/epoch - 2ms/step
# Epoch 64/100
# 54/54 - 0s - loss: 5.9120e-04 - 99ms/epoch - 2ms/step
# Epoch 65/100
# 54/54 - 0s - loss: 5.5395e-04 - 99ms/epoch - 2ms/step
# Epoch 66/100
# 54/54 - 0s - loss: 6.1308e-04 - 97ms/epoch - 2ms/step
# Epoch 67/100
# 54/54 - 0s - loss: 5.9361e-04 - 98ms/epoch - 2ms/step
# Epoch 68/100
# 54/54 - 0s - loss: 5.6551e-04 - 101ms/epoch - 2ms/step
# Epoch 69/100
# 54/54 - 0s - loss: 6.1136e-04 - 99ms/epoch - 2ms/step
# Epoch 70/100
# 54/54 - 0s - loss: 6.0348e-04 - 114ms/epoch - 2ms/step
# Epoch 71/100
# 54/54 - 0s - loss: 5.5920e-04 - 99ms/epoch - 2ms/step
# Epoch 72/100
# 54/54 - 0s - loss: 5.4809e-04 - 99ms/epoch - 2ms/step
# Epoch 73/100
# 54/54 - 0s - loss: 5.5768e-04 - 99ms/epoch - 2ms/step
# Epoch 74/100
# 54/54 - 0s - loss: 5.9383e-04 - 104ms/epoch - 2ms/step
# Epoch 75/100
# 54/54 - 0s - loss: 5.7758e-04 - 105ms/epoch - 2ms/step
# Epoch 76/100
# 54/54 - 0s - loss: 5.8955e-04 - 103ms/epoch - 2ms/step
# Epoch 77/100
# 54/54 - 0s - loss: 5.7881e-04 - 102ms/epoch - 2ms/step
# Epoch 78/100
# 54/54 - 0s - loss: 6.4298e-04 - 105ms/epoch - 2ms/step
# Epoch 79/100
# 54/54 - 0s - loss: 5.1343e-04 - 100ms/epoch - 2ms/step
# Epoch 80/100
# 54/54 - 0s - loss: 5.8174e-04 - 101ms/epoch - 2ms/step
# Epoch 81/100
# 54/54 - 0s - loss: 5.8519e-04 - 103ms/epoch - 2ms/step
# Epoch 82/100
# 54/54 - 0s - loss: 5.6920e-04 - 95ms/epoch - 2ms/step
# Epoch 83/100
# 54/54 - 0s - loss: 4.9865e-04 - 100ms/epoch - 2ms/step
# Epoch 84/100
# 54/54 - 0s - loss: 5.7135e-04 - 102ms/epoch - 2ms/step
# Epoch 85/100
# 54/54 - 0s - loss: 5.5811e-04 - 102ms/epoch - 2ms/step
# Epoch 86/100
# 54/54 - 0s - loss: 5.9147e-04 - 100ms/epoch - 2ms/step
# Epoch 87/100
# 54/54 - 0s - loss: 5.5491e-04 - 100ms/epoch - 2ms/step
# Epoch 88/100
# 54/54 - 0s - loss: 5.4471e-04 - 106ms/epoch - 2ms/step
# Epoch 89/100
# 54/54 - 0s - loss: 5.2912e-04 - 104ms/epoch - 2ms/step
# Epoch 90/100
# 54/54 - 0s - loss: 5.2181e-04 - 107ms/epoch - 2ms/step
# Epoch 91/100
# 54/54 - 0s - loss: 5.6253e-04 - 114ms/epoch - 2ms/step
# Epoch 92/100
# 54/54 - 0s - loss: 5.4965e-04 - 102ms/epoch - 2ms/step
# Epoch 93/100
# 54/54 - 0s - loss: 5.3851e-04 - 99ms/epoch - 2ms/step
# Epoch 94/100
# 54/54 - 0s - loss: 5.3169e-04 - 97ms/epoch - 2ms/step
# Epoch 95/100
# 54/54 - 0s - loss: 5.4942e-04 - 101ms/epoch - 2ms/step
# Epoch 96/100
# 54/54 - 0s - loss: 5.6172e-04 - 97ms/epoch - 2ms/step
# Epoch 97/100
# 54/54 - 0s - loss: 5.9837e-04 - 99ms/epoch - 2ms/step
# Epoch 98/100
# 54/54 - 0s - loss: 5.4793e-04 - 109ms/epoch - 2ms/step
# Epoch 99/100
# 54/54 - 0s - loss: 5.6685e-04 - 98ms/epoch - 2ms/step
# Epoch 100/100
# 54/54 - 0s - loss: 5.5332e-04 - 100ms/epoch - 2ms/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_8 (GRU)                 (None, 1, 50)             8700
#
#  dropout_8 (Dropout)         (None, 1, 50)             0
#
#  gru_9 (GRU)                 (None, 50)                15300
#
#  dropout_9 (Dropout)         (None, 50)                0
#
#  dense_4 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 24,051
# Trainable params: 24,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make predictions
train_pred = model.predict(X_train_reshape)
test_pred = model.predict(X_test_reshape)

# unable to inverse transform values due to original output having 6 features

# calculate RMSE
train_score = np.sqrt(mean_squared_error(y_train, train_pred))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test, test_pred))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 108/108 [==============================] - 1s 732us/step
# 27/27 [==============================] - 0s 965us/step
# Train score: 0.00 RMSE
# Test score: 0.33 RMSE

# %%
dataset_trans = mm.transform(dataset)

# %%
# shift train predictions for plotting
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

# shift test predictions for plotting
test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[len(train_pred) + (look_back*2)+1:len(dataset)-1, :] = test_pred

# plot baseline and predictions
plt.plot(dataset_trans[:,0])
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()
