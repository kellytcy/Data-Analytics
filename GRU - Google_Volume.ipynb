# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.layers import GRU
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-08-19    49.813290    51.835709    47.800831    49.982655    49.982655
# 2004-08-20    50.316402    54.336334    50.062355    53.952770    53.952770
# 2004-08-23    55.168217    56.528118    54.321388    54.495735    54.495735
# 2004-08-24    55.412300    55.591629    51.591621    52.239197    52.239197
# 2004-08-25    52.284027    53.798351    51.746044    52.802086    52.802086
# ...                 ...          ...          ...          ...          ...
# 2021-10-04  2713.989990  2714.000000  2623.330078  2675.300049  2675.300049
# 2021-10-05  2680.000000  2747.239990  2680.000000  2723.540039  2723.540039
# 2021-10-06  2692.510010  2757.040039  2689.729980  2747.080078  2747.080078
# 2021-10-07  2777.260010  2803.089111  2771.260010  2783.709961  2783.709961
# 2021-10-08  2798.120117  2806.340088  2788.586914  2801.120117  2801.120117
#
#               Volume
# Date
# 2004-08-19  44871361
# 2004-08-20  22942874
# 2004-08-23  18342897
# 2004-08-24  15319808
# 2004-08-25   9232276
# ...              ...
# 2021-10-04   1576500
# 2021-10-05   1206300
# 2021-10-06    988200
# 2021-10-07    912500
# 2021-10-08    946200
#
# [4316 rows x 6 columns]

# %%
df.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999920  0.999903  0.999827   0.999827 -0.476751
# High       0.999920  1.000000  0.999878  0.999911   0.999911 -0.475723
# Low        0.999903  0.999878  1.000000  0.999924   0.999924 -0.477952
# Close      0.999827  0.999911  0.999924  1.000000   1.000000 -0.476871
# Adj Close  0.999827  0.999911  0.999924  1.000000   1.000000 -0.476871
# Volume    -0.476751 -0.475723 -0.477952 -0.476871  -0.476871  1.000000

# %%
dataset = df['Volume']
dataset = dataset.values.astype('float32')
tf.random.set_seed(10)

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [],[]
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
dataset = dataset.reshape(-1,1)
mm = MinMaxScaler(feature_range=(0,1))

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# %%
look_back = 1
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)
y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
X_train = mm.fit_transform(X_train)
y_train = mm.fit_transform(y_train)

X_test = mm.transform(X_test)
y_test = mm.transform(y_test)

# %%
# reshape input to be (samples, timesteps, features)
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(GRU(50, input_shape=(1, look_back), return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(50))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train, y_train, epochs=100, batch_size = 64, verbose = 2)
# Out:
# Epoch 1/100
# 54/54 - 3s - loss: 0.0077 - 3s/epoch - 51ms/step
# Epoch 2/100
# 54/54 - 0s - loss: 0.0038 - 109ms/epoch - 2ms/step
# Epoch 3/100
# 54/54 - 0s - loss: 0.0036 - 100ms/epoch - 2ms/step
# Epoch 4/100
# 54/54 - 0s - loss: 0.0036 - 110ms/epoch - 2ms/step
# Epoch 5/100
# 54/54 - 0s - loss: 0.0035 - 100ms/epoch - 2ms/step
# Epoch 6/100
# 54/54 - 0s - loss: 0.0035 - 100ms/epoch - 2ms/step
# Epoch 7/100
# 54/54 - 0s - loss: 0.0034 - 100ms/epoch - 2ms/step
# Epoch 8/100
# 54/54 - 0s - loss: 0.0034 - 100ms/epoch - 2ms/step
# Epoch 9/100
# 54/54 - 0s - loss: 0.0034 - 100ms/epoch - 2ms/step
# Epoch 10/100
# 54/54 - 0s - loss: 0.0034 - 120ms/epoch - 2ms/step
# Epoch 11/100
# 54/54 - 0s - loss: 0.0034 - 100ms/epoch - 2ms/step
# Epoch 12/100
# 54/54 - 0s - loss: 0.0034 - 99ms/epoch - 2ms/step
# Epoch 13/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 14/100
# 54/54 - 0s - loss: 0.0033 - 100ms/epoch - 2ms/step
# Epoch 15/100
# 54/54 - 0s - loss: 0.0032 - 110ms/epoch - 2ms/step
# Epoch 16/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 17/100
# 54/54 - 0s - loss: 0.0033 - 100ms/epoch - 2ms/step
# Epoch 18/100
# 54/54 - 0s - loss: 0.0033 - 100ms/epoch - 2ms/step
# Epoch 19/100
# 54/54 - 0s - loss: 0.0032 - 111ms/epoch - 2ms/step
# Epoch 20/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 21/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 22/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 23/100
# 54/54 - 0s - loss: 0.0032 - 94ms/epoch - 2ms/step
# Epoch 24/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 25/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 26/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 27/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 28/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 29/100
# 54/54 - 0s - loss: 0.0030 - 105ms/epoch - 2ms/step
# Epoch 30/100
# 54/54 - 0s - loss: 0.0031 - 93ms/epoch - 2ms/step
# Epoch 31/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 32/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 33/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 34/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 35/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 36/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 37/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 38/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 39/100
# 54/54 - 0s - loss: 0.0031 - 110ms/epoch - 2ms/step
# Epoch 40/100
# 54/54 - 0s - loss: 0.0030 - 109ms/epoch - 2ms/step
# Epoch 41/100
# 54/54 - 0s - loss: 0.0031 - 123ms/epoch - 2ms/step
# Epoch 42/100
# 54/54 - 0s - loss: 0.0031 - 120ms/epoch - 2ms/step
# Epoch 43/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 44/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 45/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 46/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 47/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 48/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 49/100
# 54/54 - 0s - loss: 0.0031 - 116ms/epoch - 2ms/step
# Epoch 50/100
# 54/54 - 0s - loss: 0.0031 - 137ms/epoch - 3ms/step
# Epoch 51/100
# 54/54 - 0s - loss: 0.0031 - 140ms/epoch - 3ms/step
# Epoch 52/100
# 54/54 - 0s - loss: 0.0031 - 147ms/epoch - 3ms/step
# Epoch 53/100
# 54/54 - 0s - loss: 0.0031 - 101ms/epoch - 2ms/step
# Epoch 54/100
# 54/54 - 0s - loss: 0.0031 - 120ms/epoch - 2ms/step
# Epoch 55/100
# 54/54 - 0s - loss: 0.0031 - 120ms/epoch - 2ms/step
# Epoch 56/100
# 54/54 - 0s - loss: 0.0031 - 116ms/epoch - 2ms/step
# Epoch 57/100
# 54/54 - 0s - loss: 0.0030 - 120ms/epoch - 2ms/step
# Epoch 58/100
# 54/54 - 0s - loss: 0.0031 - 142ms/epoch - 3ms/step
# Epoch 59/100
# 54/54 - 0s - loss: 0.0030 - 136ms/epoch - 3ms/step
# Epoch 60/100
# 54/54 - 0s - loss: 0.0031 - 99ms/epoch - 2ms/step
# Epoch 61/100
# 54/54 - 0s - loss: 0.0031 - 110ms/epoch - 2ms/step
# Epoch 62/100
# 54/54 - 0s - loss: 0.0031 - 103ms/epoch - 2ms/step
# Epoch 63/100
# 54/54 - 0s - loss: 0.0032 - 97ms/epoch - 2ms/step
# Epoch 64/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 65/100
# 54/54 - 0s - loss: 0.0030 - 110ms/epoch - 2ms/step
# Epoch 66/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 67/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 68/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 69/100
# 54/54 - 0s - loss: 0.0032 - 101ms/epoch - 2ms/step
# Epoch 70/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 71/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 72/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 73/100
# 54/54 - 0s - loss: 0.0031 - 110ms/epoch - 2ms/step
# Epoch 74/100
# 54/54 - 0s - loss: 0.0031 - 110ms/epoch - 2ms/step
# Epoch 75/100
# 54/54 - 0s - loss: 0.0031 - 112ms/epoch - 2ms/step
# Epoch 76/100
# 54/54 - 0s - loss: 0.0030 - 138ms/epoch - 3ms/step
# Epoch 77/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 78/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 79/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 80/100
# 54/54 - 0s - loss: 0.0031 - 90ms/epoch - 2ms/step
# Epoch 81/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 82/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 83/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 84/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 85/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 86/100
# 54/54 - 0s - loss: 0.0031 - 132ms/epoch - 2ms/step
# Epoch 87/100
# 54/54 - 0s - loss: 0.0031 - 98ms/epoch - 2ms/step
# Epoch 88/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 89/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 90/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 91/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 92/100
# 54/54 - 0s - loss: 0.0031 - 103ms/epoch - 2ms/step
# Epoch 93/100
# 54/54 - 0s - loss: 0.0030 - 98ms/epoch - 2ms/step
# Epoch 94/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 95/100
# 54/54 - 0s - loss: 0.0031 - 90ms/epoch - 2ms/step
# Epoch 96/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 97/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 98/100
# 54/54 - 0s - loss: 0.0031 - 99ms/epoch - 2ms/step
# Epoch 99/100
# 54/54 - 0s - loss: 0.0031 - 97ms/epoch - 2ms/step
# Epoch 100/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred = mm.inverse_transform(train_pred)
y_train = mm.inverse_transform(y_train)

test_pred = mm.inverse_transform(test_pred)
y_test = mm.inverse_transform(y_test)

train_score = np.sqrt(mean_squared_error(y_train[:,0], train_pred[:,0]))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test[:,0], test_pred[:,0]))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 108/108 [==============================] - 1s 772us/step
# 27/27 [==============================] - 0s 875us/step
# Train score: 4485507.50 RMSE
# Test score: 703203.88 RMSE

# %%
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[len(train_pred) + (look_back*2):len(dataset)-2, :] = test_pred

plt.plot(dataset)
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()

# %% [markdown]
# ### Increasing timesteps

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
dataset = df['Volume']
dataset = dataset.values.astype('float32')
tf.random.set_seed(10)

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [],[]
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
dataset = dataset.reshape(-1,1)
mm = MinMaxScaler(feature_range=(0,1))

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# %%
train = mm.fit_transform(train)
test = mm.transform(test)

# %%
look_back = 3
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
X_train.shape
# Out:
# (3448, 3)

# %%
y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(GRU(50, input_shape=(1, look_back), return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(50))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train, y_train, epochs=100, batch_size = 64, verbose = 2)
# Out:
# Epoch 1/100
# 54/54 - 3s - loss: 0.0064 - 3s/epoch - 52ms/step
# Epoch 2/100
# 54/54 - 0s - loss: 0.0037 - 102ms/epoch - 2ms/step
# Epoch 3/100
# 54/54 - 0s - loss: 0.0035 - 107ms/epoch - 2ms/step
# Epoch 4/100
# 54/54 - 0s - loss: 0.0033 - 90ms/epoch - 2ms/step
# Epoch 5/100
# 54/54 - 0s - loss: 0.0033 - 100ms/epoch - 2ms/step
# Epoch 6/100
# 54/54 - 0s - loss: 0.0033 - 100ms/epoch - 2ms/step
# Epoch 7/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 8/100
# 54/54 - 0s - loss: 0.0033 - 91ms/epoch - 2ms/step
# Epoch 9/100
# 54/54 - 0s - loss: 0.0033 - 100ms/epoch - 2ms/step
# Epoch 10/100
# 54/54 - 0s - loss: 0.0031 - 101ms/epoch - 2ms/step
# Epoch 11/100
# 54/54 - 0s - loss: 0.0032 - 99ms/epoch - 2ms/step
# Epoch 12/100
# 54/54 - 0s - loss: 0.0031 - 110ms/epoch - 2ms/step
# Epoch 13/100
# 54/54 - 0s - loss: 0.0031 - 99ms/epoch - 2ms/step
# Epoch 14/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 15/100
# 54/54 - 0s - loss: 0.0031 - 110ms/epoch - 2ms/step
# Epoch 16/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 17/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 18/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 19/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 20/100
# 54/54 - 0s - loss: 0.0031 - 103ms/epoch - 2ms/step
# Epoch 21/100
# 54/54 - 0s - loss: 0.0030 - 107ms/epoch - 2ms/step
# Epoch 22/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 23/100
# 54/54 - 0s - loss: 0.0031 - 115ms/epoch - 2ms/step
# Epoch 24/100
# 54/54 - 0s - loss: 0.0030 - 94ms/epoch - 2ms/step
# Epoch 25/100
# 54/54 - 0s - loss: 0.0031 - 117ms/epoch - 2ms/step
# Epoch 26/100
# 54/54 - 0s - loss: 0.0030 - 102ms/epoch - 2ms/step
# Epoch 27/100
# 54/54 - 0s - loss: 0.0030 - 110ms/epoch - 2ms/step
# Epoch 28/100
# 54/54 - 0s - loss: 0.0030 - 130ms/epoch - 2ms/step
# Epoch 29/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 30/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 31/100
# 54/54 - 0s - loss: 0.0031 - 99ms/epoch - 2ms/step
# Epoch 32/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 33/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 34/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 35/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 36/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 37/100
# 54/54 - 0s - loss: 0.0030 - 90ms/epoch - 2ms/step
# Epoch 38/100
# 54/54 - 0s - loss: 0.0030 - 110ms/epoch - 2ms/step
# Epoch 39/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 40/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 41/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 42/100
# 54/54 - 0s - loss: 0.0030 - 110ms/epoch - 2ms/step
# Epoch 43/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 44/100
# 54/54 - 0s - loss: 0.0029 - 100ms/epoch - 2ms/step
# Epoch 45/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 46/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 47/100
# 54/54 - 0s - loss: 0.0031 - 90ms/epoch - 2ms/step
# Epoch 48/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 49/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 50/100
# 54/54 - 0s - loss: 0.0031 - 123ms/epoch - 2ms/step
# Epoch 51/100
# 54/54 - 0s - loss: 0.0030 - 148ms/epoch - 3ms/step
# Epoch 52/100
# 54/54 - 0s - loss: 0.0029 - 149ms/epoch - 3ms/step
# Epoch 53/100
# 54/54 - 0s - loss: 0.0030 - 181ms/epoch - 3ms/step
# Epoch 54/100
# 54/54 - 0s - loss: 0.0031 - 122ms/epoch - 2ms/step
# Epoch 55/100
# 54/54 - 0s - loss: 0.0030 - 110ms/epoch - 2ms/step
# Epoch 56/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 57/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 58/100
# 54/54 - 0s - loss: 0.0029 - 100ms/epoch - 2ms/step
# Epoch 59/100
# 54/54 - 0s - loss: 0.0030 - 111ms/epoch - 2ms/step
# Epoch 60/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 61/100
# 54/54 - 0s - loss: 0.0030 - 105ms/epoch - 2ms/step
# Epoch 62/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 63/100
# 54/54 - 0s - loss: 0.0030 - 105ms/epoch - 2ms/step
# Epoch 64/100
# 54/54 - 0s - loss: 0.0030 - 97ms/epoch - 2ms/step
# Epoch 65/100
# 54/54 - 0s - loss: 0.0031 - 123ms/epoch - 2ms/step
# Epoch 66/100
# 54/54 - 0s - loss: 0.0030 - 154ms/epoch - 3ms/step
# Epoch 67/100
# 54/54 - 0s - loss: 0.0030 - 136ms/epoch - 3ms/step
# Epoch 68/100
# 54/54 - 0s - loss: 0.0031 - 126ms/epoch - 2ms/step
# Epoch 69/100
# 54/54 - 0s - loss: 0.0030 - 120ms/epoch - 2ms/step
# Epoch 70/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 71/100
# 54/54 - 0s - loss: 0.0030 - 110ms/epoch - 2ms/step
# Epoch 72/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 73/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 74/100
# 54/54 - 0s - loss: 0.0030 - 124ms/epoch - 2ms/step
# Epoch 75/100
# 54/54 - 0s - loss: 0.0030 - 129ms/epoch - 2ms/step
# Epoch 76/100
# 54/54 - 0s - loss: 0.0029 - 119ms/epoch - 2ms/step
# Epoch 77/100
# 54/54 - 0s - loss: 0.0031 - 92ms/epoch - 2ms/step
# Epoch 78/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 79/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 80/100
# 54/54 - 0s - loss: 0.0030 - 91ms/epoch - 2ms/step
# Epoch 81/100
# 54/54 - 0s - loss: 0.0030 - 99ms/epoch - 2ms/step
# Epoch 82/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 83/100
# 54/54 - 0s - loss: 0.0030 - 90ms/epoch - 2ms/step
# Epoch 84/100
# 54/54 - 0s - loss: 0.0030 - 104ms/epoch - 2ms/step
# Epoch 85/100
# 54/54 - 0s - loss: 0.0030 - 96ms/epoch - 2ms/step
# Epoch 86/100
# 54/54 - 0s - loss: 0.0029 - 100ms/epoch - 2ms/step
# Epoch 87/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 88/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 89/100
# 54/54 - 0s - loss: 0.0030 - 90ms/epoch - 2ms/step
# Epoch 90/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 91/100
# 54/54 - 0s - loss: 0.0029 - 100ms/epoch - 2ms/step
# Epoch 92/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 93/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 94/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 95/100
# 54/54 - 0s - loss: 0.0030 - 93ms/epoch - 2ms/step
# Epoch 96/100
# 54/54 - 0s - loss: 0.0030 - 90ms/epoch - 2ms/step
# Epoch 97/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 98/100
# 54/54 - 0s - loss: 0.0030 - 90ms/epoch - 2ms/step
# Epoch 99/100
# 54/54 - 0s - loss: 0.0029 - 100ms/epoch - 2ms/step
# Epoch 100/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred = mm.inverse_transform(train_pred)
y_train = mm.inverse_transform(y_train)

test_pred = mm.inverse_transform(test_pred)
y_test = mm.inverse_transform(y_test)

train_score = np.sqrt(mean_squared_error(y_train[:,0], train_pred[:,0]))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test[:,0], test_pred[:,0]))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 108/108 [==============================] - 1s 772us/step
# 27/27 [==============================] - 0s 731us/step
# Train score: 4422577.00 RMSE
# Test score: 701564.12 RMSE

# %%
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[len(train_pred) + (look_back*2):len(dataset)-2, :] = test_pred

plt.plot(dataset)
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()

# %% [markdown]
# ### Multiple features

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
dataset = df['Volume']
dataset = df.values.astype('float32')
tf.random.set_seed(10)

mm = MinMaxScaler(feature_range=(0,1))

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# %%
train = mm.fit_transform(train)
test = mm.transform(test)

# %%
y_train = train[:,-1]
y_test = test[:,-1]

# %%
def create_dataset_features (dataset, look_back=1):
    dataX = np.ones(shape=(1, 6))
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), :]
        dataX = np.vstack((dataX, a))
    return np.array(dataX)

# %%
def create_test (dataset, look_back=1):
    dataY = np.ones(shape=(1))
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back)]
        dataY = np.vstack((dataY, a))
    return np.array(dataY)

# %%
look_back = 1
X_train = create_dataset_features(train, look_back)
X_test = create_dataset_features(test, look_back)
y_train = create_test(y_train, look_back)
y_test = create_test(y_test, look_back)

# %%
X_train = np.delete(X_train, 0, 0)
y_train = np.delete(y_train, 0, 0)
X_test = np.delete(X_test, 0, 0)
y_test = np.delete(y_test, 0, 0)

# %%
X_train_reshape = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test_reshape = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(GRU(50, input_shape=(1, 6), return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(50))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train_reshape, y_train, epochs=100, batch_size = 64, verbose = 2)
model.summary()
# Out:
# Epoch 1/100
# 54/54 - 3s - loss: 0.0073 - 3s/epoch - 52ms/step
# Epoch 2/100
# 54/54 - 0s - loss: 0.0024 - 114ms/epoch - 2ms/step
# Epoch 3/100
# 54/54 - 0s - loss: 5.5356e-04 - 95ms/epoch - 2ms/step
# Epoch 4/100
# 54/54 - 0s - loss: 3.3299e-04 - 110ms/epoch - 2ms/step
# Epoch 5/100
# 54/54 - 0s - loss: 2.7482e-04 - 108ms/epoch - 2ms/step
# Epoch 6/100
# 54/54 - 0s - loss: 2.2472e-04 - 106ms/epoch - 2ms/step
# Epoch 7/100
# 54/54 - 0s - loss: 2.5225e-04 - 93ms/epoch - 2ms/step
# Epoch 8/100
# 54/54 - 0s - loss: 2.1373e-04 - 110ms/epoch - 2ms/step
# Epoch 9/100
# 54/54 - 0s - loss: 1.8765e-04 - 98ms/epoch - 2ms/step
# Epoch 10/100
# 54/54 - 0s - loss: 2.0989e-04 - 100ms/epoch - 2ms/step
# Epoch 11/100
# 54/54 - 0s - loss: 2.0157e-04 - 110ms/epoch - 2ms/step
# Epoch 12/100
# 54/54 - 0s - loss: 1.9723e-04 - 107ms/epoch - 2ms/step
# Epoch 13/100
# 54/54 - 0s - loss: 2.2447e-04 - 102ms/epoch - 2ms/step
# Epoch 14/100
# 54/54 - 0s - loss: 1.6081e-04 - 109ms/epoch - 2ms/step
# Epoch 15/100
# 54/54 - 0s - loss: 1.6761e-04 - 100ms/epoch - 2ms/step
# Epoch 16/100
# 54/54 - 0s - loss: 1.7351e-04 - 152ms/epoch - 3ms/step
# Epoch 17/100
# 54/54 - 0s - loss: 1.6620e-04 - 100ms/epoch - 2ms/step
# Epoch 18/100
# 54/54 - 0s - loss: 1.9748e-04 - 120ms/epoch - 2ms/step
# Epoch 19/100
# 54/54 - 0s - loss: 1.6387e-04 - 100ms/epoch - 2ms/step
# Epoch 20/100
# 54/54 - 0s - loss: 1.6693e-04 - 117ms/epoch - 2ms/step
# Epoch 21/100
# 54/54 - 0s - loss: 1.4200e-04 - 123ms/epoch - 2ms/step
# Epoch 22/100
# 54/54 - 0s - loss: 1.4749e-04 - 99ms/epoch - 2ms/step
# Epoch 23/100
# 54/54 - 0s - loss: 1.4152e-04 - 100ms/epoch - 2ms/step
# Epoch 24/100
# 54/54 - 0s - loss: 1.6520e-04 - 100ms/epoch - 2ms/step
# Epoch 25/100
# 54/54 - 0s - loss: 1.4264e-04 - 100ms/epoch - 2ms/step
# Epoch 26/100
# 54/54 - 0s - loss: 1.4857e-04 - 100ms/epoch - 2ms/step
# Epoch 27/100
# 54/54 - 0s - loss: 1.2541e-04 - 111ms/epoch - 2ms/step
# Epoch 28/100
# 54/54 - 0s - loss: 1.7860e-04 - 99ms/epoch - 2ms/step
# Epoch 29/100
# 54/54 - 0s - loss: 1.2639e-04 - 100ms/epoch - 2ms/step
# Epoch 30/100
# 54/54 - 0s - loss: 1.5304e-04 - 100ms/epoch - 2ms/step
# Epoch 31/100
# 54/54 - 0s - loss: 1.4198e-04 - 100ms/epoch - 2ms/step
# Epoch 32/100
# 54/54 - 0s - loss: 1.7821e-04 - 101ms/epoch - 2ms/step
# Epoch 33/100
# 54/54 - 0s - loss: 1.2817e-04 - 110ms/epoch - 2ms/step
# Epoch 34/100
# 54/54 - 0s - loss: 1.3287e-04 - 100ms/epoch - 2ms/step
# Epoch 35/100
# 54/54 - 0s - loss: 1.2240e-04 - 110ms/epoch - 2ms/step
# Epoch 36/100
# 54/54 - 0s - loss: 1.2597e-04 - 100ms/epoch - 2ms/step
# Epoch 37/100
# 54/54 - 0s - loss: 1.5529e-04 - 100ms/epoch - 2ms/step
# Epoch 38/100
# 54/54 - 0s - loss: 1.5422e-04 - 100ms/epoch - 2ms/step
# Epoch 39/100
# 54/54 - 0s - loss: 1.3272e-04 - 100ms/epoch - 2ms/step
# Epoch 40/100
# 54/54 - 0s - loss: 1.2349e-04 - 110ms/epoch - 2ms/step
# Epoch 41/100
# 54/54 - 0s - loss: 1.2306e-04 - 100ms/epoch - 2ms/step
# Epoch 42/100
# 54/54 - 0s - loss: 1.2702e-04 - 110ms/epoch - 2ms/step
# Epoch 43/100
# 54/54 - 0s - loss: 1.1490e-04 - 100ms/epoch - 2ms/step
# Epoch 44/100
# 54/54 - 0s - loss: 1.1558e-04 - 110ms/epoch - 2ms/step
# Epoch 45/100
# 54/54 - 0s - loss: 1.1148e-04 - 100ms/epoch - 2ms/step
# Epoch 46/100
# 54/54 - 0s - loss: 1.0710e-04 - 100ms/epoch - 2ms/step
# Epoch 47/100
# 54/54 - 0s - loss: 1.2896e-04 - 104ms/epoch - 2ms/step
# Epoch 48/100
# 54/54 - 0s - loss: 1.4822e-04 - 105ms/epoch - 2ms/step
# Epoch 49/100
# 54/54 - 0s - loss: 1.2560e-04 - 100ms/epoch - 2ms/step
# Epoch 50/100
# 54/54 - 0s - loss: 1.1252e-04 - 100ms/epoch - 2ms/step
# Epoch 51/100
# 54/54 - 0s - loss: 1.3922e-04 - 110ms/epoch - 2ms/step
# Epoch 52/100
# 54/54 - 0s - loss: 1.2355e-04 - 105ms/epoch - 2ms/step
# Epoch 53/100
# 54/54 - 0s - loss: 1.3536e-04 - 100ms/epoch - 2ms/step
# Epoch 54/100
# 54/54 - 0s - loss: 1.4285e-04 - 111ms/epoch - 2ms/step
# Epoch 55/100
# 54/54 - 0s - loss: 1.1739e-04 - 97ms/epoch - 2ms/step
# Epoch 56/100
# 54/54 - 0s - loss: 1.4975e-04 - 100ms/epoch - 2ms/step
# Epoch 57/100
# 54/54 - 0s - loss: 1.2181e-04 - 100ms/epoch - 2ms/step
# Epoch 58/100
# 54/54 - 0s - loss: 1.2059e-04 - 100ms/epoch - 2ms/step
# Epoch 59/100
# 54/54 - 0s - loss: 1.2531e-04 - 135ms/epoch - 2ms/step
# Epoch 60/100
# 54/54 - 0s - loss: 1.1641e-04 - 161ms/epoch - 3ms/step
# Epoch 61/100
# 54/54 - 0s - loss: 1.1091e-04 - 128ms/epoch - 2ms/step
# Epoch 62/100
# 54/54 - 0s - loss: 1.4329e-04 - 92ms/epoch - 2ms/step
# Epoch 63/100
# 54/54 - 0s - loss: 1.7719e-04 - 100ms/epoch - 2ms/step
# Epoch 64/100
# 54/54 - 0s - loss: 1.4249e-04 - 112ms/epoch - 2ms/step
# Epoch 65/100
# 54/54 - 0s - loss: 1.1673e-04 - 102ms/epoch - 2ms/step
# Epoch 66/100
# 54/54 - 0s - loss: 1.3249e-04 - 125ms/epoch - 2ms/step
# Epoch 67/100
# 54/54 - 0s - loss: 1.0970e-04 - 127ms/epoch - 2ms/step
# Epoch 68/100
# 54/54 - 0s - loss: 1.3316e-04 - 100ms/epoch - 2ms/step
# Epoch 69/100
# 54/54 - 0s - loss: 1.2052e-04 - 100ms/epoch - 2ms/step
# Epoch 70/100
# 54/54 - 0s - loss: 1.1328e-04 - 100ms/epoch - 2ms/step
# Epoch 71/100
# 54/54 - 0s - loss: 1.4399e-04 - 100ms/epoch - 2ms/step
# Epoch 72/100
# 54/54 - 0s - loss: 1.2314e-04 - 118ms/epoch - 2ms/step
# Epoch 73/100
# 54/54 - 0s - loss: 1.1503e-04 - 128ms/epoch - 2ms/step
# Epoch 74/100
# 54/54 - 0s - loss: 1.3921e-04 - 91ms/epoch - 2ms/step
# Epoch 75/100
# 54/54 - 0s - loss: 1.0747e-04 - 110ms/epoch - 2ms/step
# Epoch 76/100
# 54/54 - 0s - loss: 1.1318e-04 - 100ms/epoch - 2ms/step
# Epoch 77/100
# 54/54 - 0s - loss: 1.1886e-04 - 100ms/epoch - 2ms/step
# Epoch 78/100
# 54/54 - 0s - loss: 1.1815e-04 - 100ms/epoch - 2ms/step
# Epoch 79/100
# 54/54 - 0s - loss: 1.1398e-04 - 100ms/epoch - 2ms/step
# Epoch 80/100
# 54/54 - 0s - loss: 1.2225e-04 - 100ms/epoch - 2ms/step
# Epoch 81/100
# 54/54 - 0s - loss: 1.0755e-04 - 100ms/epoch - 2ms/step
# Epoch 82/100
# 54/54 - 0s - loss: 1.1611e-04 - 100ms/epoch - 2ms/step
# Epoch 83/100
# 54/54 - 0s - loss: 1.1919e-04 - 100ms/epoch - 2ms/step
# Epoch 84/100
# 54/54 - 0s - loss: 1.2569e-04 - 100ms/epoch - 2ms/step
# Epoch 85/100
# 54/54 - 0s - loss: 1.1782e-04 - 100ms/epoch - 2ms/step
# Epoch 86/100
# 54/54 - 0s - loss: 1.4412e-04 - 102ms/epoch - 2ms/step
# Epoch 87/100
# 54/54 - 0s - loss: 1.2239e-04 - 98ms/epoch - 2ms/step
# Epoch 88/100
# 54/54 - 0s - loss: 1.3322e-04 - 100ms/epoch - 2ms/step
# Epoch 89/100
# 54/54 - 0s - loss: 1.1263e-04 - 104ms/epoch - 2ms/step
# Epoch 90/100
# 54/54 - 0s - loss: 1.1430e-04 - 98ms/epoch - 2ms/step
# Epoch 91/100
# 54/54 - 0s - loss: 1.1537e-04 - 100ms/epoch - 2ms/step
# Epoch 92/100
# 54/54 - 0s - loss: 1.3151e-04 - 100ms/epoch - 2ms/step
# Epoch 93/100
# 54/54 - 0s - loss: 8.8892e-05 - 100ms/epoch - 2ms/step
# Epoch 94/100
# 54/54 - 0s - loss: 1.2442e-04 - 101ms/epoch - 2ms/step
# Epoch 95/100
# 54/54 - 0s - loss: 1.0521e-04 - 99ms/epoch - 2ms/step
# Epoch 96/100
# 54/54 - 0s - loss: 1.2282e-04 - 100ms/epoch - 2ms/step
# Epoch 97/100
# 54/54 - 0s - loss: 1.1395e-04 - 100ms/epoch - 2ms/step
# Epoch 98/100
# 54/54 - 0s - loss: 1.2011e-04 - 100ms/epoch - 2ms/step
# Epoch 99/100
# 54/54 - 0s - loss: 1.1597e-04 - 100ms/epoch - 2ms/step
# Epoch 100/100
# 54/54 - 0s - loss: 1.2346e-04 - 100ms/epoch - 2ms/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_6 (GRU)                 (None, 1, 50)             8700
#
#  dropout_6 (Dropout)         (None, 1, 50)             0
#
#  gru_7 (GRU)                 (None, 50)                15300
#
#  dropout_7 (Dropout)         (None, 50)                0
#
#  dense_3 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 24,051
# Trainable params: 24,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make predictions
train_pred = model.predict(X_train_reshape)
test_pred = model.predict(X_test_reshape)

# unable to inverse transform values due to original output having 6 features

# calculate RMSE
train_score = np.sqrt(mean_squared_error(y_train, train_pred))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test, test_pred))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 108/108 [==============================] - 1s 783us/step
# 27/27 [==============================] - 0s 816us/step
# Train score: 0.00 RMSE
# Test score: 0.00 RMSE

# %%
dataset_trans = mm.transform(dataset)

# %%
# shift train predictions for plotting
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

# shift test predictions for plotting
test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[len(train_pred) + (look_back*2)+1:len(dataset)-1, :] = test_pred

# plot baseline and predictions
plt.plot(dataset_trans[:,-1])
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()
