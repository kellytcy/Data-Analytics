# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-08-19    49.813290    51.835709    47.800831    49.982655    49.982655
# 2004-08-20    50.316402    54.336334    50.062355    53.952770    53.952770
# 2004-08-23    55.168217    56.528118    54.321388    54.495735    54.495735
# 2004-08-24    55.412300    55.591629    51.591621    52.239197    52.239197
# 2004-08-25    52.284027    53.798351    51.746044    52.802086    52.802086
# ...                 ...          ...          ...          ...          ...
# 2021-10-04  2713.989990  2714.000000  2623.330078  2675.300049  2675.300049
# 2021-10-05  2680.000000  2747.239990  2680.000000  2723.540039  2723.540039
# 2021-10-06  2692.510010  2757.040039  2689.729980  2747.080078  2747.080078
# 2021-10-07  2777.260010  2803.089111  2771.260010  2783.709961  2783.709961
# 2021-10-08  2798.120117  2806.340088  2788.586914  2801.120117  2801.120117
#
#               Volume
# Date
# 2004-08-19  44871361
# 2004-08-20  22942874
# 2004-08-23  18342897
# 2004-08-24  15319808
# 2004-08-25   9232276
# ...              ...
# 2021-10-04   1576500
# 2021-10-05   1206300
# 2021-10-06    988200
# 2021-10-07    912500
# 2021-10-08    946200
#
# [4316 rows x 6 columns]

# %%
dataset = df['Open']
dataset = dataset.values.astype('float32')
tf.random.set_seed(10)

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [],[]
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
dataset = dataset.reshape(-1,1)
mm = MinMaxScaler(feature_range=(0,1))

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# %%
look_back = 1
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)
y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
X_train = mm.fit_transform(X_train)
y_train = mm.fit_transform(y_train)

X_test = mm.transform(X_test)
y_test = mm.transform(y_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(1, 1), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train, y_train, epochs=100, batch_size = 64, verbose = 2)
# Out:
# Epoch 1/100
# 54/54 - 2s - loss: 0.0826 - 2s/epoch - 46ms/step
# Epoch 2/100
# 54/54 - 0s - loss: 0.0195 - 101ms/epoch - 2ms/step
# Epoch 3/100
# 54/54 - 0s - loss: 0.0038 - 101ms/epoch - 2ms/step
# Epoch 4/100
# 54/54 - 0s - loss: 0.0019 - 106ms/epoch - 2ms/step
# Epoch 5/100
# 54/54 - 0s - loss: 0.0018 - 101ms/epoch - 2ms/step
# Epoch 6/100
# 54/54 - 0s - loss: 0.0017 - 113ms/epoch - 2ms/step
# Epoch 7/100
# 54/54 - 0s - loss: 0.0017 - 110ms/epoch - 2ms/step
# Epoch 8/100
# 54/54 - 0s - loss: 0.0015 - 102ms/epoch - 2ms/step
# Epoch 9/100
# 54/54 - 0s - loss: 0.0014 - 102ms/epoch - 2ms/step
# Epoch 10/100
# 54/54 - 0s - loss: 0.0014 - 106ms/epoch - 2ms/step
# Epoch 11/100
# 54/54 - 0s - loss: 0.0013 - 106ms/epoch - 2ms/step
# Epoch 12/100
# 54/54 - 0s - loss: 0.0012 - 105ms/epoch - 2ms/step
# Epoch 13/100
# 54/54 - 0s - loss: 0.0012 - 106ms/epoch - 2ms/step
# Epoch 14/100
# 54/54 - 0s - loss: 0.0012 - 106ms/epoch - 2ms/step
# Epoch 15/100
# 54/54 - 0s - loss: 0.0012 - 99ms/epoch - 2ms/step
# Epoch 16/100
# 54/54 - 0s - loss: 0.0011 - 103ms/epoch - 2ms/step
# Epoch 17/100
# 54/54 - 0s - loss: 0.0011 - 105ms/epoch - 2ms/step
# Epoch 18/100
# 54/54 - 0s - loss: 0.0011 - 103ms/epoch - 2ms/step
# Epoch 19/100
# 54/54 - 0s - loss: 9.9109e-04 - 100ms/epoch - 2ms/step
# Epoch 20/100
# 54/54 - 0s - loss: 9.5764e-04 - 103ms/epoch - 2ms/step
# Epoch 21/100
# 54/54 - 0s - loss: 0.0010 - 102ms/epoch - 2ms/step
# Epoch 22/100
# 54/54 - 0s - loss: 8.8732e-04 - 101ms/epoch - 2ms/step
# Epoch 23/100
# 54/54 - 0s - loss: 9.2015e-04 - 101ms/epoch - 2ms/step
# Epoch 24/100
# 54/54 - 0s - loss: 9.2652e-04 - 102ms/epoch - 2ms/step
# Epoch 25/100
# 54/54 - 0s - loss: 8.8954e-04 - 104ms/epoch - 2ms/step
# Epoch 26/100
# 54/54 - 0s - loss: 8.9978e-04 - 101ms/epoch - 2ms/step
# Epoch 27/100
# 54/54 - 0s - loss: 9.1251e-04 - 104ms/epoch - 2ms/step
# Epoch 28/100
# 54/54 - 0s - loss: 8.6671e-04 - 104ms/epoch - 2ms/step
# Epoch 29/100
# 54/54 - 0s - loss: 8.5383e-04 - 103ms/epoch - 2ms/step
# Epoch 30/100
# 54/54 - 0s - loss: 9.6386e-04 - 102ms/epoch - 2ms/step
# Epoch 31/100
# 54/54 - 0s - loss: 8.3759e-04 - 107ms/epoch - 2ms/step
# Epoch 32/100
# 54/54 - 0s - loss: 8.6751e-04 - 105ms/epoch - 2ms/step
# Epoch 33/100
# 54/54 - 0s - loss: 8.5732e-04 - 108ms/epoch - 2ms/step
# Epoch 34/100
# 54/54 - 0s - loss: 7.9798e-04 - 103ms/epoch - 2ms/step
# Epoch 35/100
# 54/54 - 0s - loss: 8.4211e-04 - 104ms/epoch - 2ms/step
# Epoch 36/100
# 54/54 - 0s - loss: 7.4452e-04 - 103ms/epoch - 2ms/step
# Epoch 37/100
# 54/54 - 0s - loss: 7.3967e-04 - 99ms/epoch - 2ms/step
# Epoch 38/100
# 54/54 - 0s - loss: 8.1673e-04 - 102ms/epoch - 2ms/step
# Epoch 39/100
# 54/54 - 0s - loss: 8.3240e-04 - 104ms/epoch - 2ms/step
# Epoch 40/100
# 54/54 - 0s - loss: 7.4563e-04 - 103ms/epoch - 2ms/step
# Epoch 41/100
# 54/54 - 0s - loss: 8.1357e-04 - 106ms/epoch - 2ms/step
# Epoch 42/100
# 54/54 - 0s - loss: 6.6775e-04 - 104ms/epoch - 2ms/step
# Epoch 43/100
# 54/54 - 0s - loss: 6.8921e-04 - 103ms/epoch - 2ms/step
# Epoch 44/100
# 54/54 - 0s - loss: 7.6795e-04 - 103ms/epoch - 2ms/step
# Epoch 45/100
# 54/54 - 0s - loss: 7.4127e-04 - 102ms/epoch - 2ms/step
# Epoch 46/100
# 54/54 - 0s - loss: 7.6763e-04 - 108ms/epoch - 2ms/step
# Epoch 47/100
# 54/54 - 0s - loss: 7.5570e-04 - 99ms/epoch - 2ms/step
# Epoch 48/100
# 54/54 - 0s - loss: 7.0245e-04 - 101ms/epoch - 2ms/step
# Epoch 49/100
# 54/54 - 0s - loss: 7.2254e-04 - 102ms/epoch - 2ms/step
# Epoch 50/100
# 54/54 - 0s - loss: 6.8218e-04 - 103ms/epoch - 2ms/step
# Epoch 51/100
# 54/54 - 0s - loss: 7.3413e-04 - 103ms/epoch - 2ms/step
# Epoch 52/100
# 54/54 - 0s - loss: 6.8690e-04 - 107ms/epoch - 2ms/step
# Epoch 53/100
# 54/54 - 0s - loss: 7.3498e-04 - 105ms/epoch - 2ms/step
# Epoch 54/100
# 54/54 - 0s - loss: 7.0236e-04 - 107ms/epoch - 2ms/step
# Epoch 55/100
# 54/54 - 0s - loss: 7.4791e-04 - 104ms/epoch - 2ms/step
# Epoch 56/100
# 54/54 - 0s - loss: 6.8769e-04 - 101ms/epoch - 2ms/step
# Epoch 57/100
# 54/54 - 0s - loss: 6.7602e-04 - 101ms/epoch - 2ms/step
# Epoch 58/100
# 54/54 - 0s - loss: 6.9799e-04 - 101ms/epoch - 2ms/step
# Epoch 59/100
# 54/54 - 0s - loss: 7.1209e-04 - 100ms/epoch - 2ms/step
# Epoch 60/100
# 54/54 - 0s - loss: 7.2162e-04 - 106ms/epoch - 2ms/step
# Epoch 61/100
# 54/54 - 0s - loss: 6.1239e-04 - 100ms/epoch - 2ms/step
# Epoch 62/100
# 54/54 - 0s - loss: 6.4787e-04 - 99ms/epoch - 2ms/step
# Epoch 63/100
# 54/54 - 0s - loss: 6.7807e-04 - 101ms/epoch - 2ms/step
# Epoch 64/100
# 54/54 - 0s - loss: 6.4117e-04 - 100ms/epoch - 2ms/step
# Epoch 65/100
# 54/54 - 0s - loss: 6.0128e-04 - 103ms/epoch - 2ms/step
# Epoch 66/100
# 54/54 - 0s - loss: 6.5854e-04 - 102ms/epoch - 2ms/step
# Epoch 67/100
# 54/54 - 0s - loss: 6.3610e-04 - 105ms/epoch - 2ms/step
# Epoch 68/100
# 54/54 - 0s - loss: 6.1862e-04 - 127ms/epoch - 2ms/step
# Epoch 69/100
# 54/54 - 0s - loss: 6.4139e-04 - 127ms/epoch - 2ms/step
# Epoch 70/100
# 54/54 - 0s - loss: 6.5814e-04 - 102ms/epoch - 2ms/step
# Epoch 71/100
# 54/54 - 0s - loss: 5.8254e-04 - 102ms/epoch - 2ms/step
# Epoch 72/100
# 54/54 - 0s - loss: 5.8429e-04 - 103ms/epoch - 2ms/step
# Epoch 73/100
# 54/54 - 0s - loss: 6.0284e-04 - 104ms/epoch - 2ms/step
# Epoch 74/100
# 54/54 - 0s - loss: 6.1389e-04 - 116ms/epoch - 2ms/step
# Epoch 75/100
# 54/54 - 0s - loss: 6.1301e-04 - 131ms/epoch - 2ms/step
# Epoch 76/100
# 54/54 - 0s - loss: 6.1983e-04 - 120ms/epoch - 2ms/step
# Epoch 77/100
# 54/54 - 0s - loss: 6.1438e-04 - 136ms/epoch - 3ms/step
# Epoch 78/100
# 54/54 - 0s - loss: 6.6986e-04 - 134ms/epoch - 2ms/step
# Epoch 79/100
# 54/54 - 0s - loss: 5.7711e-04 - 125ms/epoch - 2ms/step
# Epoch 80/100
# 54/54 - 0s - loss: 6.4645e-04 - 100ms/epoch - 2ms/step
# Epoch 81/100
# 54/54 - 0s - loss: 6.1546e-04 - 101ms/epoch - 2ms/step
# Epoch 82/100
# 54/54 - 0s - loss: 5.9791e-04 - 101ms/epoch - 2ms/step
# Epoch 83/100
# 54/54 - 0s - loss: 5.4710e-04 - 107ms/epoch - 2ms/step
# Epoch 84/100
# 54/54 - 0s - loss: 6.1827e-04 - 99ms/epoch - 2ms/step
# Epoch 85/100
# 54/54 - 0s - loss: 5.7548e-04 - 100ms/epoch - 2ms/step
# Epoch 86/100
# 54/54 - 0s - loss: 6.1837e-04 - 99ms/epoch - 2ms/step
# Epoch 87/100
# 54/54 - 0s - loss: 5.7452e-04 - 100ms/epoch - 2ms/step
# Epoch 88/100
# 54/54 - 0s - loss: 5.8737e-04 - 105ms/epoch - 2ms/step
# Epoch 89/100
# 54/54 - 0s - loss: 5.7568e-04 - 103ms/epoch - 2ms/step
# Epoch 90/100
# 54/54 - 0s - loss: 5.2911e-04 - 101ms/epoch - 2ms/step
# Epoch 91/100
# 54/54 - 0s - loss: 5.8619e-04 - 102ms/epoch - 2ms/step
# Epoch 92/100
# 54/54 - 0s - loss: 5.7992e-04 - 120ms/epoch - 2ms/step
# Epoch 93/100
# 54/54 - 0s - loss: 5.8187e-04 - 132ms/epoch - 2ms/step
# Epoch 94/100
# 54/54 - 0s - loss: 5.6682e-04 - 105ms/epoch - 2ms/step
# Epoch 95/100
# 54/54 - 0s - loss: 5.8587e-04 - 109ms/epoch - 2ms/step
# Epoch 96/100
# 54/54 - 0s - loss: 5.8330e-04 - 102ms/epoch - 2ms/step
# Epoch 97/100
# 54/54 - 0s - loss: 6.0999e-04 - 103ms/epoch - 2ms/step
# Epoch 98/100
# 54/54 - 0s - loss: 5.6862e-04 - 102ms/epoch - 2ms/step
# Epoch 99/100
# 54/54 - 0s - loss: 5.8534e-04 - 103ms/epoch - 2ms/step
# Epoch 100/100
# 54/54 - 0s - loss: 5.8392e-04 - 103ms/epoch - 2ms/step

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred = mm.inverse_transform(train_pred)
y_train = mm.inverse_transform(y_train)

test_pred = mm.inverse_transform(test_pred)
y_test = mm.inverse_transform(y_test)

train_score = np.sqrt(mean_squared_error(y_train[:,0], train_pred[:,0]))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test[:,0], test_pred[:,0]))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 108/108 [==============================] - 1s 785us/step
# 27/27 [==============================] - 0s 846us/step
# Train score: 7.78 RMSE
# Test score: 241.69 RMSE

# %%
look_back = 1
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[len(train_pred) + (look_back*2):len(dataset)-2, :] = test_pred

plt.plot(dataset)
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()

# %% [markdown]
# ### Increasing timesteps

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
dataset = df['Open']
dataset = dataset.values.astype('float32')
tf.random.set_seed(10)

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [],[]
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
dataset = dataset.reshape(-1,1)
mm = MinMaxScaler(feature_range=(0,1))

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# %%
train = mm.fit_transform(train)
test = mm.transform(test)

# %%
look_back = 3
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
X_train.shape
# Out:
# (3448, 3)

# %%
y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(1, look_back), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train, y_train, epochs=100, batch_size = 64, verbose = 2)
# Out:
# Epoch 1/100
# 54/54 - 3s - loss: 0.0752 - 3s/epoch - 47ms/step
# Epoch 2/100
# 54/54 - 0s - loss: 0.0089 - 103ms/epoch - 2ms/step
# Epoch 3/100
# 54/54 - 0s - loss: 0.0025 - 98ms/epoch - 2ms/step
# Epoch 4/100
# 54/54 - 0s - loss: 0.0024 - 102ms/epoch - 2ms/step
# Epoch 5/100
# 54/54 - 0s - loss: 0.0021 - 99ms/epoch - 2ms/step
# Epoch 6/100
# 54/54 - 0s - loss: 0.0019 - 100ms/epoch - 2ms/step
# Epoch 7/100
# 54/54 - 0s - loss: 0.0017 - 103ms/epoch - 2ms/step
# Epoch 8/100
# 54/54 - 0s - loss: 0.0015 - 99ms/epoch - 2ms/step
# Epoch 9/100
# 54/54 - 0s - loss: 0.0016 - 102ms/epoch - 2ms/step
# Epoch 10/100
# 54/54 - 0s - loss: 0.0014 - 104ms/epoch - 2ms/step
# Epoch 11/100
# 54/54 - 0s - loss: 0.0013 - 101ms/epoch - 2ms/step
# Epoch 12/100
# 54/54 - 0s - loss: 0.0014 - 101ms/epoch - 2ms/step
# Epoch 13/100
# 54/54 - 0s - loss: 0.0012 - 102ms/epoch - 2ms/step
# Epoch 14/100
# 54/54 - 0s - loss: 0.0012 - 99ms/epoch - 2ms/step
# Epoch 15/100
# 54/54 - 0s - loss: 0.0011 - 103ms/epoch - 2ms/step
# Epoch 16/100
# 54/54 - 0s - loss: 0.0012 - 103ms/epoch - 2ms/step
# Epoch 17/100
# 54/54 - 0s - loss: 0.0012 - 101ms/epoch - 2ms/step
# Epoch 18/100
# 54/54 - 0s - loss: 0.0010 - 101ms/epoch - 2ms/step
# Epoch 19/100
# 54/54 - 0s - loss: 0.0011 - 98ms/epoch - 2ms/step
# Epoch 20/100
# 54/54 - 0s - loss: 0.0010 - 104ms/epoch - 2ms/step
# Epoch 21/100
# 54/54 - 0s - loss: 0.0010 - 102ms/epoch - 2ms/step
# Epoch 22/100
# 54/54 - 0s - loss: 9.8162e-04 - 103ms/epoch - 2ms/step
# Epoch 23/100
# 54/54 - 0s - loss: 0.0011 - 102ms/epoch - 2ms/step
# Epoch 24/100
# 54/54 - 0s - loss: 9.7195e-04 - 101ms/epoch - 2ms/step
# Epoch 25/100
# 54/54 - 0s - loss: 0.0010 - 104ms/epoch - 2ms/step
# Epoch 26/100
# 54/54 - 0s - loss: 9.6794e-04 - 104ms/epoch - 2ms/step
# Epoch 27/100
# 54/54 - 0s - loss: 8.6861e-04 - 100ms/epoch - 2ms/step
# Epoch 28/100
# 54/54 - 0s - loss: 8.9536e-04 - 100ms/epoch - 2ms/step
# Epoch 29/100
# 54/54 - 0s - loss: 9.9716e-04 - 101ms/epoch - 2ms/step
# Epoch 30/100
# 54/54 - 0s - loss: 9.2765e-04 - 110ms/epoch - 2ms/step
# Epoch 31/100
# 54/54 - 0s - loss: 8.7375e-04 - 100ms/epoch - 2ms/step
# Epoch 32/100
# 54/54 - 0s - loss: 8.8733e-04 - 102ms/epoch - 2ms/step
# Epoch 33/100
# 54/54 - 0s - loss: 8.8574e-04 - 99ms/epoch - 2ms/step
# Epoch 34/100
# 54/54 - 0s - loss: 8.3045e-04 - 102ms/epoch - 2ms/step
# Epoch 35/100
# 54/54 - 0s - loss: 8.2711e-04 - 104ms/epoch - 2ms/step
# Epoch 36/100
# 54/54 - 0s - loss: 8.5839e-04 - 103ms/epoch - 2ms/step
# Epoch 37/100
# 54/54 - 0s - loss: 8.4624e-04 - 100ms/epoch - 2ms/step
# Epoch 38/100
# 54/54 - 0s - loss: 8.2971e-04 - 101ms/epoch - 2ms/step
# Epoch 39/100
# 54/54 - 0s - loss: 8.4291e-04 - 99ms/epoch - 2ms/step
# Epoch 40/100
# 54/54 - 0s - loss: 8.1328e-04 - 103ms/epoch - 2ms/step
# Epoch 41/100
# 54/54 - 0s - loss: 8.5853e-04 - 102ms/epoch - 2ms/step
# Epoch 42/100
# 54/54 - 0s - loss: 8.1397e-04 - 101ms/epoch - 2ms/step
# Epoch 43/100
# 54/54 - 0s - loss: 7.8489e-04 - 100ms/epoch - 2ms/step
# Epoch 44/100
# 54/54 - 0s - loss: 6.9607e-04 - 99ms/epoch - 2ms/step
# Epoch 45/100
# 54/54 - 0s - loss: 7.2081e-04 - 102ms/epoch - 2ms/step
# Epoch 46/100
# 54/54 - 0s - loss: 7.8547e-04 - 101ms/epoch - 2ms/step
# Epoch 47/100
# 54/54 - 0s - loss: 7.3177e-04 - 101ms/epoch - 2ms/step
# Epoch 48/100
# 54/54 - 0s - loss: 7.0940e-04 - 98ms/epoch - 2ms/step
# Epoch 49/100
# 54/54 - 0s - loss: 7.4421e-04 - 105ms/epoch - 2ms/step
# Epoch 50/100
# 54/54 - 0s - loss: 7.6097e-04 - 103ms/epoch - 2ms/step
# Epoch 51/100
# 54/54 - 0s - loss: 6.7847e-04 - 102ms/epoch - 2ms/step
# Epoch 52/100
# 54/54 - 0s - loss: 6.5028e-04 - 102ms/epoch - 2ms/step
# Epoch 53/100
# 54/54 - 0s - loss: 6.9040e-04 - 99ms/epoch - 2ms/step
# Epoch 54/100
# 54/54 - 0s - loss: 7.0887e-04 - 104ms/epoch - 2ms/step
# Epoch 55/100
# 54/54 - 0s - loss: 6.9687e-04 - 100ms/epoch - 2ms/step
# Epoch 56/100
# 54/54 - 0s - loss: 6.9249e-04 - 98ms/epoch - 2ms/step
# Epoch 57/100
# 54/54 - 0s - loss: 6.9159e-04 - 97ms/epoch - 2ms/step
# Epoch 58/100
# 54/54 - 0s - loss: 6.9663e-04 - 94ms/epoch - 2ms/step
# Epoch 59/100
# 54/54 - 0s - loss: 6.3632e-04 - 97ms/epoch - 2ms/step
# Epoch 60/100
# 54/54 - 0s - loss: 6.6786e-04 - 123ms/epoch - 2ms/step
# Epoch 61/100
# 54/54 - 0s - loss: 6.9007e-04 - 128ms/epoch - 2ms/step
# Epoch 62/100
# 54/54 - 0s - loss: 6.0420e-04 - 94ms/epoch - 2ms/step
# Epoch 63/100
# 54/54 - 0s - loss: 6.6658e-04 - 97ms/epoch - 2ms/step
# Epoch 64/100
# 54/54 - 0s - loss: 6.4462e-04 - 99ms/epoch - 2ms/step
# Epoch 65/100
# 54/54 - 0s - loss: 6.5973e-04 - 98ms/epoch - 2ms/step
# Epoch 66/100
# 54/54 - 0s - loss: 6.3420e-04 - 99ms/epoch - 2ms/step
# Epoch 67/100
# 54/54 - 0s - loss: 6.2120e-04 - 98ms/epoch - 2ms/step
# Epoch 68/100
# 54/54 - 0s - loss: 6.5629e-04 - 96ms/epoch - 2ms/step
# Epoch 69/100
# 54/54 - 0s - loss: 6.2712e-04 - 101ms/epoch - 2ms/step
# Epoch 70/100
# 54/54 - 0s - loss: 6.0949e-04 - 96ms/epoch - 2ms/step
# Epoch 71/100
# 54/54 - 0s - loss: 6.2303e-04 - 99ms/epoch - 2ms/step
# Epoch 72/100
# 54/54 - 0s - loss: 6.3459e-04 - 100ms/epoch - 2ms/step
# Epoch 73/100
# 54/54 - 0s - loss: 5.7068e-04 - 99ms/epoch - 2ms/step
# Epoch 74/100
# 54/54 - 0s - loss: 6.1291e-04 - 99ms/epoch - 2ms/step
# Epoch 75/100
# 54/54 - 0s - loss: 6.0418e-04 - 98ms/epoch - 2ms/step
# Epoch 76/100
# 54/54 - 0s - loss: 5.9943e-04 - 98ms/epoch - 2ms/step
# Epoch 77/100
# 54/54 - 0s - loss: 6.7368e-04 - 96ms/epoch - 2ms/step
# Epoch 78/100
# 54/54 - 0s - loss: 5.8637e-04 - 108ms/epoch - 2ms/step
# Epoch 79/100
# 54/54 - 0s - loss: 6.0180e-04 - 106ms/epoch - 2ms/step
# Epoch 80/100
# 54/54 - 0s - loss: 5.2497e-04 - 102ms/epoch - 2ms/step
# Epoch 81/100
# 54/54 - 0s - loss: 6.1111e-04 - 105ms/epoch - 2ms/step
# Epoch 82/100
# 54/54 - 0s - loss: 5.7699e-04 - 105ms/epoch - 2ms/step
# Epoch 83/100
# 54/54 - 0s - loss: 6.1318e-04 - 98ms/epoch - 2ms/step
# Epoch 84/100
# 54/54 - 0s - loss: 5.8028e-04 - 103ms/epoch - 2ms/step
# Epoch 85/100
# 54/54 - 0s - loss: 6.1301e-04 - 97ms/epoch - 2ms/step
# Epoch 86/100
# 54/54 - 0s - loss: 6.1454e-04 - 96ms/epoch - 2ms/step
# Epoch 87/100
# 54/54 - 0s - loss: 5.6171e-04 - 102ms/epoch - 2ms/step
# Epoch 88/100
# 54/54 - 0s - loss: 5.7432e-04 - 106ms/epoch - 2ms/step
# Epoch 89/100
# 54/54 - 0s - loss: 5.6654e-04 - 111ms/epoch - 2ms/step
# Epoch 90/100
# 54/54 - 0s - loss: 5.8351e-04 - 94ms/epoch - 2ms/step
# Epoch 91/100
# 54/54 - 0s - loss: 5.8311e-04 - 111ms/epoch - 2ms/step
# Epoch 92/100
# 54/54 - 0s - loss: 6.0662e-04 - 98ms/epoch - 2ms/step
# Epoch 93/100
# 54/54 - 0s - loss: 6.1322e-04 - 102ms/epoch - 2ms/step
# Epoch 94/100
# 54/54 - 0s - loss: 5.3212e-04 - 100ms/epoch - 2ms/step
# Epoch 95/100
# 54/54 - 0s - loss: 5.6959e-04 - 97ms/epoch - 2ms/step
# Epoch 96/100
# 54/54 - 0s - loss: 5.8171e-04 - 96ms/epoch - 2ms/step
# Epoch 97/100
# 54/54 - 0s - loss: 6.0664e-04 - 102ms/epoch - 2ms/step
# Epoch 98/100
# 54/54 - 0s - loss: 5.4476e-04 - 100ms/epoch - 2ms/step
# Epoch 99/100
# 54/54 - 0s - loss: 5.3887e-04 - 103ms/epoch - 2ms/step
# Epoch 100/100
# 54/54 - 0s - loss: 5.9618e-04 - 100ms/epoch - 2ms/step

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred = mm.inverse_transform(train_pred)
y_train = mm.inverse_transform(y_train)

test_pred = mm.inverse_transform(test_pred)
y_test = mm.inverse_transform(y_test)

train_score = np.sqrt(mean_squared_error(y_train[:,0], train_pred[:,0]))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test[:,0], test_pred[:,0]))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 108/108 [==============================] - 1s 747us/step
# 27/27 [==============================] - 0s 885us/step
# Train score: 10.36 RMSE
# Test score: 504.72 RMSE

# %%
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[len(train_pred) + (look_back*2):len(dataset)-2, :] = test_pred

plt.plot(dataset)
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()

# %% [markdown]
# ### Multiple features

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
dataset = df.values.astype('float32')
tf.random.set_seed(10)

mm = MinMaxScaler(feature_range=(0,1))

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# %%
train = mm.fit_transform(train)
test = mm.transform(test)

# %%
train
# Out:
# array([[3.5772845e-04, 1.0171272e-03, 0.0000000e+00, 1.4599040e-04,
#         1.4599040e-04, 5.4357713e-01],
#        [8.0378354e-04, 3.2179765e-03, 2.0117126e-03, 3.6717802e-03,
#         3.6717802e-03, 2.7788585e-01],
#        [5.1053390e-03, 5.1470064e-03, 5.8002844e-03, 4.1539781e-03,
#         4.1539781e-03, 2.2215134e-01],
#        ...,
#        [8.6769450e-01, 8.7106174e-01, 8.6736101e-01, 8.6549103e-01,
#         8.6549103e-01, 1.9327592e-02],
#        [8.5962659e-01, 8.6163211e-01, 8.5261244e-01, 8.6490488e-01,
#         8.6490488e-01, 2.1896239e-02],
#        [8.5776478e-01, 8.7820917e-01, 8.6205047e-01, 8.8665396e-01,
#         8.8665396e-01, 2.3393810e-02]], dtype=float32)

# %%
y_train = train[:,0]
y_test = test[:,0]

# %%
def create_dataset_features (dataset, look_back=1):
    dataX = np.ones(shape=(1, 6))
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), :]
        dataX = np.vstack((dataX, a))
    return np.array(dataX)

# %%
def create_test (dataset, look_back=1):
    dataY = np.ones(shape=(1))
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back)]
        dataY = np.vstack((dataY, a))
    return np.array(dataY)

# %%
look_back = 1
X_train = create_dataset_features(train, look_back)
X_test = create_dataset_features(test, look_back)
y_train = create_test(y_train, look_back)
y_test = create_test(y_test, look_back)

# %%
X_train = np.delete(X_train, 0, 0)
y_train = np.delete(y_train, 0, 0)
X_test = np.delete(X_test, 0, 0)
y_test = np.delete(y_test, 0, 0)

# %%
X_train_reshape = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test_reshape = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(1, 6), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train_reshape, y_train, epochs=100, batch_size = 64, verbose = 2)
model.summary()
# Out:
# Epoch 1/100
# 54/54 - 2s - loss: 0.0587 - 2s/epoch - 45ms/step
# Epoch 2/100
# 54/54 - 0s - loss: 0.0045 - 93ms/epoch - 2ms/step
# Epoch 3/100
# 54/54 - 0s - loss: 0.0023 - 115ms/epoch - 2ms/step
# Epoch 4/100
# 54/54 - 0s - loss: 0.0020 - 100ms/epoch - 2ms/step
# Epoch 5/100
# 54/54 - 0s - loss: 0.0020 - 102ms/epoch - 2ms/step
# Epoch 6/100
# 54/54 - 0s - loss: 0.0018 - 106ms/epoch - 2ms/step
# Epoch 7/100
# 54/54 - 0s - loss: 0.0018 - 105ms/epoch - 2ms/step
# Epoch 8/100
# 54/54 - 0s - loss: 0.0016 - 109ms/epoch - 2ms/step
# Epoch 9/100
# 54/54 - 0s - loss: 0.0014 - 92ms/epoch - 2ms/step
# Epoch 10/100
# 54/54 - 0s - loss: 0.0015 - 121ms/epoch - 2ms/step
# Epoch 11/100
# 54/54 - 0s - loss: 0.0013 - 100ms/epoch - 2ms/step
# Epoch 12/100
# 54/54 - 0s - loss: 0.0012 - 100ms/epoch - 2ms/step
# Epoch 13/100
# 54/54 - 0s - loss: 0.0012 - 109ms/epoch - 2ms/step
# Epoch 14/100
# 54/54 - 0s - loss: 0.0012 - 103ms/epoch - 2ms/step
# Epoch 15/100
# 54/54 - 0s - loss: 0.0012 - 110ms/epoch - 2ms/step
# Epoch 16/100
# 54/54 - 0s - loss: 0.0011 - 109ms/epoch - 2ms/step
# Epoch 17/100
# 54/54 - 0s - loss: 0.0011 - 113ms/epoch - 2ms/step
# Epoch 18/100
# 54/54 - 0s - loss: 0.0011 - 99ms/epoch - 2ms/step
# Epoch 19/100
# 54/54 - 0s - loss: 0.0011 - 102ms/epoch - 2ms/step
# Epoch 20/100
# 54/54 - 0s - loss: 0.0010 - 113ms/epoch - 2ms/step
# Epoch 21/100
# 54/54 - 0s - loss: 0.0011 - 102ms/epoch - 2ms/step
# Epoch 22/100
# 54/54 - 0s - loss: 8.6508e-04 - 111ms/epoch - 2ms/step
# Epoch 23/100
# 54/54 - 0s - loss: 9.2531e-04 - 105ms/epoch - 2ms/step
# Epoch 24/100
# 54/54 - 0s - loss: 9.4307e-04 - 101ms/epoch - 2ms/step
# Epoch 25/100
# 54/54 - 0s - loss: 8.9543e-04 - 100ms/epoch - 2ms/step
# Epoch 26/100
# 54/54 - 0s - loss: 8.9993e-04 - 117ms/epoch - 2ms/step
# Epoch 27/100
# 54/54 - 0s - loss: 8.8647e-04 - 112ms/epoch - 2ms/step
# Epoch 28/100
# 54/54 - 0s - loss: 8.5421e-04 - 104ms/epoch - 2ms/step
# Epoch 29/100
# 54/54 - 0s - loss: 8.1874e-04 - 100ms/epoch - 2ms/step
# Epoch 30/100
# 54/54 - 0s - loss: 9.4988e-04 - 111ms/epoch - 2ms/step
# Epoch 31/100
# 54/54 - 0s - loss: 8.2279e-04 - 108ms/epoch - 2ms/step
# Epoch 32/100
# 54/54 - 0s - loss: 8.1359e-04 - 115ms/epoch - 2ms/step
# Epoch 33/100
# 54/54 - 0s - loss: 8.0815e-04 - 100ms/epoch - 2ms/step
# Epoch 34/100
# 54/54 - 0s - loss: 7.6724e-04 - 102ms/epoch - 2ms/step
# Epoch 35/100
# 54/54 - 0s - loss: 8.2780e-04 - 115ms/epoch - 2ms/step
# Epoch 36/100
# 54/54 - 0s - loss: 6.9058e-04 - 101ms/epoch - 2ms/step
# Epoch 37/100
# 54/54 - 0s - loss: 7.0962e-04 - 115ms/epoch - 2ms/step
# Epoch 38/100
# 54/54 - 0s - loss: 7.7645e-04 - 102ms/epoch - 2ms/step
# Epoch 39/100
# 54/54 - 0s - loss: 7.6415e-04 - 98ms/epoch - 2ms/step
# Epoch 40/100
# 54/54 - 0s - loss: 6.8102e-04 - 101ms/epoch - 2ms/step
# Epoch 41/100
# 54/54 - 0s - loss: 7.7879e-04 - 103ms/epoch - 2ms/step
# Epoch 42/100
# 54/54 - 0s - loss: 6.1155e-04 - 110ms/epoch - 2ms/step
# Epoch 43/100
# 54/54 - 0s - loss: 6.4060e-04 - 106ms/epoch - 2ms/step
# Epoch 44/100
# 54/54 - 0s - loss: 7.2834e-04 - 99ms/epoch - 2ms/step
# Epoch 45/100
# 54/54 - 0s - loss: 7.0309e-04 - 118ms/epoch - 2ms/step
# Epoch 46/100
# 54/54 - 0s - loss: 7.2708e-04 - 133ms/epoch - 2ms/step
# Epoch 47/100
# 54/54 - 0s - loss: 7.2329e-04 - 112ms/epoch - 2ms/step
# Epoch 48/100
# 54/54 - 0s - loss: 6.5536e-04 - 100ms/epoch - 2ms/step
# Epoch 49/100
# 54/54 - 0s - loss: 6.6727e-04 - 116ms/epoch - 2ms/step
# Epoch 50/100
# 54/54 - 0s - loss: 6.2936e-04 - 100ms/epoch - 2ms/step
# Epoch 51/100
# 54/54 - 0s - loss: 6.7783e-04 - 117ms/epoch - 2ms/step
# Epoch 52/100
# 54/54 - 0s - loss: 6.1303e-04 - 100ms/epoch - 2ms/step
# Epoch 53/100
# 54/54 - 0s - loss: 6.4747e-04 - 115ms/epoch - 2ms/step
# Epoch 54/100
# 54/54 - 0s - loss: 6.3467e-04 - 100ms/epoch - 2ms/step
# Epoch 55/100
# 54/54 - 0s - loss: 6.6683e-04 - 115ms/epoch - 2ms/step
# Epoch 56/100
# 54/54 - 0s - loss: 6.0785e-04 - 103ms/epoch - 2ms/step
# Epoch 57/100
# 54/54 - 0s - loss: 6.2059e-04 - 101ms/epoch - 2ms/step
# Epoch 58/100
# 54/54 - 0s - loss: 6.1934e-04 - 98ms/epoch - 2ms/step
# Epoch 59/100
# 54/54 - 0s - loss: 6.2784e-04 - 119ms/epoch - 2ms/step
# Epoch 60/100
# 54/54 - 0s - loss: 6.6220e-04 - 99ms/epoch - 2ms/step
# Epoch 61/100
# 54/54 - 0s - loss: 5.7635e-04 - 99ms/epoch - 2ms/step
# Epoch 62/100
# 54/54 - 0s - loss: 6.0419e-04 - 117ms/epoch - 2ms/step
# Epoch 63/100
# 54/54 - 0s - loss: 5.8642e-04 - 100ms/epoch - 2ms/step
# Epoch 64/100
# 54/54 - 0s - loss: 5.7471e-04 - 98ms/epoch - 2ms/step
# Epoch 65/100
# 54/54 - 0s - loss: 5.4710e-04 - 118ms/epoch - 2ms/step
# Epoch 66/100
# 54/54 - 0s - loss: 5.9863e-04 - 103ms/epoch - 2ms/step
# Epoch 67/100
# 54/54 - 0s - loss: 5.7402e-04 - 113ms/epoch - 2ms/step
# Epoch 68/100
# 54/54 - 0s - loss: 5.6237e-04 - 102ms/epoch - 2ms/step
# Epoch 69/100
# 54/54 - 0s - loss: 6.0515e-04 - 132ms/epoch - 2ms/step
# Epoch 70/100
# 54/54 - 0s - loss: 5.9133e-04 - 138ms/epoch - 3ms/step
# Epoch 71/100
# 54/54 - 0s - loss: 5.3366e-04 - 131ms/epoch - 2ms/step
# Epoch 72/100
# 54/54 - 0s - loss: 5.0895e-04 - 99ms/epoch - 2ms/step
# Epoch 73/100
# 54/54 - 0s - loss: 5.2636e-04 - 109ms/epoch - 2ms/step
# Epoch 74/100
# 54/54 - 0s - loss: 5.7490e-04 - 102ms/epoch - 2ms/step
# Epoch 75/100
# 54/54 - 0s - loss: 5.5707e-04 - 101ms/epoch - 2ms/step
# Epoch 76/100
# 54/54 - 0s - loss: 5.5643e-04 - 117ms/epoch - 2ms/step
# Epoch 77/100
# 54/54 - 0s - loss: 5.6018e-04 - 95ms/epoch - 2ms/step
# Epoch 78/100
# 54/54 - 0s - loss: 6.0694e-04 - 123ms/epoch - 2ms/step
# Epoch 79/100
# 54/54 - 0s - loss: 5.2304e-04 - 97ms/epoch - 2ms/step
# Epoch 80/100
# 54/54 - 0s - loss: 5.7650e-04 - 99ms/epoch - 2ms/step
# Epoch 81/100
# 54/54 - 0s - loss: 5.6110e-04 - 118ms/epoch - 2ms/step
# Epoch 82/100
# 54/54 - 0s - loss: 5.5128e-04 - 98ms/epoch - 2ms/step
# Epoch 83/100
# 54/54 - 0s - loss: 4.8740e-04 - 132ms/epoch - 2ms/step
# Epoch 84/100
# 54/54 - 0s - loss: 5.6257e-04 - 126ms/epoch - 2ms/step
# Epoch 85/100
# 54/54 - 0s - loss: 5.3165e-04 - 124ms/epoch - 2ms/step
# Epoch 86/100
# 54/54 - 0s - loss: 5.7155e-04 - 117ms/epoch - 2ms/step
# Epoch 87/100
# 54/54 - 0s - loss: 5.2013e-04 - 119ms/epoch - 2ms/step
# Epoch 88/100
# 54/54 - 0s - loss: 5.2717e-04 - 117ms/epoch - 2ms/step
# Epoch 89/100
# 54/54 - 0s - loss: 5.0377e-04 - 116ms/epoch - 2ms/step
# Epoch 90/100
# 54/54 - 0s - loss: 4.9476e-04 - 127ms/epoch - 2ms/step
# Epoch 91/100
# 54/54 - 0s - loss: 5.3264e-04 - 120ms/epoch - 2ms/step
# Epoch 92/100
# 54/54 - 0s - loss: 5.1941e-04 - 134ms/epoch - 2ms/step
# Epoch 93/100
# 54/54 - 0s - loss: 5.2272e-04 - 116ms/epoch - 2ms/step
# Epoch 94/100
# 54/54 - 0s - loss: 5.1322e-04 - 110ms/epoch - 2ms/step
# Epoch 95/100
# 54/54 - 0s - loss: 5.4719e-04 - 95ms/epoch - 2ms/step
# Epoch 96/100
# 54/54 - 0s - loss: 5.3385e-04 - 131ms/epoch - 2ms/step
# Epoch 97/100
# 54/54 - 0s - loss: 5.7086e-04 - 133ms/epoch - 2ms/step
# Epoch 98/100
# 54/54 - 0s - loss: 4.9889e-04 - 109ms/epoch - 2ms/step
# Epoch 99/100
# 54/54 - 0s - loss: 5.4983e-04 - 101ms/epoch - 2ms/step
# Epoch 100/100
# 54/54 - 0s - loss: 5.1782e-04 - 115ms/epoch - 2ms/step
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_24 (LSTM)              (None, 1, 50)             11400
#
#  dropout_24 (Dropout)        (None, 1, 50)             0
#
#  lstm_25 (LSTM)              (None, 50)                20200
#
#  dropout_25 (Dropout)        (None, 50)                0
#
#  dense_12 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 31,651
# Trainable params: 31,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make predictions
train_pred = model.predict(X_train_reshape)
test_pred = model.predict(X_test_reshape)

# unable to inverse transform values due to original output having 6 features

# calculate RMSE
train_score = np.sqrt(mean_squared_error(y_train, train_pred))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test, test_pred))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 108/108 [==============================] - 1s 783us/step
# 27/27 [==============================] - 0s 883us/step
# Train score: 0.01 RMSE
# Test score: 0.46 RMSE

# %%
dataset_trans = mm.transform(dataset)

# %%
# shift train predictions for plotting
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

# shift test predictions for plotting
test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[len(train_pred) + (look_back*2)+1:len(dataset)-1, :] = test_pred

# plot baseline and predictions
plt.plot(dataset_trans[:,0])
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()
