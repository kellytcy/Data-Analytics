# %% [markdown]
# # <font color = "red">[READ THIS] Before you start</font>
# Welcome to UpLevel mini-projects! In this series, you're challenged to independently work (with our guidance) with data that you will collect to UpLevel yourself.
#
# We hope you're excited to embark on this adventure.
# ### Warning:
# This isn't just any coding course or programmes, where you receive helper code as you move from one code block to another.
#
# This is when things get <em>real</em>.
#
# In this project, you will receive instructions to execute a task along with an intended outcome. Most importantly, we will provide you with directions you can go to, to pick up code independently and implement it in this notebook.
#
# Don't worry though, we'll be dropping lots of resources you can consult and these readings will contain everything you need to succeed. You can also perform independent research to find answers independently. You just have to read closely and pick out the parts that make most sense.
#
# <strong>We make you do this not because we're lazy bastards but because being able to indepedently find code is a highly underrated skill and that's something all companies look out for.</strong>
#
# If you're really stuck and are on the verge of giving up, we gotchu fam. Head on over to https://www.facebook.com/UpLevelSG/ and post your questions there.
#
# ### What we'll be doing:
# In this project, we will do the following:
#
# 1. Download power plant performance data (Part I)
# 2. Perform exploratory data analysis (Part II)
# 3. Apply machine learning techniques to train a model to predict power plant output (Part III)
#
# ### Expectations:
# We're not going to sugarcoat it - it'll be challenging at times. You have to promise to put in the time and effort to UpLevel yourself.
#
# But we promise you that it'll ultimately be fun and rewarding, and you'll come out of it stronger and more confident than before.

# %% [markdown]
# <div style="background-color: #78E8A3; padding: 20px">
# <h3>Project Scenario</h3>
# <p>You work in a power plant, as a power supervisor.</p>
# <p>After running the plant for a few years, you're interested to see whether you can come up with a model to predict power plant output.</p>
# <p>In this project, you will use your Python skills to achieve that, using recordings of different parts in the power plant.</p>
# </div>

# %% [markdown]
# ### [Optional Reading] Anatomy of a power plant
# Combined cycle power plants (CCPP) are power plants that use gas and steam turbines together to generate electricity, compared to single turbines that only use gas. Waste heat from the gas turbine is used to create steam, which then is used with a steam turbine to generate more electricty.
#
# ![PowerPlantPic.png](attachment:PowerPlantPic.png)
#
# The output of CCPP (PE) depends on several factors, such as ambient temperature (AT), exhaust steam pressure (V), atmospheric pressure (AP), and relative humidity (RH).
#
# We will analyze the data of a particular power plant, and get a predictive model of the power plant at any time.

# %% [markdown]
# ### Step 1: Download your power plant data
# First up, let's retrieve our dataset from UCI Machine Learning Repository.
#
# Download your zip file <a href = "https://archive.ics.uci.edu/ml/machine-learning-databases/00294/CCPP.zip">here</a>, and unzip it into your project folder.

# %% [markdown]
# ### Step 2: Open the Folds5x2_pp.xlsx on Excel
#
# What you will see is that there are five sheets in there, but don't panic - the values in the sheets are identical, except they have been shuffled.
#
# ![ExcelData.png](attachment:ExcelData.png)

# %% [markdown]
# ### Step 3: Import pandas library
# Next, we import the pandas library so that we can read the Excel file.
#
# Import pandas as pd.

# %%
# Step 3: Import pandas library
import pandas as pd

# %% [markdown]
# ### Step 4: Read the Folds5x2_pp.xlsx in CCPP folder
# After you import your library, read the file inside the unzipped CCPP folder.
#
# You see something like this:
#
# ![MainFile.png](attachment:MainFile.png)
#
# Don't be alarmed if you read a different sheet and get a different file than this - the five sheets are the same.

# %%
# Step 5: Read the Excel file into a DataFrame
df = pd.read_excel("Folds5x2_pp.xlsx")
df
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %% [markdown]
# ### Step 5: Count missing values in columns
# It's important to understand whether you have missing data in your DataFrame, as missing values affect modelling.
#
# Count the sum of null values in your columns, to see if we need to work on the missing data.
#
# <strong>Hint: "how to count the NaN values in a column in pandas"</strong>

# %%
# Step 5: Count total missing values in columns
df.isnull().sum()
# Out:
# AT    0
# V     0
# AP    0
# RH    0
# PE    0
# dtype: int64

# %% [markdown]
# ### End of Part I
# Looks like there's no missing value, so we can proceed.
#
# In this Part, we downloaded and briefly examined our data. In our next Part, we will perform exploratory data analysis on the column data.
