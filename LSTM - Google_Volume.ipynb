# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-08-19    49.813290    51.835709    47.800831    49.982655    49.982655
# 2004-08-20    50.316402    54.336334    50.062355    53.952770    53.952770
# 2004-08-23    55.168217    56.528118    54.321388    54.495735    54.495735
# 2004-08-24    55.412300    55.591629    51.591621    52.239197    52.239197
# 2004-08-25    52.284027    53.798351    51.746044    52.802086    52.802086
# ...                 ...          ...          ...          ...          ...
# 2021-10-04  2713.989990  2714.000000  2623.330078  2675.300049  2675.300049
# 2021-10-05  2680.000000  2747.239990  2680.000000  2723.540039  2723.540039
# 2021-10-06  2692.510010  2757.040039  2689.729980  2747.080078  2747.080078
# 2021-10-07  2777.260010  2803.089111  2771.260010  2783.709961  2783.709961
# 2021-10-08  2798.120117  2806.340088  2788.586914  2801.120117  2801.120117
#
#               Volume
# Date
# 2004-08-19  44871361
# 2004-08-20  22942874
# 2004-08-23  18342897
# 2004-08-24  15319808
# 2004-08-25   9232276
# ...              ...
# 2021-10-04   1576500
# 2021-10-05   1206300
# 2021-10-06    988200
# 2021-10-07    912500
# 2021-10-08    946200
#
# [4316 rows x 6 columns]

# %%
dataset = df['Volume']
dataset = dataset.values.astype('float32')
tf.random.set_seed(10)

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [],[]
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
dataset = dataset.reshape(-1,1)
mm = MinMaxScaler(feature_range=(0,1))

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# %%
look_back = 1
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)
y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
X_train = mm.fit_transform(X_train)
y_train = mm.fit_transform(y_train)

X_test = mm.transform(X_test)
y_test = mm.transform(y_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(1, 1), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train, y_train, epochs=100, batch_size = 64, verbose = 2)
# Out:
# Epoch 1/100
# 54/54 - 3s - loss: 0.0109 - 3s/epoch - 51ms/step
# Epoch 2/100
# 54/54 - 0s - loss: 0.0063 - 130ms/epoch - 2ms/step
# Epoch 3/100
# 54/54 - 0s - loss: 0.0037 - 140ms/epoch - 3ms/step
# Epoch 4/100
# 54/54 - 0s - loss: 0.0037 - 111ms/epoch - 2ms/step
# Epoch 5/100
# 54/54 - 0s - loss: 0.0035 - 100ms/epoch - 2ms/step
# Epoch 6/100
# 54/54 - 0s - loss: 0.0035 - 99ms/epoch - 2ms/step
# Epoch 7/100
# 54/54 - 0s - loss: 0.0034 - 110ms/epoch - 2ms/step
# Epoch 8/100
# 54/54 - 0s - loss: 0.0034 - 100ms/epoch - 2ms/step
# Epoch 9/100
# 54/54 - 0s - loss: 0.0034 - 110ms/epoch - 2ms/step
# Epoch 10/100
# 54/54 - 0s - loss: 0.0033 - 100ms/epoch - 2ms/step
# Epoch 11/100
# 54/54 - 0s - loss: 0.0034 - 100ms/epoch - 2ms/step
# Epoch 12/100
# 54/54 - 0s - loss: 0.0033 - 110ms/epoch - 2ms/step
# Epoch 13/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 14/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 15/100
# 54/54 - 0s - loss: 0.0032 - 112ms/epoch - 2ms/step
# Epoch 16/100
# 54/54 - 0s - loss: 0.0032 - 98ms/epoch - 2ms/step
# Epoch 17/100
# 54/54 - 0s - loss: 0.0032 - 111ms/epoch - 2ms/step
# Epoch 18/100
# 54/54 - 0s - loss: 0.0032 - 99ms/epoch - 2ms/step
# Epoch 19/100
# 54/54 - 0s - loss: 0.0031 - 110ms/epoch - 2ms/step
# Epoch 20/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 21/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 22/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 23/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 24/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 25/100
# 54/54 - 0s - loss: 0.0031 - 110ms/epoch - 2ms/step
# Epoch 26/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 27/100
# 54/54 - 0s - loss: 0.0031 - 103ms/epoch - 2ms/step
# Epoch 28/100
# 54/54 - 0s - loss: 0.0031 - 107ms/epoch - 2ms/step
# Epoch 29/100
# 54/54 - 0s - loss: 0.0030 - 97ms/epoch - 2ms/step
# Epoch 30/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 31/100
# 54/54 - 0s - loss: 0.0030 - 107ms/epoch - 2ms/step
# Epoch 32/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 33/100
# 54/54 - 0s - loss: 0.0031 - 99ms/epoch - 2ms/step
# Epoch 34/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 35/100
# 54/54 - 0s - loss: 0.0031 - 110ms/epoch - 2ms/step
# Epoch 36/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 37/100
# 54/54 - 0s - loss: 0.0031 - 110ms/epoch - 2ms/step
# Epoch 38/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 39/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 40/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 41/100
# 54/54 - 0s - loss: 0.0031 - 109ms/epoch - 2ms/step
# Epoch 42/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 43/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 44/100
# 54/54 - 0s - loss: 0.0030 - 110ms/epoch - 2ms/step
# Epoch 45/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 46/100
# 54/54 - 0s - loss: 0.0031 - 110ms/epoch - 2ms/step
# Epoch 47/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 48/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 49/100
# 54/54 - 0s - loss: 0.0031 - 99ms/epoch - 2ms/step
# Epoch 50/100
# 54/54 - 0s - loss: 0.0031 - 111ms/epoch - 2ms/step
# Epoch 51/100
# 54/54 - 0s - loss: 0.0030 - 99ms/epoch - 2ms/step
# Epoch 52/100
# 54/54 - 0s - loss: 0.0030 - 110ms/epoch - 2ms/step
# Epoch 53/100
# 54/54 - 0s - loss: 0.0030 - 99ms/epoch - 2ms/step
# Epoch 54/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 55/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 56/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 57/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 58/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 59/100
# 54/54 - 0s - loss: 0.0031 - 90ms/epoch - 2ms/step
# Epoch 60/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 61/100
# 54/54 - 0s - loss: 0.0031 - 111ms/epoch - 2ms/step
# Epoch 62/100
# 54/54 - 0s - loss: 0.0031 - 98ms/epoch - 2ms/step
# Epoch 63/100
# 54/54 - 0s - loss: 0.0031 - 99ms/epoch - 2ms/step
# Epoch 64/100
# 54/54 - 0s - loss: 0.0030 - 110ms/epoch - 2ms/step
# Epoch 65/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 66/100
# 54/54 - 0s - loss: 0.0031 - 105ms/epoch - 2ms/step
# Epoch 67/100
# 54/54 - 0s - loss: 0.0030 - 103ms/epoch - 2ms/step
# Epoch 68/100
# 54/54 - 0s - loss: 0.0031 - 106ms/epoch - 2ms/step
# Epoch 69/100
# 54/54 - 0s - loss: 0.0031 - 124ms/epoch - 2ms/step
# Epoch 70/100
# 54/54 - 0s - loss: 0.0031 - 119ms/epoch - 2ms/step
# Epoch 71/100
# 54/54 - 0s - loss: 0.0030 - 99ms/epoch - 2ms/step
# Epoch 72/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 73/100
# 54/54 - 0s - loss: 0.0030 - 111ms/epoch - 2ms/step
# Epoch 74/100
# 54/54 - 0s - loss: 0.0031 - 109ms/epoch - 2ms/step
# Epoch 75/100
# 54/54 - 0s - loss: 0.0031 - 111ms/epoch - 2ms/step
# Epoch 76/100
# 54/54 - 0s - loss: 0.0030 - 97ms/epoch - 2ms/step
# Epoch 77/100
# 54/54 - 0s - loss: 0.0030 - 120ms/epoch - 2ms/step
# Epoch 78/100
# 54/54 - 0s - loss: 0.0030 - 107ms/epoch - 2ms/step
# Epoch 79/100
# 54/54 - 0s - loss: 0.0031 - 129ms/epoch - 2ms/step
# Epoch 80/100
# 54/54 - 0s - loss: 0.0030 - 116ms/epoch - 2ms/step
# Epoch 81/100
# 54/54 - 0s - loss: 0.0031 - 95ms/epoch - 2ms/step
# Epoch 82/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 83/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 84/100
# 54/54 - 0s - loss: 0.0030 - 130ms/epoch - 2ms/step
# Epoch 85/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 86/100
# 54/54 - 0s - loss: 0.0030 - 110ms/epoch - 2ms/step
# Epoch 87/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 88/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 89/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 90/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 91/100
# 54/54 - 0s - loss: 0.0030 - 111ms/epoch - 2ms/step
# Epoch 92/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 93/100
# 54/54 - 0s - loss: 0.0030 - 129ms/epoch - 2ms/step
# Epoch 94/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 95/100
# 54/54 - 0s - loss: 0.0031 - 111ms/epoch - 2ms/step
# Epoch 96/100
# 54/54 - 0s - loss: 0.0030 - 98ms/epoch - 2ms/step
# Epoch 97/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 98/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 99/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 100/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred = mm.inverse_transform(train_pred)
y_train = mm.inverse_transform(y_train)

test_pred = mm.inverse_transform(test_pred)
y_test = mm.inverse_transform(y_test)

train_score = np.sqrt(mean_squared_error(y_train[:,0], train_pred[:,0]))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test[:,0], test_pred[:,0]))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 108/108 [==============================] - 1s 751us/step
# 27/27 [==============================] - 0s 1ms/step
# Train score: 4484265.50 RMSE
# Test score: 732391.06 RMSE

# %%
look_back = 1
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[len(train_pred) + (look_back*2):len(dataset)-2, :] = test_pred

plt.plot(dataset)
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()

# %% [markdown]
# ### Increasing timesteps

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
dataset = df['Volume']
dataset = dataset.values.astype('float32')
tf.random.set_seed(10)

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [],[]
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
dataset = dataset.reshape(-1,1)
mm = MinMaxScaler(feature_range=(0,1))

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# %%
train = mm.fit_transform(train)
test = mm.transform(test)

# %%
look_back = 3
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
X_train.shape
# Out:
# (3448, 3)

# %%
y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(1, look_back), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train, y_train, epochs=100, batch_size = 64, verbose = 2)
# Out:
# Epoch 1/100
# 54/54 - 2s - loss: 0.0101 - 2s/epoch - 46ms/step
# Epoch 2/100
# 54/54 - 0s - loss: 0.0046 - 103ms/epoch - 2ms/step
# Epoch 3/100
# 54/54 - 0s - loss: 0.0037 - 108ms/epoch - 2ms/step
# Epoch 4/100
# 54/54 - 0s - loss: 0.0034 - 92ms/epoch - 2ms/step
# Epoch 5/100
# 54/54 - 0s - loss: 0.0034 - 114ms/epoch - 2ms/step
# Epoch 6/100
# 54/54 - 0s - loss: 0.0034 - 88ms/epoch - 2ms/step
# Epoch 7/100
# 54/54 - 0s - loss: 0.0031 - 116ms/epoch - 2ms/step
# Epoch 8/100
# 54/54 - 0s - loss: 0.0033 - 99ms/epoch - 2ms/step
# Epoch 9/100
# 54/54 - 0s - loss: 0.0032 - 85ms/epoch - 2ms/step
# Epoch 10/100
# 54/54 - 0s - loss: 0.0031 - 101ms/epoch - 2ms/step
# Epoch 11/100
# 54/54 - 0s - loss: 0.0032 - 100ms/epoch - 2ms/step
# Epoch 12/100
# 54/54 - 0s - loss: 0.0031 - 109ms/epoch - 2ms/step
# Epoch 13/100
# 54/54 - 0s - loss: 0.0031 - 106ms/epoch - 2ms/step
# Epoch 14/100
# 54/54 - 0s - loss: 0.0031 - 95ms/epoch - 2ms/step
# Epoch 15/100
# 54/54 - 0s - loss: 0.0031 - 95ms/epoch - 2ms/step
# Epoch 16/100
# 54/54 - 0s - loss: 0.0031 - 111ms/epoch - 2ms/step
# Epoch 17/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 18/100
# 54/54 - 0s - loss: 0.0030 - 95ms/epoch - 2ms/step
# Epoch 19/100
# 54/54 - 0s - loss: 0.0031 - 109ms/epoch - 2ms/step
# Epoch 20/100
# 54/54 - 0s - loss: 0.0030 - 98ms/epoch - 2ms/step
# Epoch 21/100
# 54/54 - 0s - loss: 0.0030 - 98ms/epoch - 2ms/step
# Epoch 22/100
# 54/54 - 0s - loss: 0.0031 - 98ms/epoch - 2ms/step
# Epoch 23/100
# 54/54 - 0s - loss: 0.0030 - 102ms/epoch - 2ms/step
# Epoch 24/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 25/100
# 54/54 - 0s - loss: 0.0030 - 115ms/epoch - 2ms/step
# Epoch 26/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 27/100
# 54/54 - 0s - loss: 0.0030 - 99ms/epoch - 2ms/step
# Epoch 28/100
# 54/54 - 0s - loss: 0.0029 - 99ms/epoch - 2ms/step
# Epoch 29/100
# 54/54 - 0s - loss: 0.0030 - 98ms/epoch - 2ms/step
# Epoch 30/100
# 54/54 - 0s - loss: 0.0030 - 103ms/epoch - 2ms/step
# Epoch 31/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 32/100
# 54/54 - 0s - loss: 0.0030 - 117ms/epoch - 2ms/step
# Epoch 33/100
# 54/54 - 0s - loss: 0.0031 - 97ms/epoch - 2ms/step
# Epoch 34/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 35/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 36/100
# 54/54 - 0s - loss: 0.0031 - 117ms/epoch - 2ms/step
# Epoch 37/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 38/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 39/100
# 54/54 - 0s - loss: 0.0030 - 99ms/epoch - 2ms/step
# Epoch 40/100
# 54/54 - 0s - loss: 0.0030 - 97ms/epoch - 2ms/step
# Epoch 41/100
# 54/54 - 0s - loss: 0.0030 - 105ms/epoch - 2ms/step
# Epoch 42/100
# 54/54 - 0s - loss: 0.0029 - 97ms/epoch - 2ms/step
# Epoch 43/100
# 54/54 - 0s - loss: 0.0030 - 102ms/epoch - 2ms/step
# Epoch 44/100
# 54/54 - 0s - loss: 0.0029 - 98ms/epoch - 2ms/step
# Epoch 45/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 46/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 47/100
# 54/54 - 0s - loss: 0.0030 - 99ms/epoch - 2ms/step
# Epoch 48/100
# 54/54 - 0s - loss: 0.0030 - 99ms/epoch - 2ms/step
# Epoch 49/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 50/100
# 54/54 - 0s - loss: 0.0030 - 99ms/epoch - 2ms/step
# Epoch 51/100
# 54/54 - 0s - loss: 0.0030 - 102ms/epoch - 2ms/step
# Epoch 52/100
# 54/54 - 0s - loss: 0.0029 - 100ms/epoch - 2ms/step
# Epoch 53/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 54/100
# 54/54 - 0s - loss: 0.0031 - 100ms/epoch - 2ms/step
# Epoch 55/100
# 54/54 - 0s - loss: 0.0029 - 106ms/epoch - 2ms/step
# Epoch 56/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 57/100
# 54/54 - 0s - loss: 0.0030 - 107ms/epoch - 2ms/step
# Epoch 58/100
# 54/54 - 0s - loss: 0.0029 - 92ms/epoch - 2ms/step
# Epoch 59/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 60/100
# 54/54 - 0s - loss: 0.0030 - 110ms/epoch - 2ms/step
# Epoch 61/100
# 54/54 - 0s - loss: 0.0030 - 88ms/epoch - 2ms/step
# Epoch 62/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 63/100
# 54/54 - 0s - loss: 0.0030 - 107ms/epoch - 2ms/step
# Epoch 64/100
# 54/54 - 0s - loss: 0.0029 - 96ms/epoch - 2ms/step
# Epoch 65/100
# 54/54 - 0s - loss: 0.0030 - 97ms/epoch - 2ms/step
# Epoch 66/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 67/100
# 54/54 - 0s - loss: 0.0030 - 99ms/epoch - 2ms/step
# Epoch 68/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 69/100
# 54/54 - 0s - loss: 0.0029 - 99ms/epoch - 2ms/step
# Epoch 70/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 71/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 72/100
# 54/54 - 0s - loss: 0.0029 - 102ms/epoch - 2ms/step
# Epoch 73/100
# 54/54 - 0s - loss: 0.0030 - 98ms/epoch - 2ms/step
# Epoch 74/100
# 54/54 - 0s - loss: 0.0030 - 99ms/epoch - 2ms/step
# Epoch 75/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 76/100
# 54/54 - 0s - loss: 0.0029 - 100ms/epoch - 2ms/step
# Epoch 77/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 78/100
# 54/54 - 0s - loss: 0.0030 - 116ms/epoch - 2ms/step
# Epoch 79/100
# 54/54 - 0s - loss: 0.0030 - 117ms/epoch - 2ms/step
# Epoch 80/100
# 54/54 - 0s - loss: 0.0030 - 114ms/epoch - 2ms/step
# Epoch 81/100
# 54/54 - 0s - loss: 0.0030 - 123ms/epoch - 2ms/step
# Epoch 82/100
# 54/54 - 0s - loss: 0.0030 - 145ms/epoch - 3ms/step
# Epoch 83/100
# 54/54 - 0s - loss: 0.0029 - 103ms/epoch - 2ms/step
# Epoch 84/100
# 54/54 - 0s - loss: 0.0029 - 132ms/epoch - 2ms/step
# Epoch 85/100
# 54/54 - 0s - loss: 0.0030 - 117ms/epoch - 2ms/step
# Epoch 86/100
# 54/54 - 0s - loss: 0.0029 - 116ms/epoch - 2ms/step
# Epoch 87/100
# 54/54 - 0s - loss: 0.0030 - 117ms/epoch - 2ms/step
# Epoch 88/100
# 54/54 - 0s - loss: 0.0030 - 133ms/epoch - 2ms/step
# Epoch 89/100
# 54/54 - 0s - loss: 0.0029 - 100ms/epoch - 2ms/step
# Epoch 90/100
# 54/54 - 0s - loss: 0.0030 - 101ms/epoch - 2ms/step
# Epoch 91/100
# 54/54 - 0s - loss: 0.0029 - 98ms/epoch - 2ms/step
# Epoch 92/100
# 54/54 - 0s - loss: 0.0030 - 103ms/epoch - 2ms/step
# Epoch 93/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 94/100
# 54/54 - 0s - loss: 0.0030 - 99ms/epoch - 2ms/step
# Epoch 95/100
# 54/54 - 0s - loss: 0.0030 - 100ms/epoch - 2ms/step
# Epoch 96/100
# 54/54 - 0s - loss: 0.0030 - 96ms/epoch - 2ms/step
# Epoch 97/100
# 54/54 - 0s - loss: 0.0030 - 104ms/epoch - 2ms/step
# Epoch 98/100
# 54/54 - 0s - loss: 0.0029 - 100ms/epoch - 2ms/step
# Epoch 99/100
# 54/54 - 0s - loss: 0.0029 - 100ms/epoch - 2ms/step
# Epoch 100/100
# 54/54 - 0s - loss: 0.0030 - 99ms/epoch - 2ms/step

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

train_pred = mm.inverse_transform(train_pred)
y_train = mm.inverse_transform(y_train)

test_pred = mm.inverse_transform(test_pred)
y_test = mm.inverse_transform(y_test)

train_score = np.sqrt(mean_squared_error(y_train[:,0], train_pred[:,0]))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test[:,0], test_pred[:,0]))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 108/108 [==============================] - 1s 768us/step
# 27/27 [==============================] - 0s 806us/step
# Train score: 4411172.50 RMSE
# Test score: 640957.38 RMSE

# %%
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[len(train_pred) + (look_back*2):len(dataset)-2, :] = test_pred

plt.plot(dataset)
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()

# %% [markdown]
# ### Multiple features

# %%
df = pd.read_csv("GOOG.csv", index_col='Date', parse_dates=True)
dataset = df.values.astype('float32')
tf.random.set_seed(10)

mm = MinMaxScaler(feature_range=(0,1))

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# %%
train = mm.fit_transform(train)
test = mm.transform(test)

# %%
train
# Out:
# array([[3.5772845e-04, 1.0171272e-03, 0.0000000e+00, 1.4599040e-04,
#         1.4599040e-04, 5.4357713e-01],
#        [8.0378354e-04, 3.2179765e-03, 2.0117126e-03, 3.6717802e-03,
#         3.6717802e-03, 2.7788585e-01],
#        [5.1053390e-03, 5.1470064e-03, 5.8002844e-03, 4.1539781e-03,
#         4.1539781e-03, 2.2215134e-01],
#        ...,
#        [8.6769450e-01, 8.7106174e-01, 8.6736101e-01, 8.6549103e-01,
#         8.6549103e-01, 1.9327592e-02],
#        [8.5962659e-01, 8.6163211e-01, 8.5261244e-01, 8.6490488e-01,
#         8.6490488e-01, 2.1896239e-02],
#        [8.5776478e-01, 8.7820917e-01, 8.6205047e-01, 8.8665396e-01,
#         8.8665396e-01, 2.3393810e-02]], dtype=float32)

# %%
y_train = train[:,-1]
y_test = test[:,-1]

# %%
def create_dataset_features (dataset, look_back=1):
    dataX = np.ones(shape=(1, 6))
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), :]
        dataX = np.vstack((dataX, a))
    return np.array(dataX)

# %%
def create_test (dataset, look_back=1):
    dataY = np.ones(shape=(1))
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back)]
        dataY = np.vstack((dataY, a))
    return np.array(dataY)

# %%
look_back = 1
X_train = create_dataset_features(train, look_back)
X_test = create_dataset_features(test, look_back)
y_train = create_test(y_train, look_back)
y_test = create_test(y_test, look_back)

# %%
X_train = np.delete(X_train, 0, 0)
y_train = np.delete(y_train, 0, 0)
X_test = np.delete(X_test, 0, 0)
y_test = np.delete(y_test, 0, 0)

# %%
X_train_reshape = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test_reshape = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(1, 6), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam')
model.fit(X_train_reshape, y_train, epochs=100, batch_size = 64, verbose = 2)
model.summary()
# Out:
# Epoch 1/100
# 54/54 - 3s - loss: 0.0106 - 3s/epoch - 47ms/step
# Epoch 2/100
# 54/54 - 0s - loss: 0.0045 - 96ms/epoch - 2ms/step
# Epoch 3/100
# 54/54 - 0s - loss: 0.0019 - 114ms/epoch - 2ms/step
# Epoch 4/100
# 54/54 - 0s - loss: 4.4683e-04 - 101ms/epoch - 2ms/step
# Epoch 5/100
# 54/54 - 0s - loss: 2.8978e-04 - 100ms/epoch - 2ms/step
# Epoch 6/100
# 54/54 - 0s - loss: 2.0447e-04 - 98ms/epoch - 2ms/step
# Epoch 7/100
# 54/54 - 0s - loss: 2.4003e-04 - 101ms/epoch - 2ms/step
# Epoch 8/100
# 54/54 - 0s - loss: 2.1309e-04 - 100ms/epoch - 2ms/step
# Epoch 9/100
# 54/54 - 0s - loss: 1.8205e-04 - 100ms/epoch - 2ms/step
# Epoch 10/100
# 54/54 - 0s - loss: 1.6818e-04 - 100ms/epoch - 2ms/step
# Epoch 11/100
# 54/54 - 0s - loss: 1.8981e-04 - 100ms/epoch - 2ms/step
# Epoch 12/100
# 54/54 - 0s - loss: 1.9344e-04 - 100ms/epoch - 2ms/step
# Epoch 13/100
# 54/54 - 0s - loss: 1.8499e-04 - 108ms/epoch - 2ms/step
# Epoch 14/100
# 54/54 - 0s - loss: 1.3865e-04 - 90ms/epoch - 2ms/step
# Epoch 15/100
# 54/54 - 0s - loss: 1.3703e-04 - 101ms/epoch - 2ms/step
# Epoch 16/100
# 54/54 - 0s - loss: 1.4175e-04 - 99ms/epoch - 2ms/step
# Epoch 17/100
# 54/54 - 0s - loss: 1.2876e-04 - 113ms/epoch - 2ms/step
# Epoch 18/100
# 54/54 - 0s - loss: 1.6549e-04 - 88ms/epoch - 2ms/step
# Epoch 19/100
# 54/54 - 0s - loss: 1.2526e-04 - 105ms/epoch - 2ms/step
# Epoch 20/100
# 54/54 - 0s - loss: 1.4370e-04 - 94ms/epoch - 2ms/step
# Epoch 21/100
# 54/54 - 0s - loss: 1.1190e-04 - 100ms/epoch - 2ms/step
# Epoch 22/100
# 54/54 - 0s - loss: 1.4065e-04 - 98ms/epoch - 2ms/step
# Epoch 23/100
# 54/54 - 0s - loss: 1.3695e-04 - 100ms/epoch - 2ms/step
# Epoch 24/100
# 54/54 - 0s - loss: 1.3344e-04 - 101ms/epoch - 2ms/step
# Epoch 25/100
# 54/54 - 0s - loss: 1.2825e-04 - 101ms/epoch - 2ms/step
# Epoch 26/100
# 54/54 - 0s - loss: 1.1565e-04 - 99ms/epoch - 2ms/step
# Epoch 27/100
# 54/54 - 0s - loss: 1.1362e-04 - 99ms/epoch - 2ms/step
# Epoch 28/100
# 54/54 - 0s - loss: 1.3817e-04 - 100ms/epoch - 2ms/step
# Epoch 29/100
# 54/54 - 0s - loss: 1.1889e-04 - 100ms/epoch - 2ms/step
# Epoch 30/100
# 54/54 - 0s - loss: 1.3555e-04 - 101ms/epoch - 2ms/step
# Epoch 31/100
# 54/54 - 0s - loss: 1.2098e-04 - 99ms/epoch - 2ms/step
# Epoch 32/100
# 54/54 - 0s - loss: 1.6373e-04 - 101ms/epoch - 2ms/step
# Epoch 33/100
# 54/54 - 0s - loss: 1.1561e-04 - 99ms/epoch - 2ms/step
# Epoch 34/100
# 54/54 - 0s - loss: 1.2927e-04 - 101ms/epoch - 2ms/step
# Epoch 35/100
# 54/54 - 0s - loss: 1.2055e-04 - 100ms/epoch - 2ms/step
# Epoch 36/100
# 54/54 - 0s - loss: 1.1852e-04 - 99ms/epoch - 2ms/step
# Epoch 37/100
# 54/54 - 0s - loss: 1.4074e-04 - 99ms/epoch - 2ms/step
# Epoch 38/100
# 54/54 - 0s - loss: 1.3693e-04 - 102ms/epoch - 2ms/step
# Epoch 39/100
# 54/54 - 0s - loss: 1.1296e-04 - 99ms/epoch - 2ms/step
# Epoch 40/100
# 54/54 - 0s - loss: 1.0911e-04 - 101ms/epoch - 2ms/step
# Epoch 41/100
# 54/54 - 0s - loss: 1.0946e-04 - 100ms/epoch - 2ms/step
# Epoch 42/100
# 54/54 - 0s - loss: 1.1408e-04 - 100ms/epoch - 2ms/step
# Epoch 43/100
# 54/54 - 0s - loss: 1.1194e-04 - 100ms/epoch - 2ms/step
# Epoch 44/100
# 54/54 - 0s - loss: 1.0608e-04 - 100ms/epoch - 2ms/step
# Epoch 45/100
# 54/54 - 0s - loss: 1.1026e-04 - 100ms/epoch - 2ms/step
# Epoch 46/100
# 54/54 - 0s - loss: 1.0448e-04 - 99ms/epoch - 2ms/step
# Epoch 47/100
# 54/54 - 0s - loss: 1.2450e-04 - 100ms/epoch - 2ms/step
# Epoch 48/100
# 54/54 - 0s - loss: 1.3692e-04 - 100ms/epoch - 2ms/step
# Epoch 49/100
# 54/54 - 0s - loss: 1.1765e-04 - 100ms/epoch - 2ms/step
# Epoch 50/100
# 54/54 - 0s - loss: 9.8598e-05 - 101ms/epoch - 2ms/step
# Epoch 51/100
# 54/54 - 0s - loss: 1.1565e-04 - 99ms/epoch - 2ms/step
# Epoch 52/100
# 54/54 - 0s - loss: 1.1310e-04 - 110ms/epoch - 2ms/step
# Epoch 53/100
# 54/54 - 0s - loss: 1.2825e-04 - 107ms/epoch - 2ms/step
# Epoch 54/100
# 54/54 - 0s - loss: 1.3338e-04 - 118ms/epoch - 2ms/step
# Epoch 55/100
# 54/54 - 0s - loss: 1.0805e-04 - 115ms/epoch - 2ms/step
# Epoch 56/100
# 54/54 - 0s - loss: 1.3006e-04 - 122ms/epoch - 2ms/step
# Epoch 57/100
# 54/54 - 0s - loss: 1.1279e-04 - 113ms/epoch - 2ms/step
# Epoch 58/100
# 54/54 - 0s - loss: 1.0756e-04 - 116ms/epoch - 2ms/step
# Epoch 59/100
# 54/54 - 0s - loss: 1.1013e-04 - 131ms/epoch - 2ms/step
# Epoch 60/100
# 54/54 - 0s - loss: 1.1086e-04 - 118ms/epoch - 2ms/step
# Epoch 61/100
# 54/54 - 0s - loss: 1.1766e-04 - 115ms/epoch - 2ms/step
# Epoch 62/100
# 54/54 - 0s - loss: 1.3780e-04 - 116ms/epoch - 2ms/step
# Epoch 63/100
# 54/54 - 0s - loss: 1.4951e-04 - 118ms/epoch - 2ms/step
# Epoch 64/100
# 54/54 - 0s - loss: 1.3010e-04 - 101ms/epoch - 2ms/step
# Epoch 65/100
# 54/54 - 0s - loss: 1.0599e-04 - 101ms/epoch - 2ms/step
# Epoch 66/100
# 54/54 - 0s - loss: 1.2590e-04 - 99ms/epoch - 2ms/step
# Epoch 67/100
# 54/54 - 0s - loss: 1.0325e-04 - 100ms/epoch - 2ms/step
# Epoch 68/100
# 54/54 - 0s - loss: 1.1169e-04 - 100ms/epoch - 2ms/step
# Epoch 69/100
# 54/54 - 0s - loss: 1.1224e-04 - 100ms/epoch - 2ms/step
# Epoch 70/100
# 54/54 - 0s - loss: 1.0151e-04 - 100ms/epoch - 2ms/step
# Epoch 71/100
# 54/54 - 0s - loss: 1.3295e-04 - 104ms/epoch - 2ms/step
# Epoch 72/100
# 54/54 - 0s - loss: 1.1148e-04 - 96ms/epoch - 2ms/step
# Epoch 73/100
# 54/54 - 0s - loss: 1.0677e-04 - 100ms/epoch - 2ms/step
# Epoch 74/100
# 54/54 - 0s - loss: 1.2684e-04 - 99ms/epoch - 2ms/step
# Epoch 75/100
# 54/54 - 0s - loss: 1.0266e-04 - 101ms/epoch - 2ms/step
# Epoch 76/100
# 54/54 - 0s - loss: 1.0983e-04 - 133ms/epoch - 2ms/step
# Epoch 77/100
# 54/54 - 0s - loss: 1.0935e-04 - 100ms/epoch - 2ms/step
# Epoch 78/100
# 54/54 - 0s - loss: 1.0787e-04 - 84ms/epoch - 2ms/step
# Epoch 79/100
# 54/54 - 0s - loss: 1.0884e-04 - 85ms/epoch - 2ms/step
# Epoch 80/100
# 54/54 - 0s - loss: 1.1349e-04 - 115ms/epoch - 2ms/step
# Epoch 81/100
# 54/54 - 0s - loss: 1.0263e-04 - 100ms/epoch - 2ms/step
# Epoch 82/100
# 54/54 - 0s - loss: 1.1014e-04 - 85ms/epoch - 2ms/step
# Epoch 83/100
# 54/54 - 0s - loss: 1.1566e-04 - 100ms/epoch - 2ms/step
# Epoch 84/100
# 54/54 - 0s - loss: 1.0693e-04 - 99ms/epoch - 2ms/step
# Epoch 85/100
# 54/54 - 0s - loss: 1.1296e-04 - 101ms/epoch - 2ms/step
# Epoch 86/100
# 54/54 - 0s - loss: 1.3019e-04 - 100ms/epoch - 2ms/step
# Epoch 87/100
# 54/54 - 0s - loss: 1.1115e-04 - 98ms/epoch - 2ms/step
# Epoch 88/100
# 54/54 - 0s - loss: 1.2290e-04 - 103ms/epoch - 2ms/step
# Epoch 89/100
# 54/54 - 0s - loss: 1.0578e-04 - 100ms/epoch - 2ms/step
# Epoch 90/100
# 54/54 - 0s - loss: 1.1243e-04 - 99ms/epoch - 2ms/step
# Epoch 91/100
# 54/54 - 0s - loss: 1.1100e-04 - 100ms/epoch - 2ms/step
# Epoch 92/100
# 54/54 - 0s - loss: 1.1360e-04 - 99ms/epoch - 2ms/step
# Epoch 93/100
# 54/54 - 0s - loss: 8.9160e-05 - 100ms/epoch - 2ms/step
# Epoch 94/100
# 54/54 - 0s - loss: 1.1614e-04 - 99ms/epoch - 2ms/step
# Epoch 95/100
# 54/54 - 0s - loss: 9.8090e-05 - 101ms/epoch - 2ms/step
# Epoch 96/100
# 54/54 - 0s - loss: 1.1421e-04 - 101ms/epoch - 2ms/step
# Epoch 97/100
# 54/54 - 0s - loss: 1.0979e-04 - 86ms/epoch - 2ms/step
# Epoch 98/100
# 54/54 - 0s - loss: 1.1260e-04 - 115ms/epoch - 2ms/step
# Epoch 99/100
# 54/54 - 0s - loss: 1.1860e-04 - 85ms/epoch - 2ms/step
# Epoch 100/100
# 54/54 - 0s - loss: 1.1695e-04 - 99ms/epoch - 2ms/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 1, 50)             11400
#
#  dropout_4 (Dropout)         (None, 1, 50)             0
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dropout_5 (Dropout)         (None, 50)                0
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 31,651
# Trainable params: 31,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make predictions
train_pred = model.predict(X_train_reshape)
test_pred = model.predict(X_test_reshape)

# unable to inverse transform values due to original output having 6 features

# calculate RMSE
train_score = np.sqrt(mean_squared_error(y_train, train_pred))
print("Train score: %.2f RMSE" % (train_score))

test_score = np.sqrt(mean_squared_error(y_test, test_pred))
print("Test score: %.2f RMSE" % (test_score))
# Out:
# 108/108 [==============================] - 1s 782us/step
# 27/27 [==============================] - 0s 808us/step
# Train score: 0.00 RMSE
# Test score: 0.00 RMSE

# %%
dataset_trans = mm.transform(dataset)

# %%
# shift train predictions for plotting
train_pred_plot = np.empty_like(dataset)
train_pred_plot[:,:] = np.nan
train_pred_plot[look_back:len(train_pred)+look_back, :] = train_pred

# shift test predictions for plotting
test_pred_plot = np.empty_like(dataset)
test_pred_plot[:,:] = np.nan
test_pred_plot[len(train_pred) + (look_back*2)+1:len(dataset)-1, :] = test_pred

# plot baseline and predictions
plt.plot(dataset_trans[:,-1])
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.show()
